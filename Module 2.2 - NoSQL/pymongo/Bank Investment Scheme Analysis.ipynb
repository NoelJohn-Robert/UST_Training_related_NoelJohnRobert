# %% [markdown]
# # 1. main()

# %%
import pymongo
import pandas as pd

# %% [markdown]
# ### 1. connecting to client

# %%
client = pymongo.MongoClient('localhost:27017')
print(client)
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %% [markdown]
# ### 2. set database and collection name

# %%
databaseName = 'bankDB'
collectionName = 'customer'

# %% [markdown]
# ### 3. list available databases

# %%
print(client.list_database_names())
# Out:
# ['ECommerce', 'admin', 'bankDB', 'config', 'local', 'pymongo_db', 'restaurants']

# %% [markdown]
# ### 4. set db

# %%
db = client[databaseName]
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'bankDB')

# %% [markdown]
# ### 5. list all collections in the database

# %%
print(db.list_collection_names())
# Out:
# ['customer']

# %% [markdown]
# ### 6. set collection

# %%
collection = db[collectionName]
print(collection)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'bankDB'), 'customer')

# %% [markdown]
# # 2. Loading data from JSON to mongoDB

# %%
fileLocation = r'C:\Users\Administrator\Downloads\bank_edited.json'

bank_df = pd.read_json(fileLocation)

# %%
bank_df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may       261         1     -1         0  unknown   no
# 1        unknown    5   may       151         1     -1         0  unknown   no
# 2        unknown    5   may        76         1     -1         0  unknown   no
# 3        unknown    5   may        92         1     -1         0  unknown   no
# 4        unknown    5   may       198         1     -1         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
# collection.insert_many(data)
# read line by line and convert into dictionary

records = bank_df.to_dict(orient='records')
if records:
    collection.insert_many(records)

# %% [markdown]
# # 3. Questions

# %% [markdown]
# ## 3.1 Give marketing success rate (No. of people subscribed / total no. of entries)

# %%
# countSubscribed = collection.count_documents({'y': 'yes'})
# totalEntries = collection.count_documents({})
# if totalEntries != 0:
#     print(f"Market success rate = {round(countSubscribed*100/totalEntries, 3)}%")
# else: 
#     print("Empty database")



totalEntries = list(collection.aggregate([{'$count': 'totalEntries'}]))[0]['totalEntries']
countSubscribed = list(collection.aggregate([{"$match": {"y": "yes"}}, {'$count': 'countSubscribed'}]))[0]['countSubscribed']

print(f"Market success rate = {round(countSubscribed*100/totalEntries, 3)}%")
# Out:
# Market success rate = 11.698%

# %%
# above thing in mongodb
# we combined two aggregate operations together using $facet

# db.customer.aggregate([
#     {
#         $facet: {
#             totalCount: [{$count: 'total'}],
#             subscribedCount: [{$match: {y: 'yes'}}, {$count: 'subscribed'}]
#         }
#     },
#     {$project: {
#         totalCount: {$arrayElemAt:['$totalCount.total', 0]}, 
#         subscribedCount: {$arrayElemAt:['$subscribedCount.subscribed', 0]},
#         successRate: {$divide: [{$arrayElemAt:['$subscribedCount.subscribed', 0]}, {$arrayElemAt:['$totalCount.total', 0]}]}
#     }}
# ])

# %% [markdown]
# ## 3.2 Give marketing failure rate

# %%
# countNotSubscribed = collection.count_documents({'y': 'no'})
# totalEntries = collection.count_documents({})
# if totalEntries != 0:
#     print(f"Market failure rate = {round(countNotSubscribed*100/totalEntries, 3)}%")
# else: 
#     print("Empty database")


# countNotSubscribed = list(collection.aggregate([{"$match": {"y": "no"}}, {'$count': 'countNotSubscribed'}]))[0]['countNotSubscribed']
# print(f"Market failure rate = {round(countNotSubscribed*100/totalEntries, 3)}%")




result = collection.aggregate([
    {
        '$facet': {
            'totalCount': [{'$count': 'total'}],
            'subscribedCount': [{'$match': {'y': 'no'}}, {'$count': 'notsubscribed'}]
        }
    },
    {
        '$project': {
            'totalCount': {'$arrayElemAt':['$totalCount.total', 0]}, 
            'subscribedCount': {'$arrayElemAt':['$subscribedCount.notsubscribed', 0]},
            'failureRate': {'$divide': [{'$arrayElemAt':['$subscribedCount.notsubscribed', 0]}, {'$arrayElemAt':['$totalCount.total', 0]}]}
        }
    }
])

print(list(result))
# Out:
# [{'totalCount': 45211, 'subscribedCount': 39922, 'failureRate': 0.8830151954170445}]

# %% [markdown]
# ## 3.3 Give the maximum, mean, median, minimum age of the average targeted customer.

# %%
list(
    db.customer.aggregate(
        [
            {'$group': {'_id':'null', 'ages':{'$push':'$age'}}}, 
            {'$project': {
                '_id': 0, 
                'avgAge': {'$avg':"$ages"}, 
                'minAge': {'$min':'$ages'}, 
                'maxAge': {'$max':'$ages'}, 
                'medianAge': {'$median': {'input':'$ages', 'method':'approximate'}}
            }
            },
        ]
    )
)
# Out:
# [{'avgAge': 40.93621021432837, 'minAge': 18, 'maxAge': 95, 'medianAge': 39.0}]

# %% [markdown]
# ## 3.4 Check if age matters in marketing subscription for deposit

# %%
list(
    collection.aggregate([
      {'$match': {'y': 'yes'}},
      {'$group': {'_id': '$age', 'count': {'$sum': 1}}},
      {'$sort': {'count':-1}}
    ]) 
)
# Out:
# [{'_id': 32, 'count': 221},
#  {'_id': 30, 'count': 217},
#  {'_id': 33, 'count': 210},
#  {'_id': 35, 'count': 209},
#  {'_id': 31, 'count': 206},
#  {'_id': 34, 'count': 198},
#  {'_id': 36, 'count': 195},
#  {'_id': 29, 'count': 171},
#  {'_id': 37, 'count': 170},
#  {'_id': 28, 'count': 162},
#  {'_id': 38, 'count': 144},
#  {'_id': 39, 'count': 143},
#  {'_id': 27, 'count': 141},
#  {'_id': 26, 'count': 134},
#  {'_id': 41, 'count': 120},
#  {'_id': 46, 'count': 118},
#  {'_id': 40, 'count': 116},
#  {'_id': 47, 'count': 113},
#  {'_id': 25, 'count': 113},
#  {'_id': 42, 'count': 111},
#  {'_id': 45, 'count': 106},
#  {'_id': 43, 'count': 103},
#  {'_id': 49, 'count': 101},
#  {'_id': 60, 'count': 98},
#  {'_id': 44, 'count': 93},
#  {'_id': 59, 'count': 88},
#  {'_id': 53, 'count': 85},
#  {'_id': 52, 'count': 85},
#  {'_id': 54, 'count': 84},
#  {'_id': 48, 'count': 82},
#  {'_id': 57, 'count': 78},
#  {'_id': 51, 'count': 77},
#  {'_id': 55, 'count': 76},
#  {'_id': 58, 'count': 72},
#  {'_id': 50, 'count': 72},
#  {'_id': 24, 'count': 68},
#  {'_id': 56, 'count': 68},
#  {'_id': 61, 'count': 57},
#  {'_id': 23, 'count': 44},
#  {'_id': 22, 'count': 40},
#  {'_id': 62, 'count': 39},
#  {'_id': 64, 'count': 35},
#  {'_id': 63, 'count': 30},
#  {'_id': 71, 'count': 25},
#  {'_id': 73, 'count': 24},
#  {'_id': 72, 'count': 24},
#  {'_id': 66, 'count': 24},
#  {'_id': 67, 'count': 23},
#  {'_id': 77, 'count': 22},
#  {'_id': 21, 'count': 22},
#  {'_id': 65, 'count': 21},
#  {'_id': 68, 'count': 21},
#  {'_id': 70, 'count': 17},
#  {'_id': 69, 'count': 17},
#  {'_id': 76, 'count': 16},
#  {'_id': 75, 'count': 15},
#  {'_id': 20, 'count': 15},
#  {'_id': 78, 'count': 14},
#  {'_id': 74, 'count': 13},
#  {'_id': 80, 'count': 12},
#  {'_id': 19, 'count': 11},
#  {'_id': 79, 'count': 10},
#  {'_id': 82, 'count': 8},
#  {'_id': 18, 'count': 7},
#  {'_id': 83, 'count': 6},
#  {'_id': 81, 'count': 6},
#  {'_id': 84, 'count': 5},
#  {'_id': 86, 'count': 4},
#  {'_id': 85, 'count': 4},
#  {'_id': 87, 'count': 3},
#  {'_id': 92, 'count': 2},
#  {'_id': 93, 'count': 2},
#  {'_id': 90, 'count': 2},
#  {'_id': 95, 'count': 1}]

# %% [markdown]
# ## 3.5 Check if marital status mattered for a subscription to deposit

# %%
list(
    collection.aggregate([
      {'$match': {'y': 'yes'}},
      {'$group': {'_id': '$marital', 'count': {'$sum': 1}}},
      {'$sort': {'count':-1}}
    ]) 
)
# Out:
# [{'_id': 'married', 'count': 2755},
#  {'_id': 'single', 'count': 1912},
#  {'_id': 'divorced', 'count': 622}]

# %% [markdown]
# ## 3.6 Check if age and marital status together mattered for a subscription to deposit scheme

# %%
list(
    db.customer.aggregate([
      {'$match': {'y': 'yes'}},
      {'$group': {'_id': {'marital':'$marital', 'age':'$age'}, 'count': {'$sum': 1}}},
      {'$sort': {'count':-1}}
    ])
)
# Out:
# [{'_id': {'marital': 'single', 'age': 30}, 'count': 151},
#  {'_id': {'marital': 'single', 'age': 28}, 'count': 138},
#  {'_id': {'marital': 'single', 'age': 29}, 'count': 133},
#  {'_id': {'marital': 'single', 'age': 32}, 'count': 124},
#  {'_id': {'marital': 'single', 'age': 26}, 'count': 121},
#  {'_id': {'marital': 'married', 'age': 34}, 'count': 118},
#  {'_id': {'marital': 'single', 'age': 31}, 'count': 111},
#  {'_id': {'marital': 'single', 'age': 27}, 'count': 110},
#  {'_id': {'marital': 'married', 'age': 35}, 'count': 101},
#  {'_id': {'marital': 'married', 'age': 36}, 'count': 100},
#  {'_id': {'marital': 'single', 'age': 25}, 'count': 99},
#  {'_id': {'marital': 'married', 'age': 37}, 'count': 98},
#  {'_id': {'marital': 'single', 'age': 33}, 'count': 97},
#  {'_id': {'marital': 'married', 'age': 33}, 'count': 97},
#  {'_id': {'marital': 'married', 'age': 39}, 'count': 87},
#  {'_id': {'marital': 'married', 'age': 32}, 'count': 87},
#  {'_id': {'marital': 'married', 'age': 38}, 'count': 86},
#  {'_id': {'marital': 'single', 'age': 35}, 'count': 84},
#  {'_id': {'marital': 'married', 'age': 47}, 'count': 83},
#  {'_id': {'marital': 'married', 'age': 46}, 'count': 80},
#  {'_id': {'marital': 'married', 'age': 31}, 'count': 80},
#  {'_id': {'marital': 'married', 'age': 60}, 'count': 73},
#  {'_id': {'marital': 'married', 'age': 40}, 'count': 73},
#  {'_id': {'marital': 'married', 'age': 41}, 'count': 72},
#  {'_id': {'marital': 'single', 'age': 36}, 'count': 71},
#  {'_id': {'marital': 'married', 'age': 49}, 'count': 71},
#  {'_id': {'marital': 'married', 'age': 42}, 'count': 70},
#  {'_id': {'marital': 'single', 'age': 34}, 'count': 69},
#  {'_id': {'marital': 'married', 'age': 45}, 'count': 68},
#  {'_id': {'marital': 'married', 'age': 52}, 'count': 67},
#  {'_id': {'marital': 'married', 'age': 59}, 'count': 66},
#  {'_id': {'marital': 'married', 'age': 43}, 'count': 62},
#  {'_id': {'marital': 'married', 'age': 53}, 'count': 60},
#  {'_id': {'marital': 'married', 'age': 51}, 'count': 59},
#  {'_id': {'marital': 'married', 'age': 30}, 'count': 59},
#  {'_id': {'marital': 'married', 'age': 57}, 'count': 58},
#  {'_id': {'marital': 'single', 'age': 24}, 'count': 58},
#  {'_id': {'marital': 'single', 'age': 37}, 'count': 57},
#  {'_id': {'marital': 'married', 'age': 50}, 'count': 57},
#  {'_id': {'marital': 'married', 'age': 58}, 'count': 54},
#  {'_id': {'marital': 'married', 'age': 54}, 'count': 52},
#  {'_id': {'marital': 'married', 'age': 48}, 'count': 51},
#  {'_id': {'marital': 'married', 'age': 55}, 'count': 50},
#  {'_id': {'marital': 'married', 'age': 56}, 'count': 49},
#  {'_id': {'marital': 'married', 'age': 44}, 'count': 48},
#  {'_id': {'marital': 'married', 'age': 61}, 'count': 47},
#  {'_id': {'marital': 'single', 'age': 23}, 'count': 42},
#  {'_id': {'marital': 'single', 'age': 39}, 'count': 40},
#  {'_id': {'marital': 'single', 'age': 22}, 'count': 40},
#  {'_id': {'marital': 'single', 'age': 38}, 'count': 38},
#  {'_id': {'marital': 'married', 'age': 62}, 'count': 34},
#  {'_id': {'marital': 'married', 'age': 29}, 'count': 33},
#  {'_id': {'marital': 'married', 'age': 64}, 'count': 31},
#  {'_id': {'marital': 'single', 'age': 40}, 'count': 31},
#  {'_id': {'marital': 'single', 'age': 41}, 'count': 31},
#  {'_id': {'marital': 'married', 'age': 27}, 'count': 29},
#  {'_id': {'marital': 'divorced', 'age': 55}, 'count': 26},
#  {'_id': {'marital': 'single', 'age': 43}, 'count': 26},
#  {'_id': {'marital': 'married', 'age': 63}, 'count': 25},
#  {'_id': {'marital': 'divorced', 'age': 46}, 'count': 25},
#  {'_id': {'marital': 'divorced', 'age': 54}, 'count': 24},
#  {'_id': {'marital': 'divorced', 'age': 36}, 'count': 24},
#  {'_id': {'marital': 'divorced', 'age': 45}, 'count': 24},
#  {'_id': {'marital': 'divorced', 'age': 35}, 'count': 24},
#  {'_id': {'marital': 'single', 'age': 44}, 'count': 24},
#  {'_id': {'marital': 'married', 'age': 72}, 'count': 23},
#  {'_id': {'marital': 'married', 'age': 66}, 'count': 22},
#  {'_id': {'marital': 'single', 'age': 42}, 'count': 22},
#  {'_id': {'marital': 'single', 'age': 21}, 'count': 21},
#  {'_id': {'marital': 'divorced', 'age': 60}, 'count': 21},
#  {'_id': {'marital': 'divorced', 'age': 44}, 'count': 21},
#  {'_id': {'marital': 'single', 'age': 47}, 'count': 20},
#  {'_id': {'marital': 'married', 'age': 28}, 'count': 20},
#  {'_id': {'marital': 'divorced', 'age': 38}, 'count': 20},
#  {'_id': {'marital': 'divorced', 'age': 42}, 'count': 19},
#  {'_id': {'marital': 'married', 'age': 77}, 'count': 19},
#  {'_id': {'marital': 'married', 'age': 73}, 'count': 19},
#  {'_id': {'marital': 'married', 'age': 65}, 'count': 19},
#  {'_id': {'marital': 'divorced', 'age': 53}, 'count': 18},
#  {'_id': {'marital': 'divorced', 'age': 41}, 'count': 17},
#  {'_id': {'marital': 'divorced', 'age': 58}, 'count': 17},
#  {'_id': {'marital': 'married', 'age': 71}, 'count': 17},
#  {'_id': {'marital': 'divorced', 'age': 59}, 'count': 16},
#  {'_id': {'marital': 'divorced', 'age': 39}, 'count': 16},
#  {'_id': {'marital': 'divorced', 'age': 49}, 'count': 16},
#  {'_id': {'marital': 'divorced', 'age': 33}, 'count': 16},
#  {'_id': {'marital': 'divorced', 'age': 48}, 'count': 16},
#  {'_id': {'marital': 'single', 'age': 48}, 'count': 15},
#  {'_id': {'marital': 'divorced', 'age': 31}, 'count': 15},
#  {'_id': {'marital': 'divorced', 'age': 43}, 'count': 15},
#  {'_id': {'marital': 'married', 'age': 67}, 'count': 15},
#  {'_id': {'marital': 'divorced', 'age': 37}, 'count': 15},
#  {'_id': {'marital': 'divorced', 'age': 57}, 'count': 15},
#  {'_id': {'marital': 'single', 'age': 45}, 'count': 14},
#  {'_id': {'marital': 'single', 'age': 20}, 'count': 14},
#  {'_id': {'marital': 'single', 'age': 49}, 'count': 14},
#  {'_id': {'marital': 'married', 'age': 25}, 'count': 14},
#  {'_id': {'marital': 'married', 'age': 68}, 'count': 13},
#  {'_id': {'marital': 'married', 'age': 69}, 'count': 13},
#  {'_id': {'marital': 'single', 'age': 46}, 'count': 13},
#  {'_id': {'marital': 'married', 'age': 26}, 'count': 13},
#  {'_id': {'marital': 'divorced', 'age': 56}, 'count': 13},
#  {'_id': {'marital': 'married', 'age': 75}, 'count': 12},
#  {'_id': {'marital': 'married', 'age': 70}, 'count': 12},
#  {'_id': {'marital': 'divorced', 'age': 40}, 'count': 12},
#  {'_id': {'marital': 'single', 'age': 19}, 'count': 11},
#  {'_id': {'marital': 'divorced', 'age': 34}, 'count': 11},
#  {'_id': {'marital': 'divorced', 'age': 50}, 'count': 11},
#  {'_id': {'marital': 'married', 'age': 80}, 'count': 11},
#  {'_id': {'marital': 'married', 'age': 74}, 'count': 11},
#  {'_id': {'marital': 'divorced', 'age': 52}, 'count': 10},
#  {'_id': {'marital': 'divorced', 'age': 51}, 'count': 10},
#  {'_id': {'marital': 'married', 'age': 24}, 'count': 10},
#  {'_id': {'marital': 'divorced', 'age': 32}, 'count': 10},
#  {'_id': {'marital': 'divorced', 'age': 47}, 'count': 10},
#  {'_id': {'marital': 'married', 'age': 76}, 'count': 10},
#  {'_id': {'marital': 'divorced', 'age': 61}, 'count': 9},
#  {'_id': {'marital': 'single', 'age': 54}, 'count': 8},
#  {'_id': {'marital': 'single', 'age': 52}, 'count': 8},
#  {'_id': {'marital': 'married', 'age': 78}, 'count': 8},
#  {'_id': {'marital': 'married', 'age': 79}, 'count': 8},
#  {'_id': {'marital': 'divorced', 'age': 71}, 'count': 8},
#  {'_id': {'marital': 'single', 'age': 51}, 'count': 8},
#  {'_id': {'marital': 'single', 'age': 18}, 'count': 7},
#  {'_id': {'marital': 'single', 'age': 53}, 'count': 7},
#  {'_id': {'marital': 'divorced', 'age': 67}, 'count': 7},
#  {'_id': {'marital': 'divorced', 'age': 30}, 'count': 7},
#  {'_id': {'marital': 'single', 'age': 56}, 'count': 6},
#  {'_id': {'marital': 'divorced', 'age': 68}, 'count': 6},
#  {'_id': {'marital': 'divorced', 'age': 78}, 'count': 6},
#  {'_id': {'marital': 'divorced', 'age': 76}, 'count': 6},
#  {'_id': {'marital': 'single', 'age': 59}, 'count': 6},
#  {'_id': {'marital': 'divorced', 'age': 70}, 'count': 5},
#  {'_id': {'marital': 'married', 'age': 82}, 'count': 5},
#  {'_id': {'marital': 'single', 'age': 57}, 'count': 5},
#  {'_id': {'marital': 'divorced', 'age': 62}, 'count': 5},
#  {'_id': {'marital': 'divorced', 'age': 29}, 'count': 5},
#  {'_id': {'marital': 'married', 'age': 84}, 'count': 4},
#  {'_id': {'marital': 'divorced', 'age': 64}, 'count': 4},
#  {'_id': {'marital': 'divorced', 'age': 63}, 'count': 4},
#  {'_id': {'marital': 'divorced', 'age': 73}, 'count': 4},
#  {'_id': {'marital': 'divorced', 'age': 28}, 'count': 4},
#  {'_id': {'marital': 'married', 'age': 81}, 'count': 4},
#  {'_id': {'marital': 'single', 'age': 50}, 'count': 4},
#  {'_id': {'marital': 'single', 'age': 60}, 'count': 4},
#  {'_id': {'marital': 'divorced', 'age': 82}, 'count': 3},
#  {'_id': {'marital': 'married', 'age': 85}, 'count': 3},
#  {'_id': {'marital': 'divorced', 'age': 75}, 'count': 3},
#  {'_id': {'marital': 'divorced', 'age': 69}, 'count': 3},
#  {'_id': {'marital': 'divorced', 'age': 77}, 'count': 3},
#  {'_id': {'marital': 'married', 'age': 83}, 'count': 3},
#  {'_id': {'marital': 'married', 'age': 92}, 'count': 2},
#  {'_id': {'marital': 'divorced', 'age': 66}, 'count': 2},
#  {'_id': {'marital': 'married', 'age': 93}, 'count': 2},
#  {'_id': {'marital': 'divorced', 'age': 65}, 'count': 2},
#  {'_id': {'marital': 'married', 'age': 87}, 'count': 2},
#  {'_id': {'marital': 'divorced', 'age': 90}, 'count': 2},
#  {'_id': {'marital': 'divorced', 'age': 79}, 'count': 2},
#  {'_id': {'marital': 'single', 'age': 68}, 'count': 2},
#  {'_id': {'marital': 'married', 'age': 86}, 'count': 2},
#  {'_id': {'marital': 'divorced', 'age': 83}, 'count': 2},
#  {'_id': {'marital': 'divorced', 'age': 27}, 'count': 2},
#  {'_id': {'marital': 'married', 'age': 23}, 'count': 2},
#  {'_id': {'marital': 'divorced', 'age': 81}, 'count': 2},
#  {'_id': {'marital': 'divorced', 'age': 74}, 'count': 2},
#  {'_id': {'marital': 'single', 'age': 69}, 'count': 1},
#  {'_id': {'marital': 'married', 'age': 20}, 'count': 1},
#  {'_id': {'marital': 'divorced', 'age': 84}, 'count': 1},
#  {'_id': {'marital': 'single', 'age': 58}, 'count': 1},
#  {'_id': {'marital': 'single', 'age': 83}, 'count': 1},
#  {'_id': {'marital': 'divorced', 'age': 87}, 'count': 1},
#  {'_id': {'marital': 'single', 'age': 63}, 'count': 1},
#  {'_id': {'marital': 'single', 'age': 61}, 'count': 1},
#  {'_id': {'marital': 'single', 'age': 73}, 'count': 1},
#  {'_id': {'marital': 'divorced', 'age': 95}, 'count': 1},
#  {'_id': {'marital': 'married', 'age': 21}, 'count': 1},
#  {'_id': {'marital': 'divorced', 'age': 86}, 'count': 1},
#  {'_id': {'marital': 'divorced', 'age': 72}, 'count': 1},
#  {'_id': {'marital': 'single', 'age': 86}, 'count': 1},
#  {'_id': {'marital': 'single', 'age': 67}, 'count': 1},
#  {'_id': {'marital': 'divorced', 'age': 85}, 'count': 1},
#  {'_id': {'marital': 'divorced', 'age': 80}, 'count': 1}]

# %% [markdown]
# ## 3.7 Find All Records Where Housing Loan is Approved

# %%
list(db.customer.find({'housing': 'yes'}))
# Out:
# [{'_id': ObjectId('66c561a994610b691202b35c'),
#   'age': 58,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 2143,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 261,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b35d'),
#   'age': 44,
#   'job': 'technician',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 29,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 151,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b35e'),
#   'age': 33,
#   'job': 'entrepreneur',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 2,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 76,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b35f'),
#   'age': 47,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 1506,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 92,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b361'),
#   'age': 35,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 231,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 139,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b362'),
#   'age': 28,
#   'job': 'management',
#   'marital': 'single',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 447,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 217,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b363'),
#   'age': 42,
#   'job': 'entrepreneur',
#   'marital': 'divorced',
#   'education': 'tertiary',
#   'default': 'yes',
#   'balance': 2,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 380,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b364'),
#   'age': 58,
#   'job': 'retired',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 121,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 50,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b365'),
#   'age': 43,
#   'job': 'technician',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 593,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 55,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b366'),
#   'age': 41,
#   'job': 'admin.',
#   'marital': 'divorced',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 270,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 222,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b367'),
#   'age': 29,
#   'job': 'admin.',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 390,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 137,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b368'),
#   'age': 53,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 6,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 517,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b369'),
#   'age': 58,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 71,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 71,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b36a'),
#   'age': 57,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 162,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 174,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b36b'),
#   'age': 51,
#   'job': 'retired',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 229,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 353,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b36c'),
#   'age': 45,
#   'job': 'admin.',
#   'marital': 'single',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 13,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 98,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b36d'),
#   'age': 57,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 52,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 38,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b36e'),
#   'age': 60,
#   'job': 'retired',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 60,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 219,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b36f'),
#   'age': 33,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 54,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b370'),
#   'age': 28,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 723,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 262,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b371'),
#   'age': 56,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 779,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 164,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b372'),
#   'age': 32,
#   'job': 'blue-collar',
#   'marital': 'single',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 23,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 160,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b373'),
#   'age': 25,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 50,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 342,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b374'),
#   'age': 40,
#   'job': 'retired',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 181,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b375'),
#   'age': 44,
#   'job': 'admin.',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': -372,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 172,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b376'),
#   'age': 39,
#   'job': 'management',
#   'marital': 'single',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 255,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 296,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b377'),
#   'age': 52,
#   'job': 'entrepreneur',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 113,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 127,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b378'),
#   'age': 46,
#   'job': 'management',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': -246,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 255,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b379'),
#   'age': 36,
#   'job': 'technician',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 265,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 348,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b37b'),
#   'age': 49,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 378,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 230,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b37c'),
#   'age': 60,
#   'job': 'admin.',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 39,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 208,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b37d'),
#   'age': 59,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 226,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b37e'),
#   'age': 51,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 10635,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 336,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b37f'),
#   'age': 57,
#   'job': 'technician',
#   'marital': 'divorced',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 63,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 242,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b380'),
#   'age': 25,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': -7,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 365,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b382'),
#   'age': 36,
#   'job': 'admin.',
#   'marital': 'divorced',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 506,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 577,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b383'),
#   'age': 37,
#   'job': 'admin.',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 137,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b384'),
#   'age': 44,
#   'job': 'services',
#   'marital': 'divorced',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 2586,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 160,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b385'),
#   'age': 50,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 49,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 180,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b386'),
#   'age': 60,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 104,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 22,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b387'),
#   'age': 54,
#   'job': 'retired',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 529,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 1492,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b388'),
#   'age': 58,
#   'job': 'retired',
#   'marital': 'married',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 96,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 616,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b389'),
#   'age': 36,
#   'job': 'admin.',
#   'marital': 'single',
#   'education': 'primary',
#   'default': 'no',
#   'balance': -171,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 242,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b38a'),
#   'age': 58,
#   'job': 'self-employed',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': -364,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 355,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b38b'),
#   'age': 44,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 225,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b38d'),
#   'age': 29,
#   'job': 'management',
#   'marital': 'single',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 363,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b38e'),
#   'age': 54,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 1291,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 266,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b38f'),
#   'age': 48,
#   'job': 'management',
#   'marital': 'divorced',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': -244,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 253,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b390'),
#   'age': 32,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 179,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b391'),
#   'age': 42,
#   'job': 'admin.',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': -76,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 787,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b392'),
#   'age': 24,
#   'job': 'technician',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': -103,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 145,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b394'),
#   'age': 38,
#   'job': 'management',
#   'marital': 'single',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 424,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 104,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b395'),
#   'age': 47,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 306,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 13,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b396'),
#   'age': 40,
#   'job': 'blue-collar',
#   'marital': 'single',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 24,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 185,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b397'),
#   'age': 46,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 179,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 1778,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b398'),
#   'age': 32,
#   'job': 'admin.',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 138,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b399'),
#   'age': 53,
#   'job': 'technician',
#   'marital': 'divorced',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 989,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 812,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b39a'),
#   'age': 57,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 249,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 164,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b39b'),
#   'age': 33,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 790,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 391,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b39c'),
#   'age': 49,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 154,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 357,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b39d'),
#   'age': 51,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 6530,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 91,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b39f'),
#   'age': 59,
#   'job': 'management',
#   'marital': 'divorced',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 59,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 273,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3a0'),
#   'age': 55,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 1205,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 158,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3a1'),
#   'age': 35,
#   'job': 'blue-collar',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 12223,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 177,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3a2'),
#   'age': 57,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 5935,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 258,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3a3'),
#   'age': 31,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 25,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 172,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3a4'),
#   'age': 54,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 282,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 154,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3a5'),
#   'age': 55,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 23,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 291,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3a6'),
#   'age': 43,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 1937,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 181,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3a7'),
#   'age': 53,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 384,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 176,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3aa'),
#   'age': 49,
#   'job': 'services',
#   'marital': 'divorced',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 272,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3ab'),
#   'age': 55,
#   'job': 'services',
#   'marital': 'divorced',
#   'education': 'secondary',
#   'default': 'yes',
#   'balance': 1,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 208,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3ac'),
#   'age': 45,
#   'job': 'admin.',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 206,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 193,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3ae'),
#   'age': 42,
#   'job': 'technician',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 690,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 20,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3af'),
#   'age': 59,
#   'job': 'admin.',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 2343,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 1042,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'yes'},
#  {'_id': ObjectId('66c561a994610b691202b3b0'),
#   'age': 46,
#   'job': 'self-employed',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 137,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 246,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3b1'),
#   'age': 51,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 173,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 529,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3b3'),
#   'age': 41,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 1270,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 1389,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'yes'},
#  {'_id': ObjectId('66c561a994610b691202b3b4'),
#   'age': 46,
#   'job': 'management',
#   'marital': 'divorced',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 16,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 188,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3b5'),
#   'age': 57,
#   'job': 'retired',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 486,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 180,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3b7'),
#   'age': 30,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 152,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 213,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3b8'),
#   'age': 60,
#   'job': 'admin.',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 290,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 583,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3b9'),
#   'age': 60,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 54,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 221,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3bb'),
#   'age': 36,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 101,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 426,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3bd'),
#   'age': 60,
#   'job': 'retired',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 81,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 101,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3be'),
#   'age': 39,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 203,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3bf'),
#   'age': 46,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 229,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 197,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3c0'),
#   'age': 44,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': -674,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 257,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3c2'),
#   'age': 52,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 128,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 229,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3c3'),
#   'age': 59,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 179,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 55,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3c4'),
#   'age': 27,
#   'job': 'technician',
#   'marital': 'single',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 400,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3c5'),
#   'age': 44,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 54,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 197,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3c6'),
#   'age': 47,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 151,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 190,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3c8'),
#   'age': 59,
#   'job': 'retired',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 30,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 514,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3c9'),
#   'age': 45,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 523,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 849,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3ca'),
#   'age': 29,
#   'job': 'services',
#   'marital': 'divorced',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 31,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 194,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3cc'),
#   'age': 56,
#   'job': 'self-employed',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': -34,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 212,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3cd'),
#   'age': 36,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 448,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 286,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3ce'),
#   'age': 59,
#   'job': 'retired',
#   'marital': 'divorced',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 81,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 107,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3cf'),
#   'age': 44,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 144,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 247,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3d0'),
#   'age': 41,
#   'job': 'admin.',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 351,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 518,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3d1'),
#   'age': 33,
#   'job': 'management',
#   'marital': 'single',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': -67,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 364,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3d4'),
#   'age': 56,
#   'job': 'technician',
#   'marital': 'divorced',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 56,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 439,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3d5'),
#   'age': 51,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 26,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 79,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3d6'),
#   'age': 34,
#   'job': 'admin.',
#   'marital': 'married',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 3,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 120,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3d7'),
#   'age': 43,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 41,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 127,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3d9'),
#   'age': 33,
#   'job': 'technician',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 105,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 262,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3da'),
#   'age': 29,
#   'job': 'admin.',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 818,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 61,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3db'),
#   'age': 34,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': -16,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 78,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3dc'),
#   'age': 31,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 143,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3dd'),
#   'age': 55,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 2476,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 579,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'yes'},
#  {'_id': ObjectId('66c561a994610b691202b3df'),
#   'age': 32,
#   'job': 'admin.',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 217,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 345,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3e0'),
#   'age': 38,
#   'job': 'technician',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 1685,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 185,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3e1'),
#   'age': 55,
#   'job': 'admin.',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 802,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 100,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3e2'),
#   'age': 28,
#   'job': 'unemployed',
#   'marital': 'single',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 125,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3e3'),
#   'age': 23,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 94,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 193,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3e4'),
#   'age': 32,
#   'job': 'technician',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 136,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3e6'),
#   'age': 32,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 517,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 528,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3e7'),
#   'age': 46,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 265,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 541,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3e8'),
#   'age': 53,
#   'job': 'housemaid',
#   'marital': 'divorced',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 947,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 163,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3e9'),
#   'age': 34,
#   'job': 'self-employed',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 3,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 301,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3eb'),
#   'age': 37,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 37,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 204,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3ec'),
#   'age': 59,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 57,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 98,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3ed'),
#   'age': 33,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 22,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 71,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3ee'),
#   'age': 56,
#   'job': 'blue-collar',
#   'marital': 'divorced',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 8,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 157,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3ef'),
#   'age': 48,
#   'job': 'unemployed',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 293,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 243,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3f0'),
#   'age': 43,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 3,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 186,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3f1'),
#   'age': 54,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 348,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 579,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3f2'),
#   'age': 51,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': -19,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 163,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3f3'),
#   'age': 26,
#   'job': 'student',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
#   'month': 'may',
#   'duration': 610,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b3f4'),
#   'age': 40,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': -4,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 5,
# ...
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 212,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b798'),
#   'age': 34,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 615,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 225,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b799'),
#   'age': 35,
#   'job': 'admin.',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 136,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 283,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b79a'),
#   'age': 44,
#   'job': 'blue-collar',
#   'marital': 'single',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 2167,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 1273,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b79b'),
#   'age': 30,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 309,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 1574,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'yes'},
#  {'_id': ObjectId('66c561a994610b691202b79c'),
#   'age': 51,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 221,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 139,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b79d'),
#   'age': 37,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 321,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 228,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b79e'),
#   'age': 39,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': -33,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 62,
#   'campaign': 5,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b79f'),
#   'age': 33,
#   'job': 'management',
#   'marital': 'single',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 76,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 256,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7a0'),
#   'age': 37,
#   'job': 'management',
#   'marital': 'divorced',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 42,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 564,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7a1'),
#   'age': 46,
#   'job': 'blue-collar',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 76,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 245,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7a2'),
#   'age': 32,
#   'job': 'admin.',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 1293,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 161,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7a3'),
#   'age': 43,
#   'job': 'entrepreneur',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 526,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 79,
#   'campaign': 4,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7a4'),
#   'age': 59,
#   'job': 'housemaid',
#   'marital': 'divorced',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 873,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 152,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7a5'),
#   'age': 46,
#   'job': 'admin.',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 40,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 591,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7a6'),
#   'age': 47,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 117,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 113,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7a7'),
#   'age': 31,
#   'job': 'services',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 671,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 193,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7a8'),
#   'age': 30,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 145,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 299,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7aa'),
#   'age': 44,
#   'job': 'blue-collar',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': -212,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 103,
#   'campaign': 4,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7ab'),
#   'age': 52,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 133,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 253,
#   'campaign': 8,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7ad'),
#   'age': 43,
#   'job': 'admin.',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 1924,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 244,
#   'campaign': 7,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7ae'),
#   'age': 47,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 145,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 157,
#   'campaign': 6,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7af'),
#   'age': 43,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 487,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 548,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7b0'),
#   'age': 52,
#   'job': 'blue-collar',
#   'marital': 'divorced',
#   'education': 'primary',
#   'default': 'no',
#   'balance': -57,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 114,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7b1'),
#   'age': 32,
#   'job': 'services',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 81,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 126,
#   'campaign': 5,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7b2'),
#   'age': 40,
#   'job': 'admin.',
#   'marital': 'single',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': -227,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 161,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7b3'),
#   'age': 57,
#   'job': 'technician',
#   'marital': 'divorced',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 2710,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 333,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7b4'),
#   'age': 30,
#   'job': 'services',
#   'marital': 'divorced',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 98,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 155,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7b5'),
#   'age': 48,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 1230,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 152,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7b6'),
#   'age': 46,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 78,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 145,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7b7'),
#   'age': 59,
#   'job': 'retired',
#   'marital': 'divorced',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 137,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 66,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7b8'),
#   'age': 50,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'yes',
#   'balance': 354,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 123,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7b9'),
#   'age': 50,
#   'job': 'blue-collar',
#   'marital': 'divorced',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 149,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 74,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7ba'),
#   'age': 33,
#   'job': 'blue-collar',
#   'marital': 'divorced',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 126,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 248,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7bb'),
#   'age': 39,
#   'job': 'technician',
#   'marital': 'single',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 0,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 130,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7bc'),
#   'age': 57,
#   'job': 'retired',
#   'marital': 'divorced',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 8266,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 71,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7bd'),
#   'age': 49,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'unknown',
#   'default': 'no',
#   'balance': 51,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 984,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7be'),
#   'age': 41,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 258,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 252,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7bf'),
#   'age': 43,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 117,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 84,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7c0'),
#   'age': 29,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 199,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 1689,
#   'campaign': 4,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'yes'},
#  {'_id': ObjectId('66c561a994610b691202b7c1'),
#   'age': 56,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 219,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 130,
#   'campaign': 4,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7c2'),
#   'age': 46,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 1571,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 489,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7c3'),
#   'age': 42,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 223,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 41,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'_id': ObjectId('66c561a994610b691202b7c5'),
#   'age': 29,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 321,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'unknown',
#   'day': 7,
#   'month': 'may',
#   'duration': 196,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  ...]

# %% [markdown]
# ## 3.8 Find Records with High Account Balance

# %%
# ??

# list(db.customer.find({'housing': 'yes'}))
list(
    db.customer.aggregate([
        {'$sort': {'balance':-1}},
        {'$project': {'_id':1, 'age':1, 'job':1, 'balance':1}},
        {'$limit': 10}
    ])
)
# Out:
# [{'_id': ObjectId('66c561aa94610b6912034f91'),
#   'age': 51,
#   'job': 'management',
#   'balance': 102127},
#  {'_id': ObjectId('66c561a994610b69120319cf'),
#   'age': 59,
#   'job': 'management',
#   'balance': 98417},
#  {'_id': ObjectId('66c561aa94610b6912035cdd'),
#   'age': 84,
#   'job': 'retired',
#   'balance': 81204},
#  {'_id': ObjectId('66c561aa94610b691203599a'),
#   'age': 84,
#   'job': 'retired',
#   'balance': 81204},
#  {'_id': ObjectId('66c561aa94610b6912035639'),
#   'age': 60,
#   'job': 'retired',
#   'balance': 71188},
#  {'_id': ObjectId('66c561a994610b69120300a5'),
#   'age': 56,
#   'job': 'management',
#   'balance': 66721},
#  {'_id': ObjectId('66c561a994610b6912030624'),
#   'age': 52,
#   'job': 'blue-collar',
#   'balance': 66653},
#  {'_id': ObjectId('66c561a994610b691202ff38'),
#   'age': 59,
#   'job': 'admin.',
#   'balance': 64343},
#  {'_id': ObjectId('66c561aa94610b69120354fa'),
#   'age': 32,
#   'job': 'entrepreneur',
#   'balance': 59649},
#  {'_id': ObjectId('66c561a994610b691202e5da'),
#   'age': 56,
#   'job': 'blue-collar',
#   'balance': 58932}]

# %% [markdown]
# ## 3.9 Count Records by Job Type

# %%
list(
    collection.aggregate([
      {'$group': {'_id': '$job', 'count': {'$sum': 1}}},
      {'$sort': {'count':-1}}
    ]) 
)
# Out:
# [{'_id': 'blue-collar', 'count': 9732},
#  {'_id': 'management', 'count': 9458},
#  {'_id': 'technician', 'count': 7597},
#  {'_id': 'admin.', 'count': 5171},
#  {'_id': 'services', 'count': 4154},
#  {'_id': 'retired', 'count': 2264},
#  {'_id': 'self-employed', 'count': 1579},
#  {'_id': 'entrepreneur', 'count': 1487},
#  {'_id': 'unemployed', 'count': 1303},
#  {'_id': 'housemaid', 'count': 1240},
#  {'_id': 'student', 'count': 938},
#  {'_id': 'unknown', 'count': 288}]

# %% [markdown]
# ## 3.10 Count Married Individuals with Secondary Education

# %%
list(
    db.customer.aggregate([
      {'$match': {'education': 'secondary', 'marital': 'married'}},
      {'$group': {'_id': {'marital':'married', 'education': 'secondary'}, 'count': {'$sum': 1}}},
      {'$sort': {'count':-1}}
    ])
)
# Out:
# [{'_id': {'marital': 'married', 'education': 'secondary'}, 'count': 13770}]

# %% [markdown]
# ## 3.11 Calculate the Average Balance for Each Job Type

# %%
list(
    collections.aggregate([
        
    ])
)

# %% [markdown]
# ## 3.12 Find the Most Common Education Level Among Those with Loans

# %%
list(
    collection.aggregate([
      {'$match': {'loan': 'yes'}},
      {'$group': {'_id': '$education', 'count': {'$sum': 1}}},
      {'$sort': {'count':-1}},
      {'$limit': 1}
    ])
)

# %% [markdown]
# ## 3.13 Find Individuals with Multiple Campaign Contacts

# %%
len(list(
    collection.find({'campaign': {'$gt': 1}})
))
# Out:
# 27667

# %% [markdown]
# ## 3.14 [DUPLICATE] Determine success rate of campaign

# %% [markdown]
# ## 3.15 Identify Anomalies in Account Balances

# %%
db.customer.aggregate([
    {'$group': {'_id':null, 
                'avgBalance':{'$balance'}, 
                'stdDevBalance': {'$stdDevSamp': '$balance'}},
    '$lookup': {'from':'customers',
               'pipeline': [{
                   '$project': {}
               }]}
    },
])

# %% [markdown]
# ## 3.16 Analyze Seasonal Patterns
# ###### seasonality is something that happens in a particular interval
# ###### eg: demand of umbrella raises every monsoon season, a pandemic happens every 100 years

# %%
list(
    db.customer.aggregate([
        {'$group': {'_id':'$month', 'averageDuration':{'$avg':'$duration'}, 'totalCalls':{'$sum':1}}},
        {'$sort': {'totalCalls':-1, 'averageDuration':-1}}
    ])
)
# Out:
# [{'_id': 'may', 'averageDuration': 260.92227226500074, 'totalCalls': 13766},
#  {'_id': 'jul', 'averageDuration': 267.9753444525018, 'totalCalls': 6895},
#  {'_id': 'aug', 'averageDuration': 232.40211301424685, 'totalCalls': 6247},
#  {'_id': 'jun', 'averageDuration': 243.0878112712975, 'totalCalls': 5341},
#  {'_id': 'nov', 'averageDuration': 253.14861460957178, 'totalCalls': 3970},
#  {'_id': 'apr', 'averageDuration': 298.09890859481584, 'totalCalls': 2932},
#  {'_id': 'feb', 'averageDuration': 248.29822574556437, 'totalCalls': 2649},
#  {'_id': 'jan', 'averageDuration': 268.2202423378475, 'totalCalls': 1403},
#  {'_id': 'oct', 'averageDuration': 288.30216802168025, 'totalCalls': 738},
#  {'_id': 'sep', 'averageDuration': 292.25215889464596, 'totalCalls': 579},
#  {'_id': 'mar', 'averageDuration': 244.40041928721175, 'totalCalls': 477},
#  {'_id': 'dec', 'averageDuration': 329.32710280373834, 'totalCalls': 214}]

# %% [markdown]
# ## 3.17 Determine Correlation Between Loan Status and Balance

# %%
list(
    db.customer.aggregate([
        {'$group': {'_id':'$loan', 'avgBalance':{'$avg':'$balance'}, 'count':{'$sum':1}}}
    ])
)
# Out:
# [{'_id': 'no', 'avgBalance': 1474.4536307846288, 'count': 37967},
#  {'_id': 'yes', 'avgBalance': 774.3099116510215, 'count': 7244}]

# %% [markdown]
# ## 3.18 Identify the Most Common Day for Successful Campaigns

# %%
list(
    db.customer.aggregate([
        {'$match': {'y': 'yes'}},
        {'$group': {'_id': '$day', 'count':{'$sum':1}}},
        {'$sort': {'count': -1}},
        {'$limit': 3}
    ])
)
# Out:
# [{'_id': 30, 'count': 271},
#  {'_id': 12, 'count': 244},
#  {'_id': 13, 'count': 241}]

# %% [markdown]
# ## 3.19 Find the Youngest Person with the Highest Account Balance

# %%
# below both methods are working correctly

list(
    # db.customer.aggregate([
    #     {'$sort': {'age':1, 'balance':-1}},
    #     {'$limit': 1}
    # ])
    
    db.customer.find().sort({'age':1, 'balance':-1}).limit(1)
)
# Out:
# [{'_id': ObjectId('66c561aa94610b691203527c'),
#   'age': 18,
#   'job': 'student',
#   'marital': 'single',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 1944,
#   'housing': 'no',
#   'loan': 'no',
#   'contact': 'telephone',
#   'day': 10,
#   'month': 'aug',
#   'duration': 122,
#   'campaign': 3,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'}]

# %% [markdown]
# ## 3.20 Identify Customers with Consistently Low Balances

# %%
list(
    db.customer.aggregate([
        {'$match': {'balance': {'$lte':100}}},
        {'$project': {'_id':1, 'age':1, 'balance':1}}
    ])
)
# Out:
# [{'_id': ObjectId('66c561a994610b691202b35d'), 'age': 44, 'balance': 29},
#  {'_id': ObjectId('66c561a994610b691202b35e'), 'age': 33, 'balance': 2},
#  {'_id': ObjectId('66c561a994610b691202b360'), 'age': 33, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b363'), 'age': 42, 'balance': 2},
#  {'_id': ObjectId('66c561a994610b691202b368'), 'age': 53, 'balance': 6},
#  {'_id': ObjectId('66c561a994610b691202b369'), 'age': 58, 'balance': 71},
#  {'_id': ObjectId('66c561a994610b691202b36c'), 'age': 45, 'balance': 13},
#  {'_id': ObjectId('66c561a994610b691202b36d'), 'age': 57, 'balance': 52},
#  {'_id': ObjectId('66c561a994610b691202b36e'), 'age': 60, 'balance': 60},
#  {'_id': ObjectId('66c561a994610b691202b36f'), 'age': 33, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b372'), 'age': 32, 'balance': 23},
#  {'_id': ObjectId('66c561a994610b691202b373'), 'age': 25, 'balance': 50},
#  {'_id': ObjectId('66c561a994610b691202b374'), 'age': 40, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b375'), 'age': 44, 'balance': -372},
#  {'_id': ObjectId('66c561a994610b691202b378'), 'age': 46, 'balance': -246},
#  {'_id': ObjectId('66c561a994610b691202b37c'), 'age': 60, 'balance': 39},
#  {'_id': ObjectId('66c561a994610b691202b37d'), 'age': 59, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b37f'), 'age': 57, 'balance': 63},
#  {'_id': ObjectId('66c561a994610b691202b380'), 'age': 25, 'balance': -7},
#  {'_id': ObjectId('66c561a994610b691202b381'), 'age': 53, 'balance': -3},
#  {'_id': ObjectId('66c561a994610b691202b383'), 'age': 37, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b385'), 'age': 50, 'balance': 49},
#  {'_id': ObjectId('66c561a994610b691202b388'), 'age': 58, 'balance': 96},
#  {'_id': ObjectId('66c561a994610b691202b389'), 'age': 36, 'balance': -171},
#  {'_id': ObjectId('66c561a994610b691202b38a'), 'age': 58, 'balance': -364},
#  {'_id': ObjectId('66c561a994610b691202b38b'), 'age': 44, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b38c'), 'age': 55, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b38d'), 'age': 29, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b38f'), 'age': 48, 'balance': -244},
#  {'_id': ObjectId('66c561a994610b691202b390'), 'age': 32, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b391'), 'age': 42, 'balance': -76},
#  {'_id': ObjectId('66c561a994610b691202b392'), 'age': 24, 'balance': -103},
#  {'_id': ObjectId('66c561a994610b691202b396'), 'age': 40, 'balance': 24},
#  {'_id': ObjectId('66c561a994610b691202b398'), 'age': 32, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b39e'), 'age': 60, 'balance': 100},
#  {'_id': ObjectId('66c561a994610b691202b39f'), 'age': 59, 'balance': 59},
#  {'_id': ObjectId('66c561a994610b691202b3a3'), 'age': 31, 'balance': 25},
#  {'_id': ObjectId('66c561a994610b691202b3a5'), 'age': 55, 'balance': 23},
#  {'_id': ObjectId('66c561a994610b691202b3a9'), 'age': 55, 'balance': 91},
#  {'_id': ObjectId('66c561a994610b691202b3aa'), 'age': 49, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b3ab'), 'age': 55, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b3b2'), 'age': 56, 'balance': 45},
#  {'_id': ObjectId('66c561a994610b691202b3b4'), 'age': 46, 'balance': 16},
#  {'_id': ObjectId('66c561a994610b691202b3b6'), 'age': 42, 'balance': 50},
#  {'_id': ObjectId('66c561a994610b691202b3b9'), 'age': 60, 'balance': 54},
#  {'_id': ObjectId('66c561a994610b691202b3ba'), 'age': 57, 'balance': -37},
#  {'_id': ObjectId('66c561a994610b691202b3bd'), 'age': 60, 'balance': 81},
#  {'_id': ObjectId('66c561a994610b691202b3be'), 'age': 39, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b3c0'), 'age': 44, 'balance': -674},
#  {'_id': ObjectId('66c561a994610b691202b3c1'), 'age': 53, 'balance': 90},
#  {'_id': ObjectId('66c561a994610b691202b3c4'), 'age': 27, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b3c5'), 'age': 44, 'balance': 54},
#  {'_id': ObjectId('66c561a994610b691202b3c7'), 'age': 34, 'balance': 61},
#  {'_id': ObjectId('66c561a994610b691202b3c8'), 'age': 59, 'balance': 30},
#  {'_id': ObjectId('66c561a994610b691202b3ca'), 'age': 29, 'balance': 31},
#  {'_id': ObjectId('66c561a994610b691202b3cb'), 'age': 46, 'balance': 79},
#  {'_id': ObjectId('66c561a994610b691202b3cc'), 'age': 56, 'balance': -34},
#  {'_id': ObjectId('66c561a994610b691202b3ce'), 'age': 59, 'balance': 81},
#  {'_id': ObjectId('66c561a994610b691202b3d1'), 'age': 33, 'balance': -67},
#  {'_id': ObjectId('66c561a994610b691202b3d3'), 'age': 57, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b3d4'), 'age': 56, 'balance': 56},
#  {'_id': ObjectId('66c561a994610b691202b3d5'), 'age': 51, 'balance': 26},
#  {'_id': ObjectId('66c561a994610b691202b3d6'), 'age': 34, 'balance': 3},
#  {'_id': ObjectId('66c561a994610b691202b3d7'), 'age': 43, 'balance': 41},
#  {'_id': ObjectId('66c561a994610b691202b3d8'), 'age': 52, 'balance': 7},
#  {'_id': ObjectId('66c561a994610b691202b3db'), 'age': 34, 'balance': -16},
#  {'_id': ObjectId('66c561a994610b691202b3dc'), 'age': 31, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b3e2'), 'age': 28, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b3e3'), 'age': 23, 'balance': 94},
#  {'_id': ObjectId('66c561a994610b691202b3e4'), 'age': 32, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b3e5'), 'age': 43, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b3e9'), 'age': 34, 'balance': 3},
#  {'_id': ObjectId('66c561a994610b691202b3ea'), 'age': 57, 'balance': 42},
#  {'_id': ObjectId('66c561a994610b691202b3eb'), 'age': 37, 'balance': 37},
#  {'_id': ObjectId('66c561a994610b691202b3ec'), 'age': 59, 'balance': 57},
#  {'_id': ObjectId('66c561a994610b691202b3ed'), 'age': 33, 'balance': 22},
#  {'_id': ObjectId('66c561a994610b691202b3ee'), 'age': 56, 'balance': 8},
#  {'_id': ObjectId('66c561a994610b691202b3f0'), 'age': 43, 'balance': 3},
#  {'_id': ObjectId('66c561a994610b691202b3f2'), 'age': 51, 'balance': -19},
#  {'_id': ObjectId('66c561a994610b691202b3f3'), 'age': 26, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b3f4'), 'age': 40, 'balance': -4},
#  {'_id': ObjectId('66c561a994610b691202b3f5'), 'age': 39, 'balance': 18},
#  {'_id': ObjectId('66c561a994610b691202b3f7'), 'age': 41, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b3fd'), 'age': 39, 'balance': 47},
#  {'_id': ObjectId('66c561a994610b691202b400'), 'age': 45, 'balance': 86},
#  {'_id': ObjectId('66c561a994610b691202b401'), 'age': 26, 'balance': 82},
#  {'_id': ObjectId('66c561a994610b691202b405'), 'age': 50, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b406'), 'age': 35, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b408'), 'age': 53, 'balance': 19},
#  {'_id': ObjectId('66c561a994610b691202b40a'), 'age': 60, 'balance': 92},
#  {'_id': ObjectId('66c561a994610b691202b40c'), 'age': 48, 'balance': 41},
#  {'_id': ObjectId('66c561a994610b691202b40d'), 'age': 34, 'balance': 51},
#  {'_id': ObjectId('66c561a994610b691202b410'), 'age': 31, 'balance': 37},
#  {'_id': ObjectId('66c561a994610b691202b412'), 'age': 35, 'balance': 59},
#  {'_id': ObjectId('66c561a994610b691202b418'), 'age': 34, 'balance': 53},
#  {'_id': ObjectId('66c561a994610b691202b419'), 'age': 31, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b41c'), 'age': 55, 'balance': 73},
#  {'_id': ObjectId('66c561a994610b691202b425'), 'age': 48, 'balance': 7},
#  {'_id': ObjectId('66c561a994610b691202b428'), 'age': 35, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b42d'), 'age': 42, 'balance': 56},
#  {'_id': ObjectId('66c561a994610b691202b42e'), 'age': 38, 'balance': -390},
#  {'_id': ObjectId('66c561a994610b691202b432'), 'age': 54, 'balance': -41},
#  {'_id': ObjectId('66c561a994610b691202b434'), 'age': 47, 'balance': 28},
#  {'_id': ObjectId('66c561a994610b691202b435'), 'age': 53, 'balance': 13},
#  {'_id': ObjectId('66c561a994610b691202b43a'), 'age': 35, 'balance': -69},
#  {'_id': ObjectId('66c561a994610b691202b43b'), 'age': 55, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b43f'), 'age': 33, 'balance': 34},
#  {'_id': ObjectId('66c561a994610b691202b442'), 'age': 47, 'balance': -12},
#  {'_id': ObjectId('66c561a994610b691202b447'), 'age': 45, 'balance': 25},
#  {'_id': ObjectId('66c561a994610b691202b449'), 'age': 37, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b44a'), 'age': 44, 'balance': 66},
#  {'_id': ObjectId('66c561a994610b691202b44b'), 'age': 49, 'balance': -9},
#  {'_id': ObjectId('66c561a994610b691202b44d'), 'age': 43, 'balance': 100},
#  {'_id': ObjectId('66c561a994610b691202b44e'), 'age': 38, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b452'), 'age': 22, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b457'), 'age': 53, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b458'), 'age': 34, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b460'), 'age': 53, 'balance': 70},
#  {'_id': ObjectId('66c561a994610b691202b465'), 'age': 30, 'balance': 25},
#  {'_id': ObjectId('66c561a994610b691202b467'), 'age': 39, 'balance': -349},
#  {'_id': ObjectId('66c561a994610b691202b469'), 'age': 40, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b46a'), 'age': 42, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b46b'), 'age': 40, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b470'), 'age': 39, 'balance': -185},
#  {'_id': ObjectId('66c561a994610b691202b471'), 'age': 49, 'balance': 47},
#  {'_id': ObjectId('66c561a994610b691202b473'), 'age': 36, 'balance': 19},
#  {'_id': ObjectId('66c561a994610b691202b474'), 'age': 50, 'balance': 61},
#  {'_id': ObjectId('66c561a994610b691202b475'), 'age': 41, 'balance': -62},
#  {'_id': ObjectId('66c561a994610b691202b477'), 'age': 58, 'balance': 76},
#  {'_id': ObjectId('66c561a994610b691202b478'), 'age': 30, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b47e'), 'age': 37, 'balance': 58},
#  {'_id': ObjectId('66c561a994610b691202b481'), 'age': 54, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b482'), 'age': 34, 'balance': 19},
#  {'_id': ObjectId('66c561a994610b691202b483'), 'age': 56, 'balance': 13},
#  {'_id': ObjectId('66c561a994610b691202b484'), 'age': 31, 'balance': 3},
#  {'_id': ObjectId('66c561a994610b691202b485'), 'age': 24, 'balance': 82},
#  {'_id': ObjectId('66c561a994610b691202b486'), 'age': 42, 'balance': 28},
#  {'_id': ObjectId('66c561a994610b691202b48b'), 'age': 36, 'balance': 62},
#  {'_id': ObjectId('66c561a994610b691202b48f'), 'age': 55, 'balance': 89},
#  {'_id': ObjectId('66c561a994610b691202b491'), 'age': 43, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b494'), 'age': 55, 'balance': 96},
#  {'_id': ObjectId('66c561a994610b691202b497'), 'age': 46, 'balance': -358},
#  {'_id': ObjectId('66c561a994610b691202b499'), 'age': 51, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b49a'), 'age': 40, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b49c'), 'age': 51, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b4a0'), 'age': 31, 'balance': 98},
#  {'_id': ObjectId('66c561a994610b691202b4a6'), 'age': 48, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b4a7'), 'age': 42, 'balance': 57},
#  {'_id': ObjectId('66c561a994610b691202b4a8'), 'age': 30, 'balance': -457},
#  {'_id': ObjectId('66c561a994610b691202b4ab'), 'age': 49, 'balance': 30},
#  {'_id': ObjectId('66c561a994610b691202b4ad'), 'age': 53, 'balance': 56},
#  {'_id': ObjectId('66c561a994610b691202b4ae'), 'age': 51, 'balance': -2},
#  {'_id': ObjectId('66c561a994610b691202b4b2'), 'age': 40, 'balance': -333},
#  {'_id': ObjectId('66c561a994610b691202b4b4'), 'age': 34, 'balance': 46},
#  {'_id': ObjectId('66c561a994610b691202b4b5'), 'age': 53, 'balance': 18},
#  {'_id': ObjectId('66c561a994610b691202b4b6'), 'age': 45, 'balance': 44},
#  {'_id': ObjectId('66c561a994610b691202b4b7'), 'age': 39, 'balance': -100},
#  {'_id': ObjectId('66c561a994610b691202b4bb'), 'age': 45, 'balance': 66},
#  {'_id': ObjectId('66c561a994610b691202b4bd'), 'age': 36, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b4be'), 'age': 59, 'balance': 27},
#  {'_id': ObjectId('66c561a994610b691202b4bf'), 'age': 31, 'balance': 12},
#  {'_id': ObjectId('66c561a994610b691202b4c0'), 'age': 44, 'balance': 34},
#  {'_id': ObjectId('66c561a994610b691202b4c6'), 'age': 27, 'balance': 8},
#  {'_id': ObjectId('66c561a994610b691202b4cb'), 'age': 43, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b4cc'), 'age': 38, 'balance': 86},
#  {'_id': ObjectId('66c561a994610b691202b4ce'), 'age': 34, 'balance': 22},
#  {'_id': ObjectId('66c561a994610b691202b4cf'), 'age': 38, 'balance': 46},
#  {'_id': ObjectId('66c561a994610b691202b4d5'), 'age': 43, 'balance': 98},
#  {'_id': ObjectId('66c561a994610b691202b4d6'), 'age': 33, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b4dc'), 'age': 38, 'balance': 20},
#  {'_id': ObjectId('66c561a994610b691202b4df'), 'age': 32, 'balance': 10},
#  {'_id': ObjectId('66c561a994610b691202b4e1'), 'age': 58, 'balance': 29},
#  {'_id': ObjectId('66c561a994610b691202b4e5'), 'age': 27, 'balance': 4},
#  {'_id': ObjectId('66c561a994610b691202b4e7'), 'age': 32, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b4e9'), 'age': 38, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b4ec'), 'age': 42, 'balance': 17},
#  {'_id': ObjectId('66c561a994610b691202b4ee'), 'age': 29, 'balance': 16},
#  {'_id': ObjectId('66c561a994610b691202b4f0'), 'age': 52, 'balance': 7},
#  {'_id': ObjectId('66c561a994610b691202b4f1'), 'age': 50, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b4f2'), 'age': 58, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b4f8'), 'age': 39, 'balance': -25},
#  {'_id': ObjectId('66c561a994610b691202b4fb'), 'age': 34, 'balance': 67},
#  {'_id': ObjectId('66c561a994610b691202b4fc'), 'age': 40, 'balance': 77},
#  {'_id': ObjectId('66c561a994610b691202b4fd'), 'age': 43, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b4fe'), 'age': 52, 'balance': 55},
#  {'_id': ObjectId('66c561a994610b691202b4ff'), 'age': 33, 'balance': 72},
#  {'_id': ObjectId('66c561a994610b691202b503'), 'age': 40, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b504'), 'age': 38, 'balance': 9},
#  {'_id': ObjectId('66c561a994610b691202b50c'), 'age': 39, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b50d'), 'age': 40, 'balance': 46},
#  {'_id': ObjectId('66c561a994610b691202b510'), 'age': 45, 'balance': 39},
#  {'_id': ObjectId('66c561a994610b691202b514'), 'age': 49, 'balance': 61},
#  {'_id': ObjectId('66c561a994610b691202b517'), 'age': 24, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b51b'), 'age': 50, 'balance': -84},
#  {'_id': ObjectId('66c561a994610b691202b51f'), 'age': 40, 'balance': 71},
#  {'_id': ObjectId('66c561a994610b691202b520'), 'age': 46, 'balance': 2},
#  {'_id': ObjectId('66c561a994610b691202b524'), 'age': 40, 'balance': -109},
#  {'_id': ObjectId('66c561a994610b691202b525'), 'age': 37, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b526'), 'age': 33, 'balance': -60},
#  {'_id': ObjectId('66c561a994610b691202b527'), 'age': 35, 'balance': 89},
#  {'_id': ObjectId('66c561a994610b691202b528'), 'age': 58, 'balance': -11},
#  {'_id': ObjectId('66c561a994610b691202b529'), 'age': 39, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b52a'), 'age': 43, 'balance': -509},
#  {'_id': ObjectId('66c561a994610b691202b52c'), 'age': 36, 'balance': 58},
#  {'_id': ObjectId('66c561a994610b691202b52e'), 'age': 36, 'balance': 20},
#  {'_id': ObjectId('66c561a994610b691202b52f'), 'age': 50, 'balance': 71},
#  {'_id': ObjectId('66c561a994610b691202b530'), 'age': 55, 'balance': 52},
#  {'_id': ObjectId('66c561a994610b691202b53f'), 'age': 43, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b541'), 'age': 54, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b543'), 'age': 59, 'balance': -76},
#  {'_id': ObjectId('66c561a994610b691202b545'), 'age': 40, 'balance': -66},
#  {'_id': ObjectId('66c561a994610b691202b546'), 'age': 32, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b547'), 'age': 29, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b548'), 'age': 36, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b54a'), 'age': 30, 'balance': -209},
#  {'_id': ObjectId('66c561a994610b691202b54b'), 'age': 39, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b54c'), 'age': 39, 'balance': 42},
#  {'_id': ObjectId('66c561a994610b691202b54d'), 'age': 50, 'balance': 41},
#  {'_id': ObjectId('66c561a994610b691202b54e'), 'age': 44, 'balance': -99},
#  {'_id': ObjectId('66c561a994610b691202b54f'), 'age': 37, 'balance': 17},
#  {'_id': ObjectId('66c561a994610b691202b551'), 'age': 32, 'balance': -170},
#  {'_id': ObjectId('66c561a994610b691202b553'), 'age': 29, 'balance': 9},
#  {'_id': ObjectId('66c561a994610b691202b556'), 'age': 57, 'balance': -331},
#  {'_id': ObjectId('66c561a994610b691202b557'), 'age': 48, 'balance': 44},
#  {'_id': ObjectId('66c561a994610b691202b558'), 'age': 60, 'balance': 15},
#  {'_id': ObjectId('66c561a994610b691202b55d'), 'age': 41, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b560'), 'age': 44, 'balance': 40},
#  {'_id': ObjectId('66c561a994610b691202b562'), 'age': 31, 'balance': 17},
#  {'_id': ObjectId('66c561a994610b691202b567'), 'age': 29, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b56d'), 'age': 30, 'balance': 83},
#  {'_id': ObjectId('66c561a994610b691202b575'), 'age': 45, 'balance': -66},
#  {'_id': ObjectId('66c561a994610b691202b577'), 'age': 34, 'balance': -144},
#  {'_id': ObjectId('66c561a994610b691202b578'), 'age': 46, 'balance': 71},
#  {'_id': ObjectId('66c561a994610b691202b57b'), 'age': 34, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b57c'), 'age': 40, 'balance': 11},
#  {'_id': ObjectId('66c561a994610b691202b57f'), 'age': 45, 'balance': 82},
#  {'_id': ObjectId('66c561a994610b691202b583'), 'age': 30, 'balance': 46},
#  {'_id': ObjectId('66c561a994610b691202b584'), 'age': 30, 'balance': 34},
#  {'_id': ObjectId('66c561a994610b691202b586'), 'age': 33, 'balance': -10},
#  {'_id': ObjectId('66c561a994610b691202b587'), 'age': 36, 'balance': -106},
#  {'_id': ObjectId('66c561a994610b691202b58f'), 'age': 47, 'balance': 83},
#  {'_id': ObjectId('66c561a994610b691202b590'), 'age': 59, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b593'), 'age': 46, 'balance': -125},
#  {'_id': ObjectId('66c561a994610b691202b594'), 'age': 34, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b598'), 'age': 41, 'balance': -137},
#  {'_id': ObjectId('66c561a994610b691202b599'), 'age': 52, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b59d'), 'age': 47, 'balance': 19},
#  {'_id': ObjectId('66c561a994610b691202b59e'), 'age': 53, 'balance': 25},
#  {'_id': ObjectId('66c561a994610b691202b5a1'), 'age': 56, 'balance': 99},
#  {'_id': ObjectId('66c561a994610b691202b5a3'), 'age': 44, 'balance': 17},
#  {'_id': ObjectId('66c561a994610b691202b5a4'), 'age': 37, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b5a5'), 'age': 35, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b5a8'), 'age': 30, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b5a9'), 'age': 37, 'balance': -325},
#  {'_id': ObjectId('66c561a994610b691202b5aa'), 'age': 36, 'balance': -15},
#  {'_id': ObjectId('66c561a994610b691202b5ad'), 'age': 48, 'balance': 74},
#  {'_id': ObjectId('66c561a994610b691202b5af'), 'age': 28, 'balance': 89},
#  {'_id': ObjectId('66c561a994610b691202b5b0'), 'age': 54, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b5b3'), 'age': 31, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b5b6'), 'age': 37, 'balance': -118},
#  {'_id': ObjectId('66c561a994610b691202b5b7'), 'age': 56, 'balance': 5},
#  {'_id': ObjectId('66c561a994610b691202b5b8'), 'age': 51, 'balance': 50},
#  {'_id': ObjectId('66c561a994610b691202b5ba'), 'age': 49, 'balance': 15},
#  {'_id': ObjectId('66c561a994610b691202b5c4'), 'age': 31, 'balance': 60},
#  {'_id': ObjectId('66c561a994610b691202b5c7'), 'age': 40, 'balance': -5},
#  {'_id': ObjectId('66c561a994610b691202b5c9'), 'age': 33, 'balance': 7},
#  {'_id': ObjectId('66c561a994610b691202b5cb'), 'age': 59, 'balance': -119},
#  {'_id': ObjectId('66c561a994610b691202b5cf'), 'age': 54, 'balance': 21},
#  {'_id': ObjectId('66c561a994610b691202b5d1'), 'age': 32, 'balance': 90},
#  {'_id': ObjectId('66c561a994610b691202b5d4'), 'age': 42, 'balance': 15},
#  {'_id': ObjectId('66c561a994610b691202b5d5'), 'age': 33, 'balance': 85},
#  {'_id': ObjectId('66c561a994610b691202b5d6'), 'age': 52, 'balance': -184},
#  {'_id': ObjectId('66c561a994610b691202b5d8'), 'age': 52, 'balance': -183},
#  {'_id': ObjectId('66c561a994610b691202b5da'), 'age': 44, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b5db'), 'age': 35, 'balance': 69},
#  {'_id': ObjectId('66c561a994610b691202b5df'), 'age': 42, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b5e0'), 'age': 43, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b5e4'), 'age': 41, 'balance': 65},
#  {'_id': ObjectId('66c561a994610b691202b5e5'), 'age': 41, 'balance': -366},
#  {'_id': ObjectId('66c561a994610b691202b5e8'), 'age': 44, 'balance': 4},
#  {'_id': ObjectId('66c561a994610b691202b5eb'), 'age': 33, 'balance': -349},
#  {'_id': ObjectId('66c561a994610b691202b5ec'), 'age': 41, 'balance': 4},
#  {'_id': ObjectId('66c561a994610b691202b5ed'), 'age': 40, 'balance': -322},
#  {'_id': ObjectId('66c561a994610b691202b5ee'), 'age': 29, 'balance': -150},
#  {'_id': ObjectId('66c561a994610b691202b5f4'), 'age': 41, 'balance': 89},
#  {'_id': ObjectId('66c561a994610b691202b5f8'), 'age': 60, 'balance': 46},
#  {'_id': ObjectId('66c561a994610b691202b5fb'), 'age': 31, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b5fc'), 'age': 49, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b5fd'), 'age': 29, 'balance': 43},
#  {'_id': ObjectId('66c561a994610b691202b5fe'), 'age': 31, 'balance': -173},
#  {'_id': ObjectId('66c561a994610b691202b601'), 'age': 35, 'balance': -131},
#  {'_id': ObjectId('66c561a994610b691202b603'), 'age': 41, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b604'), 'age': 46, 'balance': 80},
#  {'_id': ObjectId('66c561a994610b691202b607'), 'age': 49, 'balance': 82},
#  {'_id': ObjectId('66c561a994610b691202b608'), 'age': 42, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b60c'), 'age': 49, 'balance': 92},
#  {'_id': ObjectId('66c561a994610b691202b60d'), 'age': 40, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b60f'), 'age': 36, 'balance': 23},
#  {'_id': ObjectId('66c561a994610b691202b614'), 'age': 40, 'balance': 6},
#  {'_id': ObjectId('66c561a994610b691202b615'), 'age': 49, 'balance': 26},
#  {'_id': ObjectId('66c561a994610b691202b616'), 'age': 30, 'balance': -48},
#  {'_id': ObjectId('66c561a994610b691202b618'), 'age': 24, 'balance': 77},
#  {'_id': ObjectId('66c561a994610b691202b61a'), 'age': 33, 'balance': 21},
#  {'_id': ObjectId('66c561a994610b691202b61b'), 'age': 43, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b61c'), 'age': 43, 'balance': -497},
#  {'_id': ObjectId('66c561a994610b691202b61e'), 'age': 44, 'balance': 78},
#  {'_id': ObjectId('66c561a994610b691202b622'), 'age': 31, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b623'), 'age': 40, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b625'), 'age': 56, 'balance': 4},
#  {'_id': ObjectId('66c561a994610b691202b62c'), 'age': 54, 'balance': 83},
#  {'_id': ObjectId('66c561a994610b691202b62d'), 'age': 58, 'balance': 68},
#  {'_id': ObjectId('66c561a994610b691202b62e'), 'age': 52, 'balance': 58},
#  {'_id': ObjectId('66c561a994610b691202b632'), 'age': 42, 'balance': 55},
#  {'_id': ObjectId('66c561a994610b691202b63c'), 'age': 40, 'balance': -7},
#  {'_id': ObjectId('66c561a994610b691202b63d'), 'age': 55, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b646'), 'age': 56, 'balance': 7},
#  {'_id': ObjectId('66c561a994610b691202b648'), 'age': 37, 'balance': 88},
#  {'_id': ObjectId('66c561a994610b691202b649'), 'age': 30, 'balance': 32},
#  {'_id': ObjectId('66c561a994610b691202b64f'), 'age': 38, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b653'), 'age': 37, 'balance': -421},
#  {'_id': ObjectId('66c561a994610b691202b654'), 'age': 33, 'balance': 60},
#  {'_id': ObjectId('66c561a994610b691202b655'), 'age': 44, 'balance': 67},
#  {'_id': ObjectId('66c561a994610b691202b65e'), 'age': 42, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b660'), 'age': 42, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b661'), 'age': 39, 'balance': 20},
#  {'_id': ObjectId('66c561a994610b691202b662'), 'age': 55, 'balance': 92},
#  {'_id': ObjectId('66c561a994610b691202b663'), 'age': 46, 'balance': 89},
#  {'_id': ObjectId('66c561a994610b691202b666'), 'age': 43, 'balance': -454},
#  {'_id': ObjectId('66c561a994610b691202b668'), 'age': 30, 'balance': 4},
#  {'_id': ObjectId('66c561a994610b691202b66a'), 'age': 51, 'balance': -69},
#  {'_id': ObjectId('66c561a994610b691202b66b'), 'age': 38, 'balance': 42},
#  {'_id': ObjectId('66c561a994610b691202b66f'), 'age': 46, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b675'), 'age': 31, 'balance': 53},
#  {'_id': ObjectId('66c561a994610b691202b67b'), 'age': 56, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b67c'), 'age': 29, 'balance': 8},
#  {'_id': ObjectId('66c561a994610b691202b680'), 'age': 35, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b681'), 'age': 35, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b686'), 'age': 36, 'balance': -251},
#  {'_id': ObjectId('66c561a994610b691202b687'), 'age': 45, 'balance': -139},
#  {'_id': ObjectId('66c561a994610b691202b689'), 'age': 29, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b68a'), 'age': 57, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b68b'), 'age': 45, 'balance': 97},
#  {'_id': ObjectId('66c561a994610b691202b68d'), 'age': 31, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b68f'), 'age': 30, 'balance': 3},
#  {'_id': ObjectId('66c561a994610b691202b693'), 'age': 33, 'balance': 95},
#  {'_id': ObjectId('66c561a994610b691202b695'), 'age': 36, 'balance': -290},
#  {'_id': ObjectId('66c561a994610b691202b69b'), 'age': 42, 'balance': 19},
#  {'_id': ObjectId('66c561a994610b691202b69c'), 'age': 37, 'balance': 16},
#  {'_id': ObjectId('66c561a994610b691202b69f'), 'age': 44, 'balance': -329},
#  {'_id': ObjectId('66c561a994610b691202b6a0'), 'age': 30, 'balance': -174},
#  {'_id': ObjectId('66c561a994610b691202b6a1'), 'age': 45, 'balance': 68},
#  {'_id': ObjectId('66c561a994610b691202b6a2'), 'age': 35, 'balance': -532},
#  {'_id': ObjectId('66c561a994610b691202b6a3'), 'age': 36, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b6a4'), 'age': 49, 'balance': 64},
#  {'_id': ObjectId('66c561a994610b691202b6a7'), 'age': 39, 'balance': 72},
#  {'_id': ObjectId('66c561a994610b691202b6a8'), 'age': 37, 'balance': -196},
#  {'_id': ObjectId('66c561a994610b691202b6aa'), 'age': 37, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b6ab'), 'age': 42, 'balance': -246},
#  {'_id': ObjectId('66c561a994610b691202b6ac'), 'age': 56, 'balance': -203},
#  {'_id': ObjectId('66c561a994610b691202b6af'), 'age': 29, 'balance': 3},
#  {'_id': ObjectId('66c561a994610b691202b6b0'), 'age': 54, 'balance': -248},
#  {'_id': ObjectId('66c561a994610b691202b6ba'), 'age': 37, 'balance': 52},
#  {'_id': ObjectId('66c561a994610b691202b6bf'), 'age': 26, 'balance': 24},
#  {'_id': ObjectId('66c561a994610b691202b6c4'), 'age': 32, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b6cb'), 'age': 38, 'balance': 8},
#  {'_id': ObjectId('66c561a994610b691202b6cc'), 'age': 37, 'balance': 78},
#  {'_id': ObjectId('66c561a994610b691202b6ce'), 'age': 33, 'balance': 98},
#  {'_id': ObjectId('66c561a994610b691202b6cf'), 'age': 38, 'balance': 83},
#  {'_id': ObjectId('66c561a994610b691202b6d0'), 'age': 37, 'balance': 45},
#  {'_id': ObjectId('66c561a994610b691202b6d1'), 'age': 29, 'balance': 8},
#  {'_id': ObjectId('66c561a994610b691202b6d7'), 'age': 53, 'balance': -291},
#  {'_id': ObjectId('66c561a994610b691202b6da'), 'age': 29, 'balance': 56},
#  {'_id': ObjectId('66c561a994610b691202b6dd'), 'age': 38, 'balance': 100},
#  {'_id': ObjectId('66c561a994610b691202b6e2'), 'age': 32, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b6e6'), 'age': 27, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b6e9'), 'age': 43, 'balance': 66},
#  {'_id': ObjectId('66c561a994610b691202b6ea'), 'age': 51, 'balance': 37},
#  {'_id': ObjectId('66c561a994610b691202b6eb'), 'age': 32, 'balance': 64},
#  {'_id': ObjectId('66c561a994610b691202b6ec'), 'age': 47, 'balance': 34},
#  {'_id': ObjectId('66c561a994610b691202b6f1'), 'age': 28, 'balance': 97},
#  {'_id': ObjectId('66c561a994610b691202b6f2'), 'age': 38, 'balance': 5},
#  {'_id': ObjectId('66c561a994610b691202b6f3'), 'age': 37, 'balance': 74},
#  {'_id': ObjectId('66c561a994610b691202b6f8'), 'age': 32, 'balance': -205},
#  {'_id': ObjectId('66c561a994610b691202b6fa'), 'age': 35, 'balance': 39},
#  {'_id': ObjectId('66c561a994610b691202b6fc'), 'age': 52, 'balance': -98},
#  {'_id': ObjectId('66c561a994610b691202b6fd'), 'age': 33, 'balance': 44},
#  {'_id': ObjectId('66c561a994610b691202b6fe'), 'age': 55, 'balance': -90},
#  {'_id': ObjectId('66c561a994610b691202b6ff'), 'age': 33, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b700'), 'age': 40, 'balance': -94},
#  {'_id': ObjectId('66c561a994610b691202b701'), 'age': 39, 'balance': -345},
#  {'_id': ObjectId('66c561a994610b691202b702'), 'age': 54, 'balance': -932},
#  {'_id': ObjectId('66c561a994610b691202b703'), 'age': 39, 'balance': 20},
#  {'_id': ObjectId('66c561a994610b691202b704'), 'age': 49, 'balance': 90},
#  {'_id': ObjectId('66c561a994610b691202b705'), 'age': 52, 'balance': 31},
#  {'_id': ObjectId('66c561a994610b691202b707'), 'age': 26, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b708'), 'age': 40, 'balance': 61},
#  {'_id': ObjectId('66c561a994610b691202b709'), 'age': 47, 'balance': -5},
#  {'_id': ObjectId('66c561a994610b691202b70a'), 'age': 31, 'balance': -45},
#  {'_id': ObjectId('66c561a994610b691202b70d'), 'age': 33, 'balance': -6},
#  {'_id': ObjectId('66c561a994610b691202b716'), 'age': 43, 'balance': 87},
#  {'_id': ObjectId('66c561a994610b691202b71a'), 'age': 38, 'balance': -32},
#  {'_id': ObjectId('66c561a994610b691202b721'), 'age': 43, 'balance': 71},
#  {'_id': ObjectId('66c561a994610b691202b725'), 'age': 30, 'balance': 21},
#  {'_id': ObjectId('66c561a994610b691202b727'), 'age': 33, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b72a'), 'age': 31, 'balance': -825},
#  {'_id': ObjectId('66c561a994610b691202b72c'), 'age': 60, 'balance': 42},
#  {'_id': ObjectId('66c561a994610b691202b72d'), 'age': 33, 'balance': 54},
#  {'_id': ObjectId('66c561a994610b691202b738'), 'age': 38, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b739'), 'age': 36, 'balance': 91},
#  {'_id': ObjectId('66c561a994610b691202b73c'), 'age': 38, 'balance': -1},
#  {'_id': ObjectId('66c561a994610b691202b741'), 'age': 43, 'balance': 61},
#  {'_id': ObjectId('66c561a994610b691202b743'), 'age': 33, 'balance': 56},
#  {'_id': ObjectId('66c561a994610b691202b744'), 'age': 47, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b745'), 'age': 50, 'balance': 73},
#  {'_id': ObjectId('66c561a994610b691202b747'), 'age': 44, 'balance': -79},
#  {'_id': ObjectId('66c561a994610b691202b74a'), 'age': 40, 'balance': -4},
#  {'_id': ObjectId('66c561a994610b691202b74d'), 'age': 53, 'balance': 46},
#  {'_id': ObjectId('66c561a994610b691202b759'), 'age': 48, 'balance': -500},
#  {'_id': ObjectId('66c561a994610b691202b760'), 'age': 31, 'balance': 19},
#  {'_id': ObjectId('66c561a994610b691202b763'), 'age': 44, 'balance': 7},
#  {'_id': ObjectId('66c561a994610b691202b764'), 'age': 37, 'balance': 16},
#  {'_id': ObjectId('66c561a994610b691202b76f'), 'age': 40, 'balance': 4},
#  {'_id': ObjectId('66c561a994610b691202b770'), 'age': 42, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b771'), 'age': 34, 'balance': 42},
#  {'_id': ObjectId('66c561a994610b691202b773'), 'age': 30, 'balance': 60},
#  {'_id': ObjectId('66c561a994610b691202b774'), 'age': 51, 'balance': 98},
#  {'_id': ObjectId('66c561a994610b691202b775'), 'age': 52, 'balance': -181},
#  {'_id': ObjectId('66c561a994610b691202b777'), 'age': 41, 'balance': -15},
#  {'_id': ObjectId('66c561a994610b691202b77a'), 'age': 36, 'balance': -20},
#  {'_id': ObjectId('66c561a994610b691202b77c'), 'age': 44, 'balance': -171},
#  {'_id': ObjectId('66c561a994610b691202b782'), 'age': 30, 'balance': -317},
#  {'_id': ObjectId('66c561a994610b691202b784'), 'age': 29, 'balance': -158},
#  {'_id': ObjectId('66c561a994610b691202b785'), 'age': 41, 'balance': 72},
#  {'_id': ObjectId('66c561a994610b691202b786'), 'age': 44, 'balance': 58},
#  {'_id': ObjectId('66c561a994610b691202b788'), 'age': 59, 'balance': 10},
#  {'_id': ObjectId('66c561a994610b691202b78a'), 'age': 42, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b78b'), 'age': 31, 'balance': 89},
#  {'_id': ObjectId('66c561a994610b691202b78c'), 'age': 29, 'balance': 50},
#  {'_id': ObjectId('66c561a994610b691202b78d'), 'age': 39, 'balance': 29},
#  {'_id': ObjectId('66c561a994610b691202b791'), 'age': 27, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b792'), 'age': 56, 'balance': -24},
#  {'_id': ObjectId('66c561a994610b691202b794'), 'age': 37, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b795'), 'age': 54, 'balance': 99},
#  {'_id': ObjectId('66c561a994610b691202b796'), 'age': 38, 'balance': 22},
#  {'_id': ObjectId('66c561a994610b691202b79e'), 'age': 39, 'balance': -33},
#  {'_id': ObjectId('66c561a994610b691202b79f'), 'age': 33, 'balance': 76},
#  {'_id': ObjectId('66c561a994610b691202b7a0'), 'age': 37, 'balance': 42},
#  {'_id': ObjectId('66c561a994610b691202b7a1'), 'age': 46, 'balance': 76},
#  {'_id': ObjectId('66c561a994610b691202b7a5'), 'age': 46, 'balance': 40},
#  {'_id': ObjectId('66c561a994610b691202b7aa'), 'age': 44, 'balance': -212},
#  {'_id': ObjectId('66c561a994610b691202b7b0'), 'age': 52, 'balance': -57},
#  {'_id': ObjectId('66c561a994610b691202b7b1'), 'age': 32, 'balance': 81},
#  {'_id': ObjectId('66c561a994610b691202b7b2'), 'age': 40, 'balance': -227},
#  {'_id': ObjectId('66c561a994610b691202b7b4'), 'age': 30, 'balance': 98},
#  {'_id': ObjectId('66c561a994610b691202b7b6'), 'age': 46, 'balance': 78},
#  {'_id': ObjectId('66c561a994610b691202b7bb'), 'age': 39, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b7bd'), 'age': 49, 'balance': 51},
#  {'_id': ObjectId('66c561a994610b691202b7c4'), 'age': 36, 'balance': -79},
#  {'_id': ObjectId('66c561a994610b691202b7c7'), 'age': 48, 'balance': 5},
#  {'_id': ObjectId('66c561a994610b691202b7c8'), 'age': 38, 'balance': 20},
#  {'_id': ObjectId('66c561a994610b691202b7ca'), 'age': 44, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b7cb'), 'age': 28, 'balance': 3},
#  {'_id': ObjectId('66c561a994610b691202b7cc'), 'age': 28, 'balance': -55},
#  {'_id': ObjectId('66c561a994610b691202b7cf'), 'age': 56, 'balance': 93},
#  {'_id': ObjectId('66c561a994610b691202b7d1'), 'age': 34, 'balance': 78},
#  {'_id': ObjectId('66c561a994610b691202b7d6'), 'age': 44, 'balance': -30},
#  {'_id': ObjectId('66c561a994610b691202b7da'), 'age': 44, 'balance': -97},
#  {'_id': ObjectId('66c561a994610b691202b7db'), 'age': 31, 'balance': 53},
#  {'_id': ObjectId('66c561a994610b691202b7e2'), 'age': 59, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b7e7'), 'age': 32, 'balance': 89},
#  {'_id': ObjectId('66c561a994610b691202b7eb'), 'age': 30, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b7ec'), 'age': 34, 'balance': 6},
#  {'_id': ObjectId('66c561a994610b691202b7ed'), 'age': 34, 'balance': -947},
#  {'_id': ObjectId('66c561a994610b691202b7ef'), 'age': 36, 'balance': -147},
#  {'_id': ObjectId('66c561a994610b691202b7f1'), 'age': 39, 'balance': 70},
#  {'_id': ObjectId('66c561a994610b691202b7f2'), 'age': 36, 'balance': 83},
#  {'_id': ObjectId('66c561a994610b691202b7f5'), 'age': 52, 'balance': 46},
#  {'_id': ObjectId('66c561a994610b691202b7f8'), 'age': 27, 'balance': 96},
#  {'_id': ObjectId('66c561a994610b691202b7fb'), 'age': 38, 'balance': 54},
#  {'_id': ObjectId('66c561a994610b691202b800'), 'age': 36, 'balance': -206},
#  {'_id': ObjectId('66c561a994610b691202b803'), 'age': 41, 'balance': -413},
#  {'_id': ObjectId('66c561a994610b691202b804'), 'age': 33, 'balance': -81},
#  {'_id': ObjectId('66c561a994610b691202b809'), 'age': 51, 'balance': 57},
#  {'_id': ObjectId('66c561a994610b691202b80a'), 'age': 28, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b80b'), 'age': 43, 'balance': -7},
#  {'_id': ObjectId('66c561a994610b691202b817'), 'age': 48, 'balance': -18},
#  {'_id': ObjectId('66c561a994610b691202b818'), 'age': 36, 'balance': 49},
#  {'_id': ObjectId('66c561a994610b691202b81a'), 'age': 30, 'balance': 59},
#  {'_id': ObjectId('66c561a994610b691202b81b'), 'age': 46, 'balance': 45},
#  {'_id': ObjectId('66c561a994610b691202b81d'), 'age': 32, 'balance': 5},
#  {'_id': ObjectId('66c561a994610b691202b81e'), 'age': 48, 'balance': 71},
#  {'_id': ObjectId('66c561a994610b691202b81f'), 'age': 48, 'balance': 96},
#  {'_id': ObjectId('66c561a994610b691202b820'), 'age': 36, 'balance': 72},
#  {'_id': ObjectId('66c561a994610b691202b823'), 'age': 26, 'balance': 20},
#  {'_id': ObjectId('66c561a994610b691202b824'), 'age': 38, 'balance': 65},
#  {'_id': ObjectId('66c561a994610b691202b825'), 'age': 27, 'balance': 81},
#  {'_id': ObjectId('66c561a994610b691202b82c'), 'age': 42, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b831'), 'age': 55, 'balance': 84},
#  {'_id': ObjectId('66c561a994610b691202b834'), 'age': 34, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b83b'), 'age': 49, 'balance': -8},
#  {'_id': ObjectId('66c561a994610b691202b83e'), 'age': 50, 'balance': 40},
#  {'_id': ObjectId('66c561a994610b691202b83f'), 'age': 58, 'balance': 44},
#  {'_id': ObjectId('66c561a994610b691202b840'), 'age': 43, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b841'), 'age': 34, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b847'), 'age': 33, 'balance': -744},
#  {'_id': ObjectId('66c561a994610b691202b848'), 'age': 60, 'balance': -2},
#  {'_id': ObjectId('66c561a994610b691202b84d'), 'age': 34, 'balance': 80},
#  {'_id': ObjectId('66c561a994610b691202b84e'), 'age': 32, 'balance': 10},
#  {'_id': ObjectId('66c561a994610b691202b850'), 'age': 40, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b852'), 'age': 48, 'balance': 4},
#  {'_id': ObjectId('66c561a994610b691202b855'), 'age': 41, 'balance': 55},
#  {'_id': ObjectId('66c561a994610b691202b85a'), 'age': 45, 'balance': 85},
#  {'_id': ObjectId('66c561a994610b691202b85e'), 'age': 38, 'balance': 66},
#  {'_id': ObjectId('66c561a994610b691202b864'), 'age': 26, 'balance': 85},
#  {'_id': ObjectId('66c561a994610b691202b866'), 'age': 26, 'balance': -29},
#  {'_id': ObjectId('66c561a994610b691202b869'), 'age': 30, 'balance': 31},
#  {'_id': ObjectId('66c561a994610b691202b86c'), 'age': 30, 'balance': 3},
#  {'_id': ObjectId('66c561a994610b691202b870'), 'age': 41, 'balance': 47},
#  {'_id': ObjectId('66c561a994610b691202b871'), 'age': 28, 'balance': -58},
#  {'_id': ObjectId('66c561a994610b691202b878'), 'age': 44, 'balance': -95},
#  {'_id': ObjectId('66c561a994610b691202b87d'), 'age': 34, 'balance': 65},
#  {'_id': ObjectId('66c561a994610b691202b87f'), 'age': 44, 'balance': -84},
#  {'_id': ObjectId('66c561a994610b691202b880'), 'age': 44, 'balance': 36},
#  {'_id': ObjectId('66c561a994610b691202b882'), 'age': 36, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b886'), 'age': 55, 'balance': -24},
#  {'_id': ObjectId('66c561a994610b691202b889'), 'age': 44, 'balance': -617},
#  {'_id': ObjectId('66c561a994610b691202b88a'), 'age': 30, 'balance': -1},
#  {'_id': ObjectId('66c561a994610b691202b893'), 'age': 52, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b895'), 'age': 35, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b89b'), 'age': 49, 'balance': -22},
#  {'_id': ObjectId('66c561a994610b691202b89e'), 'age': 28, 'balance': 6},
#  {'_id': ObjectId('66c561a994610b691202b8a1'), 'age': 58, 'balance': 5},
#  {'_id': ObjectId('66c561a994610b691202b8a3'), 'age': 46, 'balance': -768},
#  {'_id': ObjectId('66c561a994610b691202b8a4'), 'age': 42, 'balance': 30},
#  {'_id': ObjectId('66c561a994610b691202b8a6'), 'age': 42, 'balance': 47},
#  {'_id': ObjectId('66c561a994610b691202b8a7'), 'age': 33, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b8a8'), 'age': 27, 'balance': 91},
#  {'_id': ObjectId('66c561a994610b691202b8a9'), 'age': 43, 'balance': -77},
#  {'_id': ObjectId('66c561a994610b691202b8ac'), 'age': 37, 'balance': 50},
#  {'_id': ObjectId('66c561a994610b691202b8af'), 'age': 37, 'balance': 31},
#  {'_id': ObjectId('66c561a994610b691202b8b0'), 'age': 41, 'balance': -581},
#  {'_id': ObjectId('66c561a994610b691202b8b1'), 'age': 36, 'balance': -45},
#  {'_id': ObjectId('66c561a994610b691202b8b2'), 'age': 51, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b8b5'), 'age': 33, 'balance': -232},
#  {'_id': ObjectId('66c561a994610b691202b8b7'), 'age': 31, 'balance': 28},
#  {'_id': ObjectId('66c561a994610b691202b8ba'), 'age': 26, 'balance': 37},
#  {'_id': ObjectId('66c561a994610b691202b8c0'), 'age': 32, 'balance': 3},
#  {'_id': ObjectId('66c561a994610b691202b8c7'), 'age': 40, 'balance': -29},
#  {'_id': ObjectId('66c561a994610b691202b8c9'), 'age': 39, 'balance': 82},
#  {'_id': ObjectId('66c561a994610b691202b8ca'), 'age': 28, 'balance': 21},
#  {'_id': ObjectId('66c561a994610b691202b8d0'), 'age': 39, 'balance': -244},
#  {'_id': ObjectId('66c561a994610b691202b8d1'), 'age': 30, 'balance': 70},
#  {'_id': ObjectId('66c561a994610b691202b8d2'), 'age': 35, 'balance': -339},
#  {'_id': ObjectId('66c561a994610b691202b8d3'), 'age': 31, 'balance': 59},
#  {'_id': ObjectId('66c561a994610b691202b8d5'), 'age': 26, 'balance': -41},
#  {'_id': ObjectId('66c561a994610b691202b8d6'), 'age': 25, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b8d7'), 'age': 42, 'balance': 6},
#  {'_id': ObjectId('66c561a994610b691202b8d8'), 'age': 30, 'balance': 4},
#  {'_id': ObjectId('66c561a994610b691202b8d9'), 'age': 28, 'balance': 20},
#  {'_id': ObjectId('66c561a994610b691202b8dc'), 'age': 38, 'balance': 90},
#  {'_id': ObjectId('66c561a994610b691202b8de'), 'age': 29, 'balance': 2},
#  {'_id': ObjectId('66c561a994610b691202b8e0'), 'age': 40, 'balance': 87},
#  {'_id': ObjectId('66c561a994610b691202b8e3'), 'age': 38, 'balance': -210},
#  {'_id': ObjectId('66c561a994610b691202b8e5'), 'age': 32, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b8ef'), 'age': 60, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b8f0'), 'age': 40, 'balance': -275},
#  {'_id': ObjectId('66c561a994610b691202b8f2'), 'age': 25, 'balance': 37},
#  {'_id': ObjectId('66c561a994610b691202b8fc'), 'age': 36, 'balance': 90},
#  {'_id': ObjectId('66c561a994610b691202b8fd'), 'age': 22, 'balance': 54},
#  {'_id': ObjectId('66c561a994610b691202b8fe'), 'age': 26, 'balance': -132},
#  {'_id': ObjectId('66c561a994610b691202b909'), 'age': 43, 'balance': 34},
#  {'_id': ObjectId('66c561a994610b691202b90c'), 'age': 35, 'balance': 25},
#  {'_id': ObjectId('66c561a994610b691202b90d'), 'age': 45, 'balance': 22},
#  {'_id': ObjectId('66c561a994610b691202b912'), 'age': 43, 'balance': -192},
#  {'_id': ObjectId('66c561a994610b691202b913'), 'age': 42, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b916'), 'age': 31, 'balance': 68},
#  {'_id': ObjectId('66c561a994610b691202b917'), 'age': 57, 'balance': -176},
#  {'_id': ObjectId('66c561a994610b691202b921'), 'age': 33, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b923'), 'age': 30, 'balance': 80},
#  {'_id': ObjectId('66c561a994610b691202b926'), 'age': 37, 'balance': 48},
#  {'_id': ObjectId('66c561a994610b691202b927'), 'age': 34, 'balance': 76},
#  {'_id': ObjectId('66c561a994610b691202b929'), 'age': 42, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b92f'), 'age': 28, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b930'), 'age': 55, 'balance': 82},
#  {'_id': ObjectId('66c561a994610b691202b937'), 'age': 34, 'balance': -315},
#  {'_id': ObjectId('66c561a994610b691202b938'), 'age': 41, 'balance': 64},
#  {'_id': ObjectId('66c561a994610b691202b939'), 'age': 59, 'balance': -820},
#  {'_id': ObjectId('66c561a994610b691202b93d'), 'age': 36, 'balance': 70},
#  {'_id': ObjectId('66c561a994610b691202b942'), 'age': 38, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b943'), 'age': 27, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b945'), 'age': 37, 'balance': 22},
#  {'_id': ObjectId('66c561a994610b691202b947'), 'age': 33, 'balance': 56},
#  {'_id': ObjectId('66c561a994610b691202b94f'), 'age': 31, 'balance': 50},
#  {'_id': ObjectId('66c561a994610b691202b950'), 'age': 34, 'balance': 67},
#  {'_id': ObjectId('66c561a994610b691202b951'), 'age': 46, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b952'), 'age': 33, 'balance': 61},
#  {'_id': ObjectId('66c561a994610b691202b956'), 'age': 31, 'balance': -732},
#  {'_id': ObjectId('66c561a994610b691202b959'), 'age': 50, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b960'), 'age': 32, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b961'), 'age': 59, 'balance': -138},
#  {'_id': ObjectId('66c561a994610b691202b963'), 'age': 37, 'balance': 14},
#  {'_id': ObjectId('66c561a994610b691202b969'), 'age': 50, 'balance': 72},
#  {'_id': ObjectId('66c561a994610b691202b96d'), 'age': 35, 'balance': 69},
#  {'_id': ObjectId('66c561a994610b691202b96f'), 'age': 43, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b970'), 'age': 40, 'balance': 23},
#  {'_id': ObjectId('66c561a994610b691202b971'), 'age': 36, 'balance': 42},
#  {'_id': ObjectId('66c561a994610b691202b973'), 'age': 32, 'balance': 88},
#  {'_id': ObjectId('66c561a994610b691202b97b'), 'age': 32, 'balance': 20},
#  {'_id': ObjectId('66c561a994610b691202b97c'), 'age': 52, 'balance': -17},
#  {'_id': ObjectId('66c561a994610b691202b97d'), 'age': 41, 'balance': -417},
#  {'_id': ObjectId('66c561a994610b691202b986'), 'age': 41, 'balance': -52},
#  {'_id': ObjectId('66c561a994610b691202b988'), 'age': 39, 'balance': -432},
#  {'_id': ObjectId('66c561a994610b691202b98b'), 'age': 39, 'balance': -85},
#  {'_id': ObjectId('66c561a994610b691202b98f'), 'age': 54, 'balance': 23},
#  {'_id': ObjectId('66c561a994610b691202b990'), 'age': 30, 'balance': -315},
#  {'_id': ObjectId('66c561a994610b691202b991'), 'age': 35, 'balance': 89},
#  {'_id': ObjectId('66c561a994610b691202b994'), 'age': 29, 'balance': -138},
#  {'_id': ObjectId('66c561a994610b691202b998'), 'age': 38, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b99f'), 'age': 35, 'balance': 14},
#  {'_id': ObjectId('66c561a994610b691202b9a0'), 'age': 41, 'balance': -97},
#  {'_id': ObjectId('66c561a994610b691202b9a8'), 'age': 31, 'balance': -13},
#  {'_id': ObjectId('66c561a994610b691202b9ae'), 'age': 28, 'balance': -9},
#  {'_id': ObjectId('66c561a994610b691202b9b1'), 'age': 35, 'balance': 19},
#  {'_id': ObjectId('66c561a994610b691202b9b5'), 'age': 47, 'balance': -98},
#  {'_id': ObjectId('66c561a994610b691202b9b8'), 'age': 31, 'balance': 26},
#  {'_id': ObjectId('66c561a994610b691202b9ba'), 'age': 53, 'balance': -118},
#  {'_id': ObjectId('66c561a994610b691202b9bf'), 'age': 45, 'balance': -88},
#  {'_id': ObjectId('66c561a994610b691202b9c1'), 'age': 40, 'balance': 21},
#  {'_id': ObjectId('66c561a994610b691202b9c5'), 'age': 44, 'balance': 85},
#  {'_id': ObjectId('66c561a994610b691202b9c7'), 'age': 29, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b9c8'), 'age': 33, 'balance': 60},
#  {'_id': ObjectId('66c561a994610b691202b9ca'), 'age': 35, 'balance': 40},
#  {'_id': ObjectId('66c561a994610b691202b9cb'), 'age': 31, 'balance': 22},
#  {'_id': ObjectId('66c561a994610b691202b9cc'), 'age': 36, 'balance': -333},
#  {'_id': ObjectId('66c561a994610b691202b9d1'), 'age': 34, 'balance': 33},
#  {'_id': ObjectId('66c561a994610b691202b9d2'), 'age': 41, 'balance': -320},
#  {'_id': ObjectId('66c561a994610b691202b9d3'), 'age': 43, 'balance': 49},
#  {'_id': ObjectId('66c561a994610b691202b9d4'), 'age': 37, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b9d5'), 'age': 26, 'balance': 100},
#  {'_id': ObjectId('66c561a994610b691202b9d7'), 'age': 51, 'balance': -286},
#  {'_id': ObjectId('66c561a994610b691202b9d8'), 'age': 38, 'balance': 57},
#  {'_id': ObjectId('66c561a994610b691202b9db'), 'age': 31, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b9dd'), 'age': 30, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202b9de'), 'age': 33, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202b9e4'), 'age': 34, 'balance': -322},
#  {'_id': ObjectId('66c561a994610b691202b9e6'), 'age': 43, 'balance': 3},
#  {'_id': ObjectId('66c561a994610b691202b9e7'), 'age': 28, 'balance': 6},
# ...
#  {'_id': ObjectId('66c561a994610b691202bb72'), 'age': 42, 'balance': -25},
#  {'_id': ObjectId('66c561a994610b691202bb73'), 'age': 40, 'balance': 66},
#  {'_id': ObjectId('66c561a994610b691202bb74'), 'age': 31, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bb78'), 'age': 37, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bb7b'), 'age': 28, 'balance': -201},
#  {'_id': ObjectId('66c561a994610b691202bb7c'), 'age': 40, 'balance': -278},
#  {'_id': ObjectId('66c561a994610b691202bb7d'), 'age': 43, 'balance': 16},
#  {'_id': ObjectId('66c561a994610b691202bb7e'), 'age': 51, 'balance': -283},
#  {'_id': ObjectId('66c561a994610b691202bb7f'), 'age': 28, 'balance': -103},
#  {'_id': ObjectId('66c561a994610b691202bb83'), 'age': 26, 'balance': -402},
#  {'_id': ObjectId('66c561a994610b691202bb84'), 'age': 55, 'balance': -40},
#  {'_id': ObjectId('66c561a994610b691202bb86'), 'age': 39, 'balance': 36},
#  {'_id': ObjectId('66c561a994610b691202bb89'), 'age': 33, 'balance': 2},
#  {'_id': ObjectId('66c561a994610b691202bb8f'), 'age': 28, 'balance': -871},
#  {'_id': ObjectId('66c561a994610b691202bb90'), 'age': 33, 'balance': 75},
#  {'_id': ObjectId('66c561a994610b691202bb92'), 'age': 25, 'balance': -454},
#  {'_id': ObjectId('66c561a994610b691202bb93'), 'age': 29, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bb9d'), 'age': 30, 'balance': -149},
#  {'_id': ObjectId('66c561a994610b691202bb9e'), 'age': 54, 'balance': -337},
#  {'_id': ObjectId('66c561a994610b691202bba1'), 'age': 56, 'balance': 75},
#  {'_id': ObjectId('66c561a994610b691202bba3'), 'age': 60, 'balance': 78},
#  {'_id': ObjectId('66c561a994610b691202bbaa'), 'age': 25, 'balance': -439},
#  {'_id': ObjectId('66c561a994610b691202bbab'), 'age': 31, 'balance': 37},
#  {'_id': ObjectId('66c561a994610b691202bbad'), 'age': 27, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202bbaf'), 'age': 34, 'balance': -89},
#  {'_id': ObjectId('66c561a994610b691202bbb4'), 'age': 27, 'balance': -302},
#  {'_id': ObjectId('66c561a994610b691202bbba'), 'age': 25, 'balance': 40},
#  {'_id': ObjectId('66c561a994610b691202bbbe'), 'age': 28, 'balance': -214},
#  {'_id': ObjectId('66c561a994610b691202bbc7'), 'age': 29, 'balance': 11},
#  {'_id': ObjectId('66c561a994610b691202bbc9'), 'age': 44, 'balance': 23},
#  {'_id': ObjectId('66c561a994610b691202bbcc'), 'age': 46, 'balance': -29},
#  {'_id': ObjectId('66c561a994610b691202bbd2'), 'age': 29, 'balance': -28},
#  {'_id': ObjectId('66c561a994610b691202bbd4'), 'age': 32, 'balance': 5},
#  {'_id': ObjectId('66c561a994610b691202bbd6'), 'age': 47, 'balance': -1445},
#  {'_id': ObjectId('66c561a994610b691202bbd7'), 'age': 26, 'balance': -23},
#  {'_id': ObjectId('66c561a994610b691202bbd8'), 'age': 28, 'balance': -284},
#  {'_id': ObjectId('66c561a994610b691202bbdb'), 'age': 29, 'balance': -72},
#  {'_id': ObjectId('66c561a994610b691202bbdd'), 'age': 43, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bbe2'), 'age': 33, 'balance': 14},
#  {'_id': ObjectId('66c561a994610b691202bbe3'), 'age': 28, 'balance': -219},
#  {'_id': ObjectId('66c561a994610b691202bbeb'), 'age': 56, 'balance': 13},
#  {'_id': ObjectId('66c561a994610b691202bbed'), 'age': 43, 'balance': -63},
#  {'_id': ObjectId('66c561a994610b691202bbf7'), 'age': 36, 'balance': -475},
#  {'_id': ObjectId('66c561a994610b691202bbfc'), 'age': 23, 'balance': 5},
#  {'_id': ObjectId('66c561a994610b691202bbfd'), 'age': 37, 'balance': 18},
#  {'_id': ObjectId('66c561a994610b691202bbfe'), 'age': 31, 'balance': -464},
#  {'_id': ObjectId('66c561a994610b691202bc01'), 'age': 28, 'balance': -260},
#  {'_id': ObjectId('66c561a994610b691202bc07'), 'age': 30, 'balance': 37},
#  {'_id': ObjectId('66c561a994610b691202bc0a'), 'age': 28, 'balance': 34},
#  {'_id': ObjectId('66c561a994610b691202bc0c'), 'age': 41, 'balance': 31},
#  {'_id': ObjectId('66c561a994610b691202bc0d'), 'age': 42, 'balance': -189},
#  {'_id': ObjectId('66c561a994610b691202bc18'), 'age': 45, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bc1a'), 'age': 38, 'balance': -329},
#  {'_id': ObjectId('66c561a994610b691202bc1b'), 'age': 24, 'balance': 94},
#  {'_id': ObjectId('66c561a994610b691202bc1d'), 'age': 32, 'balance': -18},
#  {'_id': ObjectId('66c561a994610b691202bc1e'), 'age': 48, 'balance': 26},
#  {'_id': ObjectId('66c561a994610b691202bc23'), 'age': 44, 'balance': 78},
#  {'_id': ObjectId('66c561a994610b691202bc26'), 'age': 57, 'balance': 73},
#  {'_id': ObjectId('66c561a994610b691202bc2a'), 'age': 55, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bc2b'), 'age': 25, 'balance': -76},
#  {'_id': ObjectId('66c561a994610b691202bc31'), 'age': 46, 'balance': -43},
#  {'_id': ObjectId('66c561a994610b691202bc38'), 'age': 48, 'balance': 40},
#  {'_id': ObjectId('66c561a994610b691202bc3a'), 'age': 26, 'balance': 96},
#  {'_id': ObjectId('66c561a994610b691202bc3f'), 'age': 45, 'balance': 27},
#  {'_id': ObjectId('66c561a994610b691202bc40'), 'age': 32, 'balance': -24},
#  {'_id': ObjectId('66c561a994610b691202bc41'), 'age': 39, 'balance': 23},
#  {'_id': ObjectId('66c561a994610b691202bc43'), 'age': 28, 'balance': -353},
#  {'_id': ObjectId('66c561a994610b691202bc44'), 'age': 31, 'balance': -474},
#  {'_id': ObjectId('66c561a994610b691202bc47'), 'age': 29, 'balance': 16},
#  {'_id': ObjectId('66c561a994610b691202bc4a'), 'age': 31, 'balance': -759},
#  {'_id': ObjectId('66c561a994610b691202bc4d'), 'age': 53, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bc4f'), 'age': 57, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bc51'), 'age': 50, 'balance': -37},
#  {'_id': ObjectId('66c561a994610b691202bc52'), 'age': 36, 'balance': 90},
#  {'_id': ObjectId('66c561a994610b691202bc53'), 'age': 46, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bc55'), 'age': 31, 'balance': 98},
#  {'_id': ObjectId('66c561a994610b691202bc5d'), 'age': 25, 'balance': 1},
#  {'_id': ObjectId('66c561a994610b691202bc5e'), 'age': 35, 'balance': -12},
#  {'_id': ObjectId('66c561a994610b691202bc65'), 'age': 46, 'balance': 41},
#  {'_id': ObjectId('66c561a994610b691202bc6c'), 'age': 56, 'balance': 11},
#  {'_id': ObjectId('66c561a994610b691202bc6d'), 'age': 35, 'balance': 36},
#  {'_id': ObjectId('66c561a994610b691202bc72'), 'age': 26, 'balance': -3},
#  {'_id': ObjectId('66c561a994610b691202bc73'), 'age': 22, 'balance': -168},
#  {'_id': ObjectId('66c561a994610b691202bc77'), 'age': 28, 'balance': -95},
#  {'_id': ObjectId('66c561a994610b691202bc79'), 'age': 26, 'balance': 8},
#  {'_id': ObjectId('66c561a994610b691202bc7b'), 'age': 27, 'balance': -541},
#  {'_id': ObjectId('66c561a994610b691202bc7c'), 'age': 34, 'balance': 23},
#  {'_id': ObjectId('66c561a994610b691202bc7d'), 'age': 25, 'balance': 17},
#  {'_id': ObjectId('66c561a994610b691202bc82'), 'age': 32, 'balance': -428},
#  {'_id': ObjectId('66c561a994610b691202bc85'), 'age': 22, 'balance': 83},
#  {'_id': ObjectId('66c561a994610b691202bc87'), 'age': 33, 'balance': 5},
#  {'_id': ObjectId('66c561a994610b691202bc8e'), 'age': 48, 'balance': 86},
#  {'_id': ObjectId('66c561a994610b691202bc90'), 'age': 24, 'balance': -126},
#  {'_id': ObjectId('66c561a994610b691202bc91'), 'age': 45, 'balance': -3},
#  {'_id': ObjectId('66c561a994610b691202bc92'), 'age': 26, 'balance': 54},
#  {'_id': ObjectId('66c561a994610b691202bc93'), 'age': 24, 'balance': -192},
#  {'_id': ObjectId('66c561a994610b691202bc96'), 'age': 30, 'balance': -522},
#  {'_id': ObjectId('66c561a994610b691202bc97'), 'age': 21, 'balance': 99},
#  {'_id': ObjectId('66c561a994610b691202bc98'), 'age': 42, 'balance': -1664},
#  {'_id': ObjectId('66c561a994610b691202bc99'), 'age': 32, 'balance': 2},
#  {'_id': ObjectId('66c561a994610b691202bc9c'), 'age': 32, 'balance': 62},
#  {'_id': ObjectId('66c561a994610b691202bc9f'), 'age': 37, 'balance': 36},
#  {'_id': ObjectId('66c561a994610b691202bca0'), 'age': 29, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bca2'), 'age': 46, 'balance': 91},
#  {'_id': ObjectId('66c561a994610b691202bca3'), 'age': 32, 'balance': -3},
#  {'_id': ObjectId('66c561a994610b691202bca8'), 'age': 32, 'balance': -121},
#  {'_id': ObjectId('66c561a994610b691202bca9'), 'age': 36, 'balance': -195},
#  {'_id': ObjectId('66c561a994610b691202bcaa'), 'age': 30, 'balance': -208},
#  {'_id': ObjectId('66c561a994610b691202bcae'), 'age': 45, 'balance': 66},
#  {'_id': ObjectId('66c561a994610b691202bcaf'), 'age': 24, 'balance': -122},
#  {'_id': ObjectId('66c561a994610b691202bcb0'), 'age': 54, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bcb1'), 'age': 33, 'balance': -90},
#  {'_id': ObjectId('66c561a994610b691202bcb3'), 'age': 36, 'balance': -423},
#  {'_id': ObjectId('66c561a994610b691202bcb9'), 'age': 47, 'balance': -13},
#  {'_id': ObjectId('66c561a994610b691202bcbb'), 'age': 24, 'balance': -10},
#  {'_id': ObjectId('66c561a994610b691202bcbc'), 'age': 23, 'balance': 5},
#  {'_id': ObjectId('66c561a994610b691202bcbd'), 'age': 27, 'balance': 71},
#  {'_id': ObjectId('66c561a994610b691202bcc1'), 'age': 55, 'balance': 39},
#  {'_id': ObjectId('66c561a994610b691202bcc3'), 'age': 59, 'balance': -49},
#  {'_id': ObjectId('66c561a994610b691202bcc4'), 'age': 20, 'balance': -103},
#  {'_id': ObjectId('66c561a994610b691202bcc5'), 'age': 30, 'balance': -846},
#  {'_id': ObjectId('66c561a994610b691202bcca'), 'age': 28, 'balance': -185},
#  {'_id': ObjectId('66c561a994610b691202bccd'), 'age': 28, 'balance': 52},
#  {'_id': ObjectId('66c561a994610b691202bcd1'), 'age': 29, 'balance': -114},
#  {'_id': ObjectId('66c561a994610b691202bcd6'), 'age': 26, 'balance': 92},
#  {'_id': ObjectId('66c561a994610b691202bcd7'), 'age': 21, 'balance': -273},
#  {'_id': ObjectId('66c561a994610b691202bcda'), 'age': 40, 'balance': -166},
#  {'_id': ObjectId('66c561a994610b691202bcdb'), 'age': 39, 'balance': -141},
#  {'_id': ObjectId('66c561a994610b691202bcdc'), 'age': 25, 'balance': -250},
#  {'_id': ObjectId('66c561a994610b691202bcde'), 'age': 57, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bce0'), 'age': 34, 'balance': -185},
#  {'_id': ObjectId('66c561a994610b691202bce8'), 'age': 45, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bcf1'), 'age': 44, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bcf5'), 'age': 43, 'balance': 24},
#  {'_id': ObjectId('66c561a994610b691202bcf7'), 'age': 26, 'balance': -204},
#  {'_id': ObjectId('66c561a994610b691202bcfe'), 'age': 41, 'balance': -111},
#  {'_id': ObjectId('66c561a994610b691202bd00'), 'age': 40, 'balance': 92},
#  {'_id': ObjectId('66c561a994610b691202bd04'), 'age': 30, 'balance': -166},
#  {'_id': ObjectId('66c561a994610b691202bd06'), 'age': 23, 'balance': 4},
#  {'_id': ObjectId('66c561a994610b691202bd07'), 'age': 44, 'balance': 23},
#  {'_id': ObjectId('66c561a994610b691202bd0c'), 'age': 29, 'balance': 95},
#  {'_id': ObjectId('66c561a994610b691202bd12'), 'age': 45, 'balance': -395},
#  {'_id': ObjectId('66c561a994610b691202bd14'), 'age': 54, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bd15'), 'age': 44, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bd1d'), 'age': 46, 'balance': 48},
#  {'_id': ObjectId('66c561a994610b691202bd1f'), 'age': 43, 'balance': -633},
#  {'_id': ObjectId('66c561a994610b691202bd24'), 'age': 59, 'balance': -892},
#  {'_id': ObjectId('66c561a994610b691202bd25'), 'age': 52, 'balance': 11},
#  {'_id': ObjectId('66c561a994610b691202bd2d'), 'age': 45, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bd37'), 'age': 24, 'balance': 11},
#  {'_id': ObjectId('66c561a994610b691202bd38'), 'age': 42, 'balance': 5},
#  {'_id': ObjectId('66c561a994610b691202bd3c'), 'age': 53, 'balance': -27},
#  {'_id': ObjectId('66c561a994610b691202bd42'), 'age': 27, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bd44'), 'age': 34, 'balance': 2},
#  {'_id': ObjectId('66c561a994610b691202bd45'), 'age': 44, 'balance': 3},
#  {'_id': ObjectId('66c561a994610b691202bd48'), 'age': 26, 'balance': 8},
#  {'_id': ObjectId('66c561a994610b691202bd4a'), 'age': 35, 'balance': -371},
#  {'_id': ObjectId('66c561a994610b691202bd53'), 'age': 53, 'balance': -689},
#  {'_id': ObjectId('66c561a994610b691202bd54'), 'age': 39, 'balance': 14},
#  {'_id': ObjectId('66c561a994610b691202bd55'), 'age': 35, 'balance': 56},
#  {'_id': ObjectId('66c561a994610b691202bd57'), 'age': 29, 'balance': 17},
#  {'_id': ObjectId('66c561a994610b691202bd5b'), 'age': 56, 'balance': 88},
#  {'_id': ObjectId('66c561a994610b691202bd5c'), 'age': 28, 'balance': 64},
#  {'_id': ObjectId('66c561a994610b691202bd5d'), 'age': 51, 'balance': 36},
#  {'_id': ObjectId('66c561a994610b691202bd5e'), 'age': 54, 'balance': 42},
#  {'_id': ObjectId('66c561a994610b691202bd62'), 'age': 41, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bd64'), 'age': 31, 'balance': 81},
#  {'_id': ObjectId('66c561a994610b691202bd68'), 'age': 54, 'balance': 51},
#  {'_id': ObjectId('66c561a994610b691202bd69'), 'age': 46, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bd6b'), 'age': 34, 'balance': 34},
#  {'_id': ObjectId('66c561a994610b691202bd70'), 'age': 25, 'balance': 54},
#  {'_id': ObjectId('66c561a994610b691202bd74'), 'age': 43, 'balance': 42},
#  {'_id': ObjectId('66c561a994610b691202bd78'), 'age': 57, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bd79'), 'age': 31, 'balance': -745},
#  {'_id': ObjectId('66c561a994610b691202bd7a'), 'age': 54, 'balance': 88},
#  {'_id': ObjectId('66c561a994610b691202bd86'), 'age': 40, 'balance': 59},
#  {'_id': ObjectId('66c561a994610b691202bd8d'), 'age': 42, 'balance': -32},
#  {'_id': ObjectId('66c561a994610b691202bd9b'), 'age': 44, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bd9d'), 'age': 43, 'balance': 17},
#  {'_id': ObjectId('66c561a994610b691202bda1'), 'age': 41, 'balance': 14},
#  {'_id': ObjectId('66c561a994610b691202bda4'), 'age': 52, 'balance': 26},
#  {'_id': ObjectId('66c561a994610b691202bda7'), 'age': 27, 'balance': -588},
#  {'_id': ObjectId('66c561a994610b691202bda9'), 'age': 60, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bdad'), 'age': 33, 'balance': -306},
#  {'_id': ObjectId('66c561a994610b691202bdb2'), 'age': 41, 'balance': -4},
#  {'_id': ObjectId('66c561a994610b691202bdb8'), 'age': 52, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bdb9'), 'age': 55, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bdbc'), 'age': 24, 'balance': -427},
#  {'_id': ObjectId('66c561a994610b691202bdbd'), 'age': 25, 'balance': 53},
#  {'_id': ObjectId('66c561a994610b691202bdbe'), 'age': 40, 'balance': 93},
#  {'_id': ObjectId('66c561a994610b691202bdc1'), 'age': 26, 'balance': -214},
#  {'_id': ObjectId('66c561a994610b691202bdc5'), 'age': 42, 'balance': -135},
#  {'_id': ObjectId('66c561a994610b691202bdc6'), 'age': 31, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bdc7'), 'age': 43, 'balance': 59},
#  {'_id': ObjectId('66c561a994610b691202bdc9'), 'age': 30, 'balance': 49},
#  {'_id': ObjectId('66c561a994610b691202bdca'), 'age': 23, 'balance': -213},
#  {'_id': ObjectId('66c561a994610b691202bdcf'), 'age': 33, 'balance': -15},
#  {'_id': ObjectId('66c561a994610b691202bdd5'), 'age': 29, 'balance': -44},
#  {'_id': ObjectId('66c561a994610b691202bddc'), 'age': 28, 'balance': 15},
#  {'_id': ObjectId('66c561a994610b691202bde0'), 'age': 59, 'balance': -278},
#  {'_id': ObjectId('66c561a994610b691202bde1'), 'age': 34, 'balance': -100},
#  {'_id': ObjectId('66c561a994610b691202bde2'), 'age': 43, 'balance': 15},
#  {'_id': ObjectId('66c561a994610b691202bde3'), 'age': 38, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202bde7'), 'age': 35, 'balance': 11},
#  {'_id': ObjectId('66c561a994610b691202bdea'), 'age': 24, 'balance': 32},
#  {'_id': ObjectId('66c561a994610b691202bdeb'), 'age': 35, 'balance': -123},
#  {'_id': ObjectId('66c561a994610b691202bdec'), 'age': 33, 'balance': -238},
#  {'_id': ObjectId('66c561a994610b691202bdfb'), 'age': 25, 'balance': 57},
#  {'_id': ObjectId('66c561a994610b691202be01'), 'age': 27, 'balance': 37},
#  {'_id': ObjectId('66c561a994610b691202be07'), 'age': 57, 'balance': 7},
#  {'_id': ObjectId('66c561a994610b691202be08'), 'age': 46, 'balance': 57},
#  {'_id': ObjectId('66c561a994610b691202be09'), 'age': 57, 'balance': 0},
#  {'_id': ObjectId('66c561a994610b691202be0e'), 'age': 42, 'balance': 43},
#  {'_id': ObjectId('66c561a994610b691202be18'), 'age': 25, 'balance': 53},
#  ...]

# %% [markdown]
# ## 3.21 Analyze the Relationship Between Campaign Duration and Outcome

# %%
db.customer.create_index({'duration':1, 'y':1})
# Out:
# 'duration_1_y_1'

# %%
list(
    db.customer.aggregate([
        {'$group': {'_id':['$y'], 'avgDuration':{'$avg':'$duration'}, 'maxDuration':{'$max':'$duration'}, 'minDuration':{'$min':'$duration'}}},
        {'$project': {'_id':1, 'avgDuration':1, 'maxDuration':1, 'minDuration':1}}
    ])
)
# Out:
# [{'_id': ['no'],
#   'avgDuration': 221.18280647262162,
#   'maxDuration': 4918,
#   'minDuration': 0},
#  {'_id': ['yes'],
#   'avgDuration': 537.2945736434109,
#   'maxDuration': 3881,
#   'minDuration': 8}]

# %% [markdown]
# ## 3.22 Detect Loan Trends Among Different Job Categories

# %%
db.customer.create_index({'job':1, 'loan':1})
# Out:
# 'job_1_loan_1'

# %%
list(
    db.customer.aggregate([
        {'$match': {'loan':'yes'}},
        {'$group': {'_id':'$job', 'avgBalance':{'$avg':'$balance'}, 'count':{'$sum':1}}},
        {'$sort': {'count':-1}}
    ])
)
# Out:
# [{'_id': 'blue-collar', 'avgBalance': 691.5700712589073, 'count': 1684},
#  {'_id': 'technician', 'avgBalance': 745.4598930481284, 'count': 1309},
#  {'_id': 'management', 'avgBalance': 965.7350359138069, 'count': 1253},
#  {'_id': 'admin.', 'avgBalance': 693.7941473259334, 'count': 991},
#  {'_id': 'services', 'avgBalance': 613.4425837320574, 'count': 836},
#  {'_id': 'entrepreneur', 'avgBalance': 1185.7780898876404, 'count': 356},
#  {'_id': 'retired', 'avgBalance': 887.0388349514564, 'count': 309},
#  {'_id': 'self-employed', 'avgBalance': 745.1397379912664, 'count': 229},
#  {'_id': 'housemaid', 'avgBalance': 793.9407894736842, 'count': 152},
#  {'_id': 'unemployed', 'avgBalance': 509.5045871559633, 'count': 109},
#  {'_id': 'student', 'avgBalance': 1101.8333333333333, 'count': 12},
#  {'_id': 'unknown', 'avgBalance': 482.5, 'count': 4}]

# %%
# insight: people with loans have lower profile job

# %% [markdown]
# ## 3.23 Identify the Most Common Outcomes for Married Individuals

# %%
list(
    db.customer.aggregate([
        {'$match': {'marital':'married'}},
        {'$group': {'_id':'$y', 'count':{'$sum':1}}},
    ])
)

# insight: for married individuals, outcome is yes for  2755 individuals and no for 24459 individuals.
# Out:
# [{'_id': 'no', 'count': 24459}, {'_id': 'yes', 'count': 2755}]

# %% [markdown]
# ## 3.24 Find the Distribution of Account Balances Across Different Education Levels

# %%
list(
    db.customer.aggregate([
        {'$group': {'_id':'$education', 'avgBalance':{'$avg':'$balance'}, 'count':{'$sum':1}}}
    ])
)
# Out:
# [{'_id': 'primary', 'avgBalance': 1250.9499343161583, 'count': 6851},
#  {'_id': 'tertiary', 'avgBalance': 1758.4164348545223, 'count': 13301},
#  {'_id': 'unknown', 'avgBalance': 1526.7544426494346, 'count': 1857},
#  {'_id': 'secondary', 'avgBalance': 1154.880786139126, 'count': 23202}]

# %% [markdown]
# ## 3.25 [DUPLICATE] How are account balances distributed among different education levels?

# %% [markdown]
# ## 3.26 Find ranking of Customers based on Account Balance.
