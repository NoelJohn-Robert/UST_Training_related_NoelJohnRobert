# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.0.2.15:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.8</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
sc.stop()

# %%
spark.stop()

# %%
from pyspark import SparkConf, SparkContext
# setMaster sets spark ContextManager which is loca[cpu cores]
config = SparkConf().setMaster('local[2]').setAppName("ETL Pipeline")
sc = SparkContext(conf=config)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('ETL Pipeline').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.0.2.15:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.8</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>ETL Pipeline</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
hremployeeDF = spark.read.format('jdbc')\
.option('url', 'jdbc:mysql://localhost:3306/hremployeedb')\
.option('dbtable', 'HR_Employee').option('user', 'root').option('password', 'hadoop@123')\
.option('driver', 'com.mysql.cj.jdbc.Driver').load()

# %%
hremployeeDF
# Out:
# DataFrame[EmployeeID: int, Department: string, JobRole: string, Attrition: string, Gender: string, Age: int, MaritalStatus: string, Education: string, EducationField: string, BusinessTravel: string, JobInvolvement: string, JobLevel: int, JobSatisfaction: string, Hourlyrate: int, Income: int, Salaryhike: int, OverTime: string, Workex: int, YearsSinceLastPromotion: int, EmpSatisfaction: string, TrainingTimesLastYear: int, WorkLifeBalance: string, Performance_Rating: string]

# %%
# show physical plan of execution, which is nkown as DAG
hremployeeDF.explain()
# Out:
# == Physical Plan ==
# *(1) Scan JDBCRelation(HR_Employee) [numPartitions=1] [EmployeeID#0,Department#1,JobRole#2,Attrition#3,Gender#4,Age#5,MaritalStatus#6,Education#7,EducationField#8,BusinessTravel#9,JobInvolvement#10,JobLevel#11,JobSatisfaction#12,Hourlyrate#13,Income#14,Salaryhike#15,OverTime#16,Workex#17,YearsSinceLastPromotion#18,EmpSatisfaction#19,TrainingTimesLastYear#20,WorkLifeBalance#21,Performance_Rating#22] PushedFilters: [], ReadSchema: struct<EmployeeID:int,Department:string,JobRole:string,Attrition:string,Gender:string,Age:int,Mar...

# %% [markdown]
# ### Materialized view of Table

# %%
hremployeeDF.createOrReplaceTempView('hremployee')

# %% [markdown]
# ### Q1: Display shape of hremployee table
# #### show number of rows and number of columns

# %%
#spark.sql("""
#    SELECT * FROM (
#        SELECT COUNT(*) AS rows FROM hremployee
#        SELECT COUNT(*) FROM INFORMATION_SCHEMA.COLUMNS WHERE type='table'
#    );
#""")

rows = spark.sql("""
    SELECT COUNT(*) AS rows FROM hremployee
""").show()

num_of_cols = len(hremployeeDF.columns)


print(rows)
print(num_of_cols)
# Out:
# +----+
# |rows|
# +----+
# |1469|
# +----+
#
# None
# 23

# %%
spark.sql(f"""
    SELECT COUNT(*) AS row_count, {num_of_cols} AS column_count FROM hremployee
""").show()
# Out:
# +---------+------------+
# |row_count|column_count|
# +---------+------------+
# |     1469|          23|
# +---------+------------+

# %% [raw]
# SELECT COUNT(*) FROM INFORMATION_SCHEMA.COLUMNS WHERE table_name = '???'

# %%
spark.sql('DESCRIBE hremployee').show(100)
# Out:
# +--------------------+---------+-------+
# |            col_name|data_type|comment|
# +--------------------+---------+-------+
# |          EmployeeID|      int|   null|
# |          Department|   string|   null|
# |             JobRole|   string|   null|
# |           Attrition|   string|   null|
# |              Gender|   string|   null|
# |                 Age|      int|   null|
# |       MaritalStatus|   string|   null|
# |           Education|   string|   null|
# |      EducationField|   string|   null|
# |      BusinessTravel|   string|   null|
# |      JobInvolvement|   string|   null|
# |            JobLevel|      int|   null|
# |     JobSatisfaction|   string|   null|
# |          Hourlyrate|      int|   null|
# |              Income|      int|   null|
# |          Salaryhike|      int|   null|
# |            OverTime|   string|   null|
# |              Workex|      int|   null|
# |YearsSinceLastPro...|      int|   null|
# |     EmpSatisfaction|   string|   null|
# |TrainingTimesLast...|      int|   null|
# |     WorkLifeBalance|   string|   null|
# |  Performance_Rating|   string|   null|
# +--------------------+---------+-------+

# %% [markdown]
# ### Q2: Write a query to show first 3 employee from each jobrole to join the company

# %%
spark.sql("""
    SELECT EmployeeID, JobRole, ranks AS Seniority_in_Department
    FROM (
        SELECT EmployeeID, JobRole,
        DENSE_RANK() OVER(PARTITION BY JobRole ORDER BY EmployeeID) as ranks
        FROM hremployee
    ) AS _
    WHERE ranks<=3
""").show(100)
# Out:
# +----------+--------------------+-----------------------+
# |EmployeeID|             JobRole|Seniority_in_Department|
# +----------+--------------------+-----------------------+
# |         1|     Sales Executive|                      1|
# |        28|     Sales Executive|                      2|
# |        40|     Sales Executive|                      3|
# |         9|Manufacturing Dir...|                      1|
# |        16|Manufacturing Dir...|                      2|
# |        21|Manufacturing Dir...|                      3|
# |         3|Laboratory Techni...|                      1|
# |         5|Laboratory Techni...|                      2|
# |         6|Laboratory Techni...|                      3|
# |        22|Sales Representative|                      1|
# |        34|Sales Representative|                      2|
# |        37|Sales Representative|                      3|
# |        10|Healthcare Repres...|                      1|
# |        29|Healthcare Repres...|                      2|
# |        32|Healthcare Repres...|                      3|
# |         2|  Research Scientist|                      1|
# |         4|  Research Scientist|                      2|
# |        13|  Research Scientist|                      3|
# |        19|             Manager|                      1|
# |        26|             Manager|                      2|
# |        30|             Manager|                      3|
# |        23|   Research Director|                      1|
# |        46|   Research Director|                      2|
# |        56|   Research Director|                      3|
# |        80|     Human Resources|                      1|
# |       101|     Human Resources|                      2|
# |       135|     Human Resources|                      3|
# +----------+--------------------+-----------------------+

# %% [markdown]
# ### Q3: Write a query to show top3 employees from each job role earning highest salary

# %%
spark.sql("""
    SELECT *
    FROM (
        SELECT EmployeeID, JobRole, Income,
        DENSE_RANK() OVER(PARTITION BY JobRole ORDER BY Income DESC) as ranks
        FROM hremployee
    ) AS _
    WHERE ranks<=3
""").show(30)
# Out:
# +----------+--------------------+------+-----+
# |EmployeeID|             JobRole|Income|ranks|
# +----------+--------------------+------+-----+
# |        99|     Sales Executive| 13872|    1|
# |       545|     Sales Executive| 13770|    2|
# |       839|     Sales Executive| 13758|    3|
# |       722|Manufacturing Dir...| 13973|    1|
# |       628|Manufacturing Dir...| 13826|    2|
# |       744|Manufacturing Dir...| 13726|    3|
# |       678|Laboratory Techni...|  7403|    1|
# |       817|Laboratory Techni...|  6782|    2|
# |       945|Laboratory Techni...|  6674|    3|
# |       565|Sales Representative|  6632|    1|
# |      1308|Sales Representative|  5405|    2|
# |      1220|Sales Representative|  4502|    3|
# |      1181|Healthcare Repres...| 13966|    1|
# |       317|Healthcare Repres...| 13964|    2|
# |       190|Healthcare Repres...| 13734|    3|
# |        68|  Research Scientist|  9724|    1|
# |      1315|  Research Scientist|  6962|    2|
# |      1305|  Research Scientist|  6854|    3|
# |       191|             Manager| 19999|    1|
# |       852|             Manager| 19943|    2|
# |       166|             Manager| 19926|    3|
# |       747|   Research Director| 19973|    1|
# |       899|   Research Director| 19740|    2|
# |      1010|   Research Director| 19701|    3|
# |       511|     Human Resources| 10725|    1|
# |       790|     Human Resources| 10482|    2|
# |       441|     Human Resources|  9950|    3|
# +----------+--------------------+------+-----+

# %% [markdown]
# ### Q4: Show top 3 highest package from overall Job role

# %%
spark.sql("""
    SELECT EmployeeID, JobRole, Income
    FROM hremployee
    ORDER BY Income DESC
""").show(3)
# Out:
# +----------+-----------------+------+
# |EmployeeID|          JobRole|Income|
# +----------+-----------------+------+
# |       191|          Manager| 19999|
# |       747|Research Director| 19973|
# |       852|          Manager| 19943|
# +----------+-----------------+------+
# only showing top 3 rows

# %% [markdown]
# ### Q5: Write a Spark SQL query to sho employees in ascending order wrt employee income compared to previous income for each job role

# %%
spark.sql("""
    SELECT EmployeeID, JobRole, Income, (Income-lagged_income) AS diff
    FROM (
        SELECT EmployeeID, JobRole, Income,
        LAG(Income, 1) OVER(PARTITION BY JobRole ORDER BY JobRole) as lagged_income
        FROM hremployee
        WHERE Income IS NOT NULL
    ) AS _
    ORDER BY JobRole,diff
""").show(2500)
# Out:
# +----------+--------------------+------+-----+
# |EmployeeID|             JobRole|Income| diff|
# +----------+--------------------+------+-----+
# |        10|Healthcare Repres...|  5237| null|
# |       285|Healthcare Repres...|  4741|-8755|
# |      1183|Healthcare Repres...|  6842|-7124|
# |      1157|Healthcare Repres...|  4148|-7097|
# |       205|Healthcare Repres...|  6673|-7061|
# |       677|Healthcare Repres...|  4014|-6538|
# |       397|Healthcare Repres...|  4522|-6443|
# |       833|Healthcare Repres...|  5731|-6438|
# |      1065|Healthcare Repres...|  4035|-6431|
# |       745|Healthcare Repres...|  4777|-6222|
# |       736|Healthcare Repres...|  4240|-6148|
# |      1098|Healthcare Repres...|  4069|-6055|
# |        89|Healthcare Repres...|  4152|-5944|
# |       489|Healthcare Repres...|  4089|-5735|
# |       929|Healthcare Repres...|  7978|-5599|
# |       105|Healthcare Repres...|  5163|-5510|
# |       267|Healthcare Repres...|  5582|-5356|
# |      1231|Healthcare Repres...|  5562|-5186|
# |       555|Healthcare Repres...|  6811|-4292|
# |      1045|Healthcare Repres...|  6651|-4200|
# |       527|Healthcare Repres...|  4553|-4068|
# |       334|Healthcare Repres...|  9985|-3979|
# |       373|Healthcare Repres...|  6540|-3956|
# |       309|Healthcare Repres...|  5660|-3953|
# |      1131|Healthcare Repres...|  5063|-3790|
# |        32|Healthcare Repres...|  6465|-3783|
# |      1425|Healthcare Repres...|  4878|-3755|
# |      1008|Healthcare Repres...|  7553|-3367|
# |       357|Healthcare Repres...|  6781|-3204|
# |       791|Healthcare Repres...|  7119|-3203|
# |       460|Healthcare Repres...|  6811|-3013|
# |      1214|Healthcare Repres...|  7879|-3004|
# |      1407|Healthcare Repres...|  4617|-2893|
# |        94|Healthcare Repres...| 10673|-2830|
# |      1287|Healthcare Repres...|  5538|-2783|
# |      1299|Healthcare Repres...|  6513|-2413|
# |       768|Healthcare Repres...|  4107|-2278|
# |       979|Healthcare Repres...|  6377|-2123|
# |      1304|Healthcare Repres...|  4448|-2065|
# |       209|Healthcare Repres...|  4876|-1797|
# |       558|Healthcare Repres...|  5093|-1718|
# |       268|Healthcare Repres...|  4000|-1582|
# |      1199|Healthcare Repres...|  5347|-1495|
# |       550|Healthcare Repres...|  6142|-1483|
# |       716|Healthcare Repres...|  5488|-1461|
# |      1352|Healthcare Repres...|  5033|-1351|
# |      1123|Healthcare Repres...|  6142|-1299|
# |      1259|Healthcare Repres...|  5294|-1000|
# |       943|Healthcare Repres...|  7094| -884|
# |       164|Healthcare Repres...|  9439| -873|
# |       573|Healthcare Repres...|  4335| -758|
# |       472|Healthcare Repres...|  9824| -703|
# |      1398|Healthcare Repres...|  5968| -699|
# |      1456|Healthcare Repres...|  5689| -617|
# |       848|Healthcare Repres...|  5343| -388|
# |       651|Healthcare Repres...|  5562| -371|
# |       618|Healthcare Repres...|  5933| -355|
# |       904|Healthcare Repres...|  6623| -189|
# |       583|Healthcare Repres...|  4244|  -91|
# |       303|Healthcare Repres...|  5661|  -84|
# |       361|Healthcare Repres...|  6755|  -26|
# |      1387|Healthcare Repres...|  5373|  -26|
# |       897|Healthcare Repres...|  6812|  -21|
# |       414|Healthcare Repres...|  4523|    1|
# |       785|Healthcare Repres...|  8823|  101|
# |        65|Healthcare Repres...| 10096|  212|
# |       984|Healthcare Repres...|  6687|  310|
# |      1362|Healthcare Repres...|  5399|  366|
# |      1093|Healthcare Repres...| 10124|  409|
# |      1261|Healthcare Repres...|  5811|  517|
# |       795|Healthcare Repres...|  7756|  637|
# |      1250|Healthcare Repres...|  6294|  732|
# |       525|Healthcare Repres...|  8621|  896|
# |       288|Healthcare Repres...|  5745| 1004|
# |       665|Healthcare Repres...|  6586| 1024|
# |       695|Healthcare Repres...|  6949| 1094|
# |      1090|Healthcare Repres...|  9715| 1109|
# |      1388|Healthcare Repres...|  6667| 1294|
# |      1294|Healthcare Repres...|  6870| 1332|
# |       959|Healthcare Repres...|  8500| 1406|
# |      1441|Healthcare Repres...|  6306| 1428|
# |       896|Healthcare Repres...|  6833| 1490|
# |       786|Healthcare Repres...| 10322| 1499|
# |      1399|Healthcare Repres...|  7510| 1542|
# |       252|Healthcare Repres...| 10938| 1542|
# |       746|Healthcare Repres...|  6385| 1608|
# |      1203|Healthcare Repres...|  7005| 1658|
# |       814|Healthcare Repres...| 12169| 1724|
# |       691|Healthcare Repres...|  5855| 1841|
# |      1324|Healthcare Repres...|  6384| 1936|
# |       606|Healthcare Repres...|  6288| 2044|
# |      1298|Healthcare Repres...|  8926| 2056|
# |       440|Healthcare Repres...|  9824| 2192|
# |      1081|Healthcare Repres...|  8606| 2218|
# |       111|Healthcare Repres...|  7484| 2321|
# |      1074|Healthcare Repres...|  6388| 2353|
# |      1278|Healthcare Repres...|  8321| 2510|
# |       807|Healthcare Repres...| 10445| 2689|
# |      1125|Healthcare Repres...|  8853| 2711|
# |       127|Healthcare Repres...| 10312| 2828|
# |      1221|Healthcare Repres...| 10748| 2869|
# |       530|Healthcare Repres...|  7625| 3072|
# |       439|Healthcare Repres...|  7632| 3109|
# |      1035|Healthcare Repres...| 10851| 3298|
# |      1099|Healthcare Repres...|  7441| 3372|
# |        54|Healthcare Repres...|  9884| 3419|
# |       510|Healthcare Repres...|  7725| 3636|
# |       466|Healthcare Repres...| 10527| 3716|
# |       368|Healthcare Repres...| 10496| 3741|
# |      1055|Healthcare Repres...| 10466| 3815|
# |      1173|Healthcare Repres...|  8008| 3860|
# |      1209|Healthcare Repres...| 10883| 3878|
# |       305|Healthcare Repres...|  9613| 3952|
# |       675|Healthcare Repres...| 10552| 3966|
# |      1414|Healthcare Repres...|  8633| 4016|
# |       993|Healthcare Repres...| 10920| 4233|
# |       190|Healthcare Repres...| 13734| 4295|
# |      1466|Healthcare Repres...|  9991| 4302|
# |       376|Healthcare Repres...| 10965| 4425|
# |       210|Healthcare Repres...|  9396| 4520|
# |       781|Healthcare Repres...|  8722| 4615|
# |       730|Healthcare Repres...| 10388| 4900|
# |       553|Healthcare Repres...| 11103| 4961|
# |        29|Healthcare Repres...| 10248| 5011|
# |      1181|Healthcare Repres...| 13966| 5958|
# |      1138|Healthcare Repres...| 11245| 6182|
# |       737|Healthcare Repres...| 10999| 6759|
# |       915|Healthcare Repres...| 13577| 6954|
# |       317|Healthcare Repres...| 13964| 8304|
# |        91|Healthcare Repres...| 13503| 9351|
# |       269|Healthcare Repres...| 13496| 9496|
# |        80|     Human Resources|  5021| null|
# |       827|     Human Resources|  2844|-7638|
# |      1245|     Human Resources|  2145|-7611|
# |       454|     Human Resources|  2741|-7209|
# |      1036|     Human Resources|  2109|-5879|
# |       552|     Human Resources|  6389|-4336|
# |       600|     Human Resources|  2143|-4246|
# |       233|     Human Resources|  2267|-4080|
# |       351|     Human Resources|  2696|-3714|
# |       101|     Human Resources|  2073|-2948|
# |       656|     Human Resources|  2277|-2927|
# |       634|     Human Resources|  2342|-2594|
# |      1200|     Human Resources|  3195|-2548|
# |       924|     Human Resources|  4490|-1782|
# |      1222|     Human Resources|  1555|-1640|
# |      1289|     Human Resources|  2592|-1479|
# |       944|     Human Resources|  3423|-1067|
# |      1379|     Human Resources|  2863|-1023|
# |      1411|     Human Resources|  2187| -804|
# |       864|     Human Resources|  3600| -723|
# |      1064|     Human Resources|  2064| -678|
# |      1313|     Human Resources|  2335| -621|
# |      1297|     Human Resources|  2148| -444|
# |      1165|     Human Resources|  5743| -334|
# |       423|     Human Resources|  2564| -132|
# |       760|     Human Resources|  2177| -100|
# |      1246|     Human Resources|  2180|   35|
# |      1329|     Human Resources|  2804|   98|
# |      1400|     Human Resources|  2991|  128|
# |      1323|     Human Resources|  2706|  371|
# |      1280|     Human Resources|  4071|  532|
# |      1040|     Human Resources|  2742|  633|
# |      1312|     Human Resources|  2956|  808|
# |       135|     Human Resources|  2942|  869|
# |      1347|     Human Resources|  3886| 1082|
# |       630|     Human Resources|  4936| 1199|
# |      1269|     Human Resources|  3539| 1359|
# |       836|     Human Resources|  4323| 1479|
# |       614|     Human Resources|  3737| 1594|
# |       879|     Human Resources|  6272| 2672|
# |       655|     Human Resources|  5204| 2862|
# |       494|     Human Resources|  5985| 3244|
# |      1243|     Human Resources|  9756| 3326|
# |       140|     Human Resources|  6347| 3405|
# |      1107|     Human Resources|  6077| 4013|
# |       311|     Human Resources|  6410| 4143|
# |      1006|     Human Resources|  7988| 4565|
# |       511|     Human Resources| 10725| 4740|
# |      1228|     Human Resources|  6430| 4875|
# |      1450|     Human Resources|  8837| 6650|
# |       441|     Human Resources|  9950| 7386|
# |       790|     Human Resources| 10482| 8305|
# |         3|Laboratory Techni...|  2090| null|
# |       683|Laboratory Techni...|  2332|-5071|
# |       954|Laboratory Techni...|  2362|-4312|
# |      1256|Laboratory Techni...|  2468|-4004|
# |        62|Laboratory Techni...|  2406|-3509|
# |       778|Laboratory Techni...|  1416|-3418|
# |       114|Laboratory Techni...|  2774|-3300|
# |       337|Laboratory Techni...|  2119|-3138|
# |        88|Laboratory Techni...|  2075|-3051|
# |       506|Laboratory Techni...|  2659|-3020|
# |      1097|Laboratory Techni...|  2296|-2911|
# |       316|Laboratory Techni...|  2455|-2755|
# |       231|Laboratory Techni...|  3212|-2702|
# |      1302|Laboratory Techni...|  2705|-2641|
# |      1412|Laboratory Techni...|  3748|-2575|
# |      1147|Laboratory Techni...|  3211|-2558|
# |       825|Laboratory Techni...|  4272|-2510|
# |      1001|Laboratory Techni...|  2950|-2479|
# |       657|Laboratory Techni...|  2795|-2436|
# |       794|Laboratory Techni...|  2207|-2414|
# |       829|Laboratory Techni...|  1904|-2368|
# |       417|Laboratory Techni...|  1702|-2329|
# |      1023|Laboratory Techni...|  3500|-2310|
# |       922|Laboratory Techni...|  2154|-2290|
# |       632|Laboratory Techni...|  2818|-2276|
# |       287|Laboratory Techni...|  3161|-2254|
# |       586|Laboratory Techni...|  1601|-2232|
# |       688|Laboratory Techni...|  2519|-2202|
# |      1134|Laboratory Techni...|  2690|-2186|
# |      1018|Laboratory Techni...|  2099|-2185|
# |       714|Laboratory Techni...|  2270|-2177|
# |       832|Laboratory Techni...|  2610|-2156|
# |      1130|Laboratory Techni...|  3407|-2155|
# |      1343|Laboratory Techni...|  2062|-2135|
# |       849|Laboratory Techni...|  2376|-2044|
# |       178|Laboratory Techni...|  1102|-1970|
# |      1415|Laboratory Techni...|  2008|-1969|
# |      1210|Laboratory Techni...|  2028|-1958|
# |        52|Laboratory Techni...|  3441|-1940|
# |      1205|Laboratory Techni...|  1393|-1913|
# |        50|Laboratory Techni...|  2269|-1742|
# |      1321|Laboratory Techni...|  2105|-1707|
# |       204|Laboratory Techni...|  2741|-1684|
# |       352|Laboratory Techni...|  2370|-1613|
# |      1072|Laboratory Techni...|  3180|-1609|
# |       743|Laboratory Techni...|  2380|-1537|
# |        14|Laboratory Techni...|  2661|-1532|
# |       241|Laboratory Techni...|  2232|-1498|
# |       147|Laboratory Techni...|  2720|-1480|
# |      1465|Laboratory Techni...|  2571|-1454|
# |      1361|Laboratory Techni...|  2544|-1434|
# |       464|Laboratory Techni...|  2340|-1415|
# |       516|Laboratory Techni...|  1281|-1378|
# |       733|Laboratory Techni...|  2422|-1321|
# |       442|Laboratory Techni...|  2093|-1315|
# |       798|Laboratory Techni...|  2377|-1314|
# |      1273|Laboratory Techni...|  2398|-1304|
# |       968|Laboratory Techni...|  2387|-1282|
# |      1068|Laboratory Techni...|  2561|-1277|
# |      1402|Laboratory Techni...|  1129|-1238|
# |       551|Laboratory Techni...|  2500|-1208|
# |       396|Laboratory Techni...|  2258|-1190|
# |       843|Laboratory Techni...|  2515|-1082|
# |       931|Laboratory Techni...|  2838|-1029|
# |      1155|Laboratory Techni...|  3069| -997|
# |       872|Laboratory Techni...|  2210| -986|
# |       297|Laboratory Techni...|  1420| -953|
# |       572|Laboratory Techni...|  4364| -945|
# |      1082|Laboratory Techni...|  2272| -908|
# |      1171|Laboratory Techni...|  2166| -903|
# |       590|Laboratory Techni...|  2319| -830|
# |       289|Laboratory Techni...|  2373| -788|
# |       387|Laboratory Techni...|  3034| -782|
# |       235|Laboratory Techni...|  2436| -776|
# |       973|Laboratory Techni...|  1611| -776|
# |       150|Laboratory Techni...|  1483| -755|
# |       881|Laboratory Techni...|  2743| -748|
# |       261|Laboratory Techni...|  2794| -685|
# |      1202|Laboratory Techni...|  3306| -683|
# |      1224|Laboratory Techni...|  2305| -669|
# |        15|Laboratory Techni...|  2028| -633|
# |       263|Laboratory Techni...|  2176| -618|
# |      1238|Laboratory Techni...|  3295| -612|
# |       208|Laboratory Techni...|  2153| -588|
# |      1043|Laboratory Techni...|  3162| -560|
# |       582|Laboratory Techni...|  3833| -531|
# |       406|Laboratory Techni...|  4031| -527|
# |       638|Laboratory Techni...|  2314| -504|
# |      1060|Laboratory Techni...|  3172| -501|
# |      1390|Laboratory Techni...|  2367| -500|
# |       149|Laboratory Techni...|  2238| -482|
# |      1266|Laboratory Techni...|  2289| -477|
# |       312|Laboratory Techni...|  5210| -464|
# |       389|Laboratory Techni...|  2576| -458|
# |       432|Laboratory Techni...|  3780| -450|
# |        31|Laboratory Techni...|  2496| -439|
# |      1427|Laboratory Techni...|  2406| -431|
# |      1004|Laboratory Techni...|  3229| -400|
# |         6|Laboratory Techni...|  3068| -400|
# |         7|Laboratory Techni...|  2670| -398|
# |       672|Laboratory Techni...|  2008| -396|
# |      1110|Laboratory Techni...|  2074| -376|
# |       670|Laboratory Techni...|  2404| -374|
# |       437|Laboratory Techni...|  3408| -372|
# |       841|Laboratory Techni...|  2258| -352|
# |      1033|Laboratory Techni...|  3646| -329|
# |      1317|Laboratory Techni...|  2379| -326|
# |       129|Laboratory Techni...|  2523| -312|
# |        33|Laboratory Techni...|  2206| -290|
# |      1136|Laboratory Techni...|  2408| -282|
# |       270|Laboratory Techni...|  3210| -275|
# |        11|Laboratory Techni...|  2426| -267|
# |       658|Laboratory Techni...|  2532| -263|
# |       173|Laboratory Techni...|  2088| -260|
# |       942|Laboratory Techni...|  4627| -256|
# |        41|Laboratory Techni...|  1951| -255|
# |      1083|Laboratory Techni...|  2018| -254|
# |       477|Laboratory Techni...|  2127| -213|
# |      1028|Laboratory Techni...|  3294| -206|
# |       902|Laboratory Techni...|  2559| -184|
# |       362|Laboratory Techni...|  2213| -157|
# |      1180|Laboratory Techni...|  2013| -153|
# |       661|Laboratory Techni...|  2380| -152|
# |      1193|Laboratory Techni...|  2440| -147|
# |       450|Laboratory Techni...|  3755| -139|
# |       857|Laboratory Techni...|  3033|  -98|
# |      1444|Laboratory Techni...|  2339|  -67|
# |       110|Laboratory Techni...|  2871|  -55|
# |       557|Laboratory Techni...|  2450|  -50|
# |        43|Laboratory Techni...|  2293|  -48|
# |       400|Laboratory Techni...|  2218|  -40|
# |       100|Laboratory Techni...|  2042|  -33|
# |         8|Laboratory Techni...|  2693|   23|
# |       735|Laboratory Techni...|  2451|   29|
# |      1386|Laboratory Techni...|  2867|   57|
# |       119|Laboratory Techni...|  2835|   61|
# |       916|Laboratory Techni...|  2625|   66|
# |       980|Laboratory Techni...|  5429|   66|
# |      1037|Laboratory Techni...|  3722|   76|
# |       726|Laboratory Techni...|  3743|  110|
# |      1108|Laboratory Techni...|  2450|  154|
# |       869|Laboratory Techni...|  3196|  163|
# |      1426|Laboratory Techni...|  2837|  177|
# |       801|Laboratory Techni...|  2596|  219|
# |      1341|Laboratory Techni...|  4197|  229|
# |      1413|Laboratory Techni...|  3977|  229|
# |      1383|Laboratory Techni...|  2810|  266|
# |       237|Laboratory Techni...|  2707|  271|
# |      1263|Laboratory Techni...|  2766|  298|
# |      1005|Laboratory Techni...|  3578|  349|
# |       257|Laboratory Techni...|  2593|  361|
# |       753|Laboratory Techni...|  2743|  363|
# |       374|Laboratory Techni...|  3816|  364|
# |      1095|Laboratory Techni...|  5207|  366|
# |        42|Laboratory Techni...|  2341|  390|
# |       420|Laboratory Techni...|  2097|  395|
# |       668|Laboratory Techni...|  2778|  398|
# |      1230|Laboratory Techni...|  3907|  430|
# |       690|Laboratory Techni...|  2973|  454|
# |       588|Laboratory Techni...|  3149|  455|
# |       427|Laboratory Techni...|  2564|  467|
# |       544|Laboratory Techni...|  3708|  487|
# |       933|Laboratory Techni...|  3339|  501|
# |      1051|Laboratory Techni...|  3673|  511|
# |      1354|Laboratory Techni...|  2587|  525|
# |       874|Laboratory Techni...|  2741|  531|
# |       718|Laboratory Techni...|  2811|  541|
# |        58|Laboratory Techni...|  4014|  573|
# |      1192|Laboratory Techni...|  2587|  574|
# |        75|Laboratory Techni...|  3038|  632|
# |      1422|Laboratory Techni...|  2660|  652|
# |      1066|Laboratory Techni...|  3838|  666|
# |       787|Laboratory Techni...|  4621|  666|
# |      1002|Laboratory Techni...|  3629|  679|
# |      1030|Laboratory Techni...|  3975|  681|
# |      1007|Laboratory Techni...|  4284|  706|
# |       197|Laboratory Techni...|  4425|  735|
# |       875|Laboratory Techni...|  3491|  750|
# |       853|Laboratory Techni...|  3131|  755|
# |       480|Laboratory Techni...|  2886|  759|
# |       484|Laboratory Techni...|  3681|  795|
# |       762|Laboratory Techni...|  4834|  809|
# |       719|Laboratory Techni...|  3633|  822|
# |      1128|Laboratory Techni...|  5562|  839|
# |       641|Laboratory Techni...|  3162|  848|
# |      1149|Laboratory Techni...|  4066|  855|
# |       154|Laboratory Techni...|  2348|  865|
# |       392|Laboratory Techni...|  3448|  872|
# |       103|Laboratory Techni...|  2926|  884|
# |       260|Laboratory Techni...|  3479|  886|
# |        18|Laboratory Techni...|  2935|  907|
# |      1219|Laboratory Techni...|  2974|  946|
# |      1286|Laboratory Techni...|  3377|  979|
# |       174|Laboratory Techni...|  3072|  984|
# |       240|Laboratory Techni...|  3730| 1023|
# |       587|Laboratory Techni...|  2694| 1093|
# |      1227|Laboratory Techni...|  3477| 1172|
# |      1206|Laboratory Techni...|  2570| 1177|
# |       180|Laboratory Techni...|  2288| 1186|
# |       365|Laboratory Techni...|  3452| 1239|
# |       757|Laboratory Techni...|  4025| 1282|
# |       966|Laboratory Techni...|  3669| 1307|
# |       265|Laboratory Techni...|  3485| 1309|
# |       842|Laboratory Techni...|  3597| 1339|
# |         5|Laboratory Techni...|  3468| 1378|
# |      1360|Laboratory Techni...|  3978| 1391|
# |       184|Laboratory Techni...|  3690| 1402|
# |      1272|Laboratory Techni...|  3702| 1413|
# |      1208|Laboratory Techni...|  3986| 1416|
# |      1318|Laboratory Techni...|  3812| 1433|
# |       741|Laboratory Techni...|  3917| 1466|
# |      1133|Laboratory Techni...|  4876| 1469|
# |       697|Laboratory Techni...|  4447| 1474|
# |       797|Laboratory Techni...|  3691| 1484|
# |      1408|Laboratory Techni...|  2647| 1518|
# |       940|Laboratory Techni...|  4883| 1544|
# |      1201|Laboratory Techni...|  3989| 1549|
# |       431|Laboratory Techni...|  4230| 1666|
# |       141|Laboratory Techni...|  4200| 1677|
# |      1459|Laboratory Techni...|  4025| 1686|
# |       930|Laboratory Techni...|  3867| 1713|
# |        45|Laboratory Techni...|  4011| 1718|
# |        12|Laboratory Techni...|  4193| 1767|
# |       444|Laboratory Techni...|  3894| 1801|
# |       921|Laboratory Techni...|  4444| 1819|
# |      1469|Laboratory Techni...|  4404| 1833|
# |      1325|Laboratory Techni...|  3968| 1863|
# |       338|Laboratory Techni...|  3983| 1864|
# |        59|Laboratory Techni...|  5915| 1901|
# |       844|Laboratory Techni...|  4420| 1905|
# |       524|Laboratory Techni...|  3221| 1940|
# |      1290|Laboratory Techni...|  5346| 1969|
# |       306|Laboratory Techni...|  5674| 1986|
# |       492|Laboratory Techni...|  5679| 1998|
# |       945|Laboratory Techni...|  6674| 2047|
# |       644|Laboratory Techni...|  5231| 2069|
# |        81|Laboratory Techni...|  5126| 2088|
# |       284|Laboratory Techni...|  5415| 2205|
# |      1071|Laboratory Techni...|  4789| 2228|
# |       299|Laboratory Techni...|  3688| 2268|
# |       405|Laboratory Techni...|  4558| 2340|
# |       687|Laboratory Techni...|  4721| 2389|
# |       782|Laboratory Techni...|  3955| 2539|
# |      1122|Laboratory Techni...|  4723| 2649|
# |       602|Laboratory Techni...|  5094| 2775|
# |       331|Laboratory Techni...|  5257| 2802|
# |      1088|Laboratory Techni...|  4841| 2823|
# |       559|Laboratory Techni...|  5309| 2859|
# |       831|Laboratory Techni...|  4766| 2862|
# |        51|Laboratory Techni...|  5381| 3112|
# |      1240|Laboratory Techni...|  6472| 3177|
# |       112|Laboratory Techni...|  6074| 3203|
# |      1142|Laboratory Techni...|  5769| 3361|
# |      1409|Laboratory Techni...|  6323| 3676|
# |      1019|Laboratory Techni...|  5810| 3711|
# |       974|Laboratory Techni...|  5363| 3752|
# |       221|Laboratory Techni...|  5914| 3761|
# |       817|Laboratory Techni...|  6782| 4186|
# |       678|Laboratory Techni...|  7403| 5395|
# |        19|             Manager| 15427| null|
# |       272|             Manager| 11849|-7196|
# |       353|             Manager| 12504|-6768|
# |      1275|             Manager| 13116|-6717|
# |       759|             Manager| 11904|-5746|
# |       117|             Manager| 11631|-5697|
# |       963|             Manager| 14026|-5691|
# |      1075|             Manager| 11244|-5555|
# |       457|             Manager| 11557|-5278|
# |       949|             Manager| 11916|-5207|
# |      1166|             Manager| 15202|-4456|
# |        66|             Manager| 14756|-4191|
# |       314|             Manager| 11878|-4137|
# |       425|             Manager| 14118|-3923|
# |       236|             Manager| 16064|-3453|
# |       436|             Manager| 13610|-3436|
# |       195|             Manager| 16792|-3207|
# |       216|             Manager| 13591|-3201|
# |       493|             Manager| 15402|-2798|
# |       409|             Manager| 16555|-2642|
# |      1348|             Manager| 16823|-2569|
# |       562|             Manager| 16856|-2333|
# |       264|             Manager| 16872|-2330|
# |       702|             Manager| 14852|-2247|
# |       756|             Manager| 17650|-2195|
# |      1135|             Manager| 17567|-2046|
# |       593|             Manager| 16752|-1678|
# |       862|             Manager| 17048|-1558|
# |       418|             Manager| 18041|-1525|
# |       113|             Manager| 17328|-1516|
# |      1194|             Manager| 15972|-1454|
# |       585|             Manager| 18430|-1429|
# |       859|             Manager| 18606|-1337|
# |       937|             Manager| 18061|-1129|
# |       938|             Manager| 17123| -938|
# |       187|             Manager| 19033| -893|
# |       700|             Manager| 17099| -825|
# |       805|             Manager| 16885| -780|
# |       923|             Manager| 19190| -657|
# |      1195|             Manager| 15379| -593|
# |      1443|             Manager| 18880| -551|
# |       908|             Manager| 18213| -498|
# |       617|             Manager| 16307| -445|
# |       536|             Manager| 19141| -372|
# |      1126|             Manager| 19331| -255|
# |      1437|             Manager| 19431| -205|
# |      1096|             Manager| 16437| -169|
# |        30|             Manager| 18947| -147|
# |       917|             Manager| 18789|  -35|
# |       539|             Manager| 19189|   48|
# |       245|             Manager| 19202|  134|
# |       277|             Manager| 11996|  147|
# |       148|             Manager| 17181|  222|
# |      1129|             Manager| 19613|  282|
# |       234|             Manager| 19517|  285|
# |      1351|             Manager| 17174|  351|
# |       957|             Manager| 19717|  530|
# |      1080|             Manager| 16606|  574|
# |       811|             Manager| 17465|  580|
# |       914|             Manager| 18824|  611|
# |      1374|             Manager| 17875|  701|
# |       868|             Manager| 17856|  808|
# |       900|             Manager| 18711|  855|
# |       742|             Manager| 18303|  859|
# |       800|             Manager| 17665|  909|
# |       191|             Manager| 19999|  966|
# |       919|             Manager| 19847| 1058|
# |       956|             Manager| 19187| 1326|
# |       750|             Manager| 19845| 1542|
# |       478|             Manager| 18200| 1605|
# |       654|             Manager| 17924| 1617|
# |      1401|             Manager| 19636| 1761|
# |      1154|             Manager| 19658| 2091|
# |       271|             Manager| 19045| 2173|
# |       327|             Manager| 19272| 2204|
# |      1184|             Manager| 17426| 2224|
# |       852|             Manager| 19943| 2478|
# |       401|             Manager| 19197| 2538|
# |       711|             Manager| 17444| 2592|
# |       166|             Manager| 19926| 2745|
# |      1000|             Manager| 16799| 2773|
# |       426|             Manager| 17046| 2928|
# |       569|             Manager| 19859| 3003|
# |       238|             Manager| 19068| 3004|
# |       412|             Manager| 19566| 3011|
# |      1330|             Manager| 19392| 3101|
# |      1116|             Manager| 19586| 3149|
# |      1301|             Manager| 16291| 3175|
# |       446|             Manager| 16835| 3225|
# |        26|             Manager| 19094| 3667|
# |       301|             Manager| 16015| 4019|
# |       106|             Manager| 18844| 4088|
# |       498|             Manager| 19513| 4111|
# |       380|             Manager| 16659| 4155|
# |      1242|             Manager| 19833| 4454|
# |      1076|             Manager| 16032| 4788|
# |       775|             Manager| 16756| 4852|
# |       467|             Manager| 16595| 5038|
# |       315|             Manager| 17068| 5190|
# |       120|             Manager| 16959| 5328|
# |       232|             Manager| 19232| 5641|
# |       955|             Manager| 17861| 5945|
# |         9|Manufacturing Dir...|  9526| null|
# |       631|Manufacturing Dir...|  4775|-9051|
# |       740|Manufacturing Dir...|  4227|-8515|
# |       986|Manufacturing Dir...|  6179|-7223|
# |      1288|Manufacturing Dir...|  5762|-7203|
# |       725|Manufacturing Dir...|  4377|-6468|
# |       156|Manufacturing Dir...|  4319|-6331|
# |       662|Manufacturing Dir...|  4765|-6138|
# |        21|Manufacturing Dir...|  4011|-5969|
# |       452|Manufacturing Dir...|  7406|-5831|
# |      1112|Manufacturing Dir...|  4855|-5314|
# |       734|Manufacturing Dir...|  5472|-5267|
# |      1406|Manufacturing Dir...|  4440|-5239|
# |       256|Manufacturing Dir...|  4898|-5150|
# |       928|Manufacturing Dir...|  5410|-5102|
# |      1158|Manufacturing Dir...|  5768|-4667|
# |       225|Manufacturing Dir...|  4345|-4129|
# |      1091|Manufacturing Dir...|  4320|-4056|
# |      1003|Manufacturing Dir...|  9362|-3885|
# |       856|Manufacturing Dir...|  6474|-3800|
# |      1467|Manufacturing Dir...|  6142|-3794|
# |      1345|Manufacturing Dir...|  4788|-3790|
# |       823|Manufacturing Dir...|  4033|-3746|
# |      1073|Manufacturing Dir...|  6549|-3660|
# |      1463|Manufacturing Dir...|  9936|-3634|
# |       193|Manufacturing Dir...|  5916|-3631|
# |       810|Manufacturing Dir...|  7655|-3321|
# |       455|Manufacturing Dir...|  4262|-3144|
# |       724|Manufacturing Dir...| 10845|-3128|
# |       818|Manufacturing Dir...|  7779|-3041|
# |       754|Manufacturing Dir...| 10880|-2846|
# |       561|Manufacturing Dir...|  5121|-2740|
# |      1174|Manufacturing Dir...|  5206|-2739|
# |       341|Manufacturing Dir...|  6347|-2596|
# |       605|Manufacturing Dir...|  4434|-2443|
# |       970|Manufacturing Dir...|  7898|-2110|
# |        76|Manufacturing Dir...|  4424|-2075|
# |       347|Manufacturing Dir...|  6032|-2063|
# |       774|Manufacturing Dir...|  8858|-2022|
# |       201|Manufacturing Dir...|  4298|-1963|
# |      1034|Manufacturing Dir...|  7446|-1916|
# |       411|Manufacturing Dir...|  6091|-1878|
# |      1322|Manufacturing Dir...|  8578|-1755|
# |       185|Manufacturing Dir...|  4450|-1682|
# |       708|Manufacturing Dir...|  5067|-1658|
# |      1239|Manufacturing Dir...|  5238|-1645|
# |       136|Manufacturing Dir...|  4941|-1626|
# |      1291|Manufacturing Dir...|  4213|-1549|
# |       531|Manufacturing Dir...|  7412|-1435|
# |       413|Manufacturing Dir...|  4810|-1281|
# |       390|Manufacturing Dir...|  4197|-1061|
# |       473|Manufacturing Dir...|  6447|-1044|
# |       543|Manufacturing Dir...|  7861| -932|
# |      1182|Manufacturing Dir...|  4374| -921|
# |       300|Manufacturing Dir...|  5482| -915|
# |       366|Manufacturing Dir...|  5258| -774|
# |      1372|Manufacturing Dir...|  5151| -755|
# |       594|Manufacturing Dir...|  5228| -752|
# |      1159|Manufacturing Dir...|  5042| -726|
# |       932|Manufacturing Dir...|  4695| -715|
# |       130|Manufacturing Dir...|  6567| -693|
# |       198|Manufacturing Dir...|  5265| -651|
# |       667|Manufacturing Dir...|  4171| -594|
# |       512|Manufacturing Dir...|  8847| -587|
# |      1151|Manufacturing Dir...|  4877| -500|
# |       738|Manufacturing Dir...|  5003| -469|
# |       200|Manufacturing Dir...|  6261| -292|
# |       727|Manufacturing Dir...|  4148| -229|
# |      1145|Manufacturing Dir...|  4663| -192|
# |      1440|Manufacturing Dir...|  5131| -190|
# |       950|Manufacturing Dir...|  4534| -161|
# |        85|Manufacturing Dir...|  4325|  -99|
# |       920|Manufacturing Dir...| 10512|   10|
# |      1146|Manufacturing Dir...|  4724|   61|
# |      1175|Manufacturing Dir...|  5295|   89|
# |       601|Manufacturing Dir...|  6162|  100|
# |       395|Manufacturing Dir...|  4306|  109|
# |        61|Manufacturing Dir...|  6162|  169|
# |      1164|Manufacturing Dir...|  7945|  189|
# |       648|Manufacturing Dir...| 10903|  218|
# |       891|Manufacturing Dir...| 10502|  250|
# |       429|Manufacturing Dir...|  5070|  260|
# |       977|Manufacturing Dir...| 13402|  260|
# |        67|Manufacturing Dir...|  6499|  337|
# |       576|Manufacturing Dir...|  5485|  364|
# |      1232|Manufacturing Dir...|  6883|  367|
# |        16|Manufacturing Dir...|  9980|  454|
# |       250|Manufacturing Dir...|  6434|  477|
# |       579|Manufacturing Dir...|  5980|  495|
# |      1148|Manufacturing Dir...|  5377|  653|
# |      1303|Manufacturing Dir...| 10333|  666|
# |       603|Manufacturing Dir...|  6877|  715|
# |      1160|Manufacturing Dir...|  5770|  728|
# |       343|Manufacturing Dir...|  7143|  796|
# |      1062|Manufacturing Dir...| 10209|  829|
# |       598|Manufacturing Dir...|  6062|  834|
# |      1418|Manufacturing Dir...|  5321|  881|
# |       878|Manufacturing Dir...|  7379|  905|
# |       345|Manufacturing Dir...|  8095|  952|
# |       788|Manufacturing Dir...| 10976| 1019|
# |       826|Manufacturing Dir...|  5056| 1023|
# |       783|Manufacturing Dir...|  9957| 1099|
# |      1346|Manufacturing Dir...|  5906| 1118|
# |       199|Manufacturing Dir...|  6553| 1288|
# |       538|Manufacturing Dir...|  8793| 1381|
# |       279|Manufacturing Dir...|  6397| 1499|
# |       248|Manufacturing Dir...|  5957| 1612|
# |       212|Manufacturing Dir...|  8474| 1670|
# |       157|Manufacturing Dir...|  6132| 1813|
# |      1079|Manufacturing Dir...|  8376| 1827|
# |      1038|Manufacturing Dir...|  9380| 1934|
# |        60|Manufacturing Dir...|  5993| 1982|
# |      1161|Manufacturing Dir...|  7756| 1986|
# |      1229|Manufacturing Dir...|  6516| 2142|
# |       202|Manufacturing Dir...|  6804| 2506|
# |       693|Manufacturing Dir...|  6725| 2554|
# |       449|Manufacturing Dir...| 13237| 2589|
# |       883|Manufacturing Dir...| 10252| 2873|
# |        86|Manufacturing Dir...|  7260| 2935|
# |       507|Manufacturing Dir...|  9434| 2987|
# |       813|Manufacturing Dir...| 10820| 3165|
# |       465|Manufacturing Dir...|  7491| 3229|
# |       326|Manufacturing Dir...|  8943| 3461|
# |       628|Manufacturing Dir...| 13826| 3605|
# |       251|Manufacturing Dir...| 10048| 3614|
# |       407|Manufacturing Dir...|  7969| 3663|
# |      1394|Manufacturing Dir...|  9679| 4528|
# |       189|Manufacturing Dir...|  9547| 5097|
# |       847|Manufacturing Dir...| 10274| 5218|
# |       972|Manufacturing Dir...| 13142| 5244|
# |      1296|Manufacturing Dir...|  9667| 5454|
# |       967|Manufacturing Dir...| 10008| 5474|
# |      1156|Manufacturing Dir...| 10435| 5558|
# |       435|Manufacturing Dir...| 10648| 5578|
# |       137|Manufacturing Dir...| 10650| 5709|
# |       612|Manufacturing Dir...| 10221| 5787|
# |      1111|Manufacturing Dir...| 10169| 5849|
# |       636|Manufacturing Dir...| 10685| 5910|
# |       729|Manufacturing Dir...| 10739| 6591|
# |       995|Manufacturing Dir...| 13247| 7068|
# |      1268|Manufacturing Dir...| 12965| 7727|
# |       739|Manufacturing Dir...| 12742| 7739|
# |      1445|Manufacturing Dir...| 13570| 8439|
# |       722|Manufacturing Dir...| 13973| 8906|
# |       744|Manufacturing Dir...| 13726| 9499|
# |        23|   Research Director| 11994| null|
# |      1405|   Research Director| 11031|-8130|
# |       731|   Research Director| 11416|-8003|
# |       421|   Research Director| 11935|-7471|
# |       342|   Research Director| 11510|-6790|
# |       308|   Research Director| 12061|-6604|
# |      1357|   Research Director| 13348|-6317|
# |       214|   Research Director| 12490|-6232|
# |       838|   Research Director| 13499|-6127|
# |        56|   Research Director| 13458|-6087|
# |       591|   Research Director| 11691|-5948|
# |       888|   Research Director| 13191|-5890|
# |      1284|   Research Director| 13464|-5864|
# |       276|   Research Director| 13603|-5833|
# |        78|   Research Director| 13245|-5495|
# |       532|   Research Director| 11159|-5468|
# |      1011|   Research Director| 14732|-4969|
# |       611|   Research Director| 12808|-4351|
# |      1041|   Research Director| 13757|-3412|
# |      1177|   Research Director| 13269|-3144|
# |       542|   Research Director| 11713|-3101|
# |       490|   Research Director| 16627|-2875|
# |      1176|   Research Director| 16413|-2636|
# |       906|   Research Director| 16124|-2141|
# |       610|   Research Director| 17159|-2087|
# |      1086|   Research Director| 14411|-1917|
# |       456|   Research Director| 16184|-1677|
# |       391|   Research Director| 14336|-1656|
# |       281|   Research Director| 17584|-1560|
# |       905|   Research Director| 18265|-1475|
# |      1225|   Research Director| 16704| -899|
# |       188|   Research Director| 18722| -815|
# |       767|   Research Director| 19237| -736|
# |       682|   Research Director| 13582| -693|
# |      1078|   Research Director| 16328| -679|
# |       223|   Research Director| 12185| -305|
# |        96|   Research Director| 13549| -115|
# |       815|   Research Director| 19626|   -1|
# |      1277|   Research Director| 19328|  290|
# |       771|   Research Director| 19627|  390|
# |      1056|   Research Director| 17007|  409|
# |        79|   Research Director| 13664|  419|
# |      1009|   Research Director| 17328|  448|
# |      1432|   Research Director| 13744|  538|
# |      1025|   Research Director| 17169|  747|
# |       946|   Research Director| 16880|  756|
# |      1421|   Research Director| 11957|  926|
# |       291|   Research Director| 18665| 1081|
# |      1430|   Research Director| 13206| 1249|
# |       124|   Research Director| 19537| 1365|
# |       650|   Research Director| 14275| 1467|
# |       246|   Research Director| 13675| 1490|
# |      1015|   Research Director| 16422| 1690|
# |       899|   Research Director| 19740| 1961|
# |       717|   Research Director| 19419| 2020|
# |      1310|   Research Director| 15787| 2323|
# |      1264|   Research Director| 19038| 2334|
# |      1010|   Research Director| 19701| 2373|
# |      1044|   Research Director| 16598| 2841|
# |       474|   Research Director| 19502| 3318|
# |       535|   Research Director| 14814| 3655|
# |       715|   Research Director| 17399| 3817|
# |      1331|   Research Director| 19665| 3878|
# |      1185|   Research Director| 17603| 4334|
# |       349|   Research Director| 15992| 4482|
# |       895|   Research Director| 17779| 4588|
# |       107|   Research Director| 18172| 4623|
# |      1140|   Research Director| 19049| 4638|
# |       393|   Research Director| 19406| 5070|
# |        63|   Research Director| 18740| 5282|
# |       280|   Research Director| 19144| 5541|
# |       870|   Research Director| 19081| 5582|
# |       258|   Research Director| 19436| 5761|
# |      1377|   Research Director| 19161| 5813|
# |       430|   Research Director| 17861| 5926|
# |       589|   Research Director| 17639| 5926|
# |       330|   Research Director| 18300| 6239|
# |        46|   Research Director| 19545| 7551|
# |       596|   Research Director| 19246| 7555|
# |       747|   Research Director| 19973| 8557|
# |         2|  Research Scientist|  5130| null|
# |        69|  Research Scientist|  2194|-7530|
# |       513|  Research Scientist|  2045|-4601|
# |       502|  Research Scientist|  2083|-4239|
# |      1320|  Research Scientist|  2936|-4026|
# |       259|  Research Scientist|  2723|-3822|
# |      1104|  Research Scientist|  2451|-3427|
# |      1118|  Research Scientist|  2061|-3423|
# |        82|  Research Scientist|  2859|-3361|
# |      1069|  Research Scientist|  1563|-3337|
# |      1373|  Research Scientist|  2133|-3334|
# |       370|  Research Scientist|  2657|-3317|
# |      1307|  Research Scientist|  3591|-3263|
# |       475|  Research Scientist|  2725|-2852|
# |        24|  Research Scientist|  1232|-2712|
# |       633|  Research Scientist|  2515|-2660|
# |      1420|  Research Scientist|  2782|-2628|
# |      1381|  Research Scientist|  2144|-2627|
# |       126|  Research Scientist|  2368|-2595|
# |       990|  Research Scientist|  2996|-2471|
# |       541|  Research Scientist|  2216|-2464|
# |       319|  Research Scientist|  2478|-2463|
# |       102|  Research Scientist|  2956|-2373|
# |      1449|  Research Scientist|  2439|-2348|
# |       158|  Research Scientist|  3346|-2259|
# |         4|  Research Scientist|  2909|-2221|
# |       978|  Research Scientist|  2029|-2220|
# |       884|  Research Scientist|  2781|-2217|
# |       799|  Research Scientist|  2313|-2195|
# |       295|  Research Scientist|  2326|-2159|
# |       780|  Research Scientist|  2461|-2154|
# |      1092|  Research Scientist|  2132|-2153|
# |      1053|  Research Scientist|  1274|-2146|
# |       313|  Research Scientist|  2695|-2126|
# |       604|  Research Scientist|  2274|-2108|
# |      1397|  Research Scientist|  2897|-2106|
# |      1152|  Research Scientist|  3117|-2091|
# |      1311|  Research Scientist|  1514|-2077|
# |      1207|  Research Scientist|  3537|-1933|
# |       109|  Research Scientist|  2889|-1920|
# |       121|  Research Scientist|  2613|-1892|
# |       854|  Research Scientist|  2552|-1870|
# |       408|  Research Scientist|  2654|-1795|
# |       911|  Research Scientist|  1223|-1771|
# |       177|  Research Scientist|  2500|-1757|
# |      1017|  Research Scientist|  1261|-1735|
# |      1114|  Research Scientist|  2367|-1720|
# |       998|  Research Scientist|  2394|-1687|
# |       144|  Research Scientist|  2632|-1685|
# |       595|  Research Scientist|  2700|-1681|
# |      1435|  Research Scientist|  2436|-1672|
# |       419|  Research Scientist|  2886|-1670|
# |       728|  Research Scientist|  1051|-1633|
# |        35|  Research Scientist|  2293|-1626|
# |       182|  Research Scientist|  2311|-1618|
# |       324|  Research Scientist|  3464|-1591|
# |       253|  Research Scientist|  2340|-1580|
# |       858|  Research Scientist|  2936|-1541|
# |      1248|  Research Scientist|  3445|-1523|
# |       207|  Research Scientist|  2328|-1487|
# |       486|  Research Scientist|  2187|-1435|
# |      1024|  Research Scientist|  2066|-1354|
# |      1349|  Research Scientist|  2933|-1351|
# |       890|  Research Scientist|  2235|-1344|
# |       721|  Research Scientist|  2132|-1320|
# |       142|  Research Scientist|  3452|-1287|
# |      1336|  Research Scientist|  2662|-1240|
# |       645|  Research Scientist|  2356|-1224|
# |       903|  Research Scientist|  2517|-1175|
# |       335|  Research Scientist|  3697|-1172|
# |      1141|  Research Scientist|  2141|-1171|
# |       701|  Research Scientist|  2479|-1138|
# |       926|  Research Scientist|  2372|-1134|
# |       286|  Research Scientist|  2115|-1115|
# |      1283|  Research Scientist|  2044|-1099|
# |       692|  Research Scientist|  3617|-1061|
# |       514|  Research Scientist|  1009|-1036|
# |       161|  Research Scientist|  2323|-1023|
# |      1429|  Research Scientist|  4108| -990|
# |       575|  Research Scientist|  3280| -978|
# |      1226|  Research Scientist|  3433| -968|
# |      1170|  Research Scientist|  2580| -937|
# |      1016|  Research Scientist|  2996| -908|
# |       333|  Research Scientist|  4869| -906|
# |      1335|  Research Scientist|  3902| -872|
# |       621|  Research Scientist|  2559| -865|
# |       384|  Research Scientist|  2244| -858|
# |      1258|  Research Scientist|  2109| -823|
# |       770|  Research Scientist|  2007| -814|
# |      1457|  Research Scientist|  2001| -808|
# |       346|  Research Scientist|  2904| -793|
# |       860|  Research Scientist|  2168| -768|
# |      1279|  Research Scientist|  2342| -713|
# |      1187|  Research Scientist|  4735| -698|
# |        72|  Research Scientist|  2703| -685|
# |       616|  Research Scientist|  1706| -660|
# |       273|  Research Scientist|  2070| -653|
# |      1353|  Research Scientist|  2307| -626|
# |      1212|  Research Scientist|  2929| -608|
# |       218|  Research Scientist|  2058| -599|
# |       828|  Research Scientist|  2703| -588|
# |      1233|  Research Scientist|  2862| -571|
# |       863|  Research Scientist|  2290| -563|
# |       763|  Research Scientist|  2042| -558|
# |       679|  Research Scientist|  2259| -540|
# |      1217|  Research Scientist|  4401| -529|
# |       517|  Research Scientist|  2819| -529|
# |      1252|  Research Scientist|  2932| -513|
# |       578|  Research Scientist|  2782| -498|
# |      1332|  Research Scientist|  2439| -497|
# |       637|  Research Scientist|  2022| -493|
# |       192|  Research Scientist|  2279| -477|
# |       809|  Research Scientist|  2514| -465|
# |       372|  Research Scientist|  2201| -456|
# |       226|  Research Scientist|  2177| -445|
# |       816|  Research Scientist|  2070| -444|
# |       554|  Research Scientist|  2342| -417|
# |       962|  Research Scientist|  4249| -412|
# |       247|  Research Scientist|  2911| -408|
# |        48|  Research Scientist|  3022| -397|
# |       563|  Research Scientist|  2686| -371|
# |       958|  Research Scientist|  3544| -360|
# |       422|  Research Scientist|  2546| -340|
# |       669|  Research Scientist|  2377| -316|
# |       162|  Research Scientist|  2024| -299|
# |       934|  Research Scientist|  2080| -292|
# |      1262|  Research Scientist|  2437| -281|
# |      1370|  Research Scientist|  5467| -280|
# |      1169|  Research Scientist|  3517| -243|
# |       892|  Research Scientist|  2011| -224|
# |       491|  Research Scientist|  2619| -217|
# |        73|  Research Scientist|  2501| -202|
# |       597|  Research Scientist|  2506| -194|
# |       194|  Research Scientist|  2089| -190|
# |      1339|  Research Scientist|  2472| -190|
# |       615|  Research Scientist|  2366| -187|
# |       865|  Research Scientist|  2107| -183|
# |      1168|  Research Scientist|  3760| -176|
# |       834|  Research Scientist|  2539| -164|
# |       710|  Research Scientist|  2321| -158|
# |       893|  Research Scientist|  1859| -152|
# |       165|  Research Scientist|  2566| -147|
# |       167|  Research Scientist|  2451| -115|
# |       520|  Research Scientist|  2720|  -99|
# |      1367|  Research Scientist|  2226|  -81|
# |       901|  Research Scientist|  3692|  -68|
# |       671|  Research Scientist|  2318|  -59|
# |        13|  Research Scientist|  2911|    2|
# |      1127|  Research Scientist|  2073|   12|
# |       935|  Research Scientist|  2096|   16|
# |       171|  Research Scientist|  3058|   20|
# |       386|  Research Scientist|  2285|   41|
# |      1029|  Research Scientist|  2127|   61|
# |       907|  Research Scientist|  2585|   68|
# |       712|  Research Scientist|  2404|   83|
# |       824|  Research Scientist|  3291|   90|
# |       664|  Research Scientist|  2693|  134|
# |       499|  Research Scientist|  2773|  154|
# |      1089|  Research Scientist|  4285|  201|
# |       659|  Research Scientist|  2559|  203|
# |       230|  Research Scientist|  2389|  212|
# |      1046|  Research Scientist|  2345|  218|
# |       433|  Research Scientist|  2768|  222|
# |       244|  Research Scientist|  3319|  247|
# |       203|  Research Scientist|  3815|  251|
# |       939|  Research Scientist|  2372|  276|
# |       607|  Research Scientist|  2553|  279|
# |       789|  Research Scientist|  3660|  284|
# |      1375|  Research Scientist|  2432|  299|
# |       215|  Research Scientist|  2657|  329|
# |       378|  Research Scientist|  2543|  342|
# |        36|  Research Scientist|  2645|  352|
# |      1455|  Research Scientist|  2809|  370|
# |        17|  Research Scientist|  3298|  387|
# |      1293|  Research Scientist|  2438|  394|
# |       910|  Research Scientist|  2994|  409|
# |       186|  Research Scientist|  2756|  445|
# |       882|  Research Scientist|  4998|  457|
# |       674|  Research Scientist|  2799|  481|
# |      1139|  Research Scientist|  3312|  498|
# |       548|  Research Scientist|  2759|  543|
# |       723|  Research Scientist|  2684|  552|
# |       383|  Research Scientist|  3102|  559|
# |       222|  Research Scientist|  2622|  564|
# |       146|  Research Scientist|  3204|  572|
# |       983|  Research Scientist|  2610|  581|
# |       170|  Research Scientist|  3038|  587|
# |      1423|  Research Scientist|  3375|  593|
# |      1115|  Research Scientist|  2972|  605|
# |       504|  Research Scientist|  2691|  608|
# |      1260|  Research Scientist|  2718|  609|
# |      1265|  Research Scientist|  3055|  618|
# |       925|  Research Scientist|  3506|  631|
# |        20|  Research Scientist|  3944|  646|
# |       488|  Research Scientist|  2836|  649|
# |       804|  Research Scientist|  2979|  666|
# |       243|  Research Scientist|  3072|  683|
# |       861|  Research Scientist|  2853|  685|
# |       163|  Research Scientist|  2713|  689|
# |       560|  Research Scientist|  3057|  715|
# |      1190|  Research Scientist|  5470|  735|
# |      1137|  Research Scientist|  2814|  741|
# |       571|  Research Scientist|  4258|  753|
# |        39|  Research Scientist|  3419|  774|
# |       766|  Research Scientist|  2821|  779|
# |       887|  Research Scientist|  3579|  798|
# |      1077|  Research Scientist|  2362|  799|
# |      1282|  Research Scientist|  3143|  801|
# |      1460|  Research Scientist|  3785|  808|
# |       566|  Research Scientist|  3505|  819|
# |      1163|  Research Scientist|  3936|  819|
# |       793|  Research Scientist|  4508|  848|
# |       143|  Research Scientist|  4317|  865|
# |       482|  Research Scientist|  3622|  897|
# |       784|  Research Scientist|  3376|  915|
# |      1382|  Research Scientist|  3065|  921|
# |       773|  Research Scientist|  2942|  935|
# |        27|  Research Scientist|  3919|  959|
# |      1458|  Research Scientist|  2977|  976|
# |       249|  Research Scientist|  3920| 1009|
# |       713|  Research Scientist|  3452| 1048|
# |      1047|  Research Scientist|  3420| 1075|
# |      1419|  Research Scientist|  5410| 1078|
# |       996|  Research Scientist|  4081| 1085|
# |       960|  Research Scientist|  4661| 1117|
# |       820|  Research Scientist|  3201| 1131|
# |       275|  Research Scientist|  3230| 1160|
# |       292|  Research Scientist|  4485| 1175|
# |        70|  Research Scientist|  3388| 1194|
# |       290|  Research Scientist|  3310| 1195|
# |       176|  Research Scientist|  4257| 1199|
# |       624|  Research Scientist|  3761| 1202|
# |       627|  Research Scientist|  5175| 1414|
# |       181|  Research Scientist|  3929| 1429|
# |      1404|  Research Scientist|  4332| 1435|
# |       196|  Research Scientist|  3564| 1475|
# |       999|  Research Scientist|  3904| 1510|
# |       941|  Research Scientist|  3904| 1532|
# |       732|  Research Scientist|  2600| 1549|
# |       640|  Research Scientist|  3580| 1558|
# |       580|  Research Scientist|  4381| 1599|
# |       115|  Research Scientist|  4505| 1616|
# |      1113|  Research Scientist|  4087| 1636|
# |       913|  Research Scientist|  2875| 1652|
# |       779|  Research Scientist|  4615| 1673|
# |       619|  Research Scientist|  3424| 1718|
# |      1085|  Research Scientist|  4084| 1722|
# |      1424|  Research Scientist|  5098| 1723|
# |        25|  Research Scientist|  2960| 1728|
# ...
# |       574|     Sales Executive|  5326|-2261|
# |       761|     Sales Executive|  7525|-2200|
# |        71|     Sales Executive|  5473|-2164|
# |       635|     Sales Executive|  4194|-2140|
# |       398|     Sales Executive|  4487|-2051|
# |       961|     Sales Executive|  4103|-2048|
# |       483|     Sales Executive|  4233|-2039|
# |      1253|     Sales Executive|  5147|-1993|
# |       802|     Sales Executive|  4728|-1966|
# |       886|     Sales Executive|  4950|-1902|
# |       749|     Sales Executive|  4969|-1892|
# |       388|     Sales Executive|  5715|-1881|
# |       533|     Sales Executive|  4960|-1836|
# |      1454|     Sales Executive|  4850|-1802|
# |       623|     Sales Executive|  4403|-1798|
# |       453|     Sales Executive|  4805|-1777|
# |      1198|     Sales Executive|  5368|-1714|
# |       262|     Sales Executive|  5249|-1682|
# |      1216|     Sales Executive|  7847|-1678|
# |      1340|     Sales Executive|  5673|-1641|
# |      1094|     Sales Executive|  5473|-1610|
# |       704|     Sales Executive|  5666|-1598|
# |       448|     Sales Executive|  4717|-1513|
# |       969|     Sales Executive|  4639|-1486|
# |      1026|     Sales Executive|  4162|-1485|
# |        40|     Sales Executive|  5376|-1449|
# |       307|     Sales Executive|  5484|-1445|
# |       168|     Sales Executive|  9419|-1436|
# |        64|     Sales Executive|  7637|-1432|
# |       812|     Sales Executive|  7351|-1389|
# |       339|     Sales Executive|  6118|-1339|
# |      1447|     Sales Executive|  5406|-1306|
# |        55|     Sales Executive|  4157|-1297|
# |      1186|     Sales Executive|  4581|-1288|
# |      1276|     Sales Executive|  4189|-1279|
# |      1247|     Sales Executive|  8346|-1264|
# |      1385|     Sales Executive|  8628|-1260|
# |      1416|     Sales Executive|  4440|-1237|
# |       850|     Sales Executive|  5346|-1232|
# |       866|     Sales Executive|  4115|-1231|
# |       792|     Sales Executive|  9582|-1216|
# |      1251|     Sales Executive|  7140|-1206|
# |       434|     Sales Executive|  9071|-1195|
# |       592|     Sales Executive|  5324|-1176|
# |      1059|     Sales Executive|  4599|-1166|
# |        77|     Sales Executive|  4312|-1161|
# |       375|     Sales Executive|  5253|-1127|
# |      1356|     Sales Executive|  4393|-1114|
# |      1393|     Sales Executive|  4105|-1099|
# |      1366|     Sales Executive|  5736|-1098|
# |       304|     Sales Executive|  6929|-1091|
# |       381|     Sales Executive|  4260|-1044|
# |      1319|     Sales Executive|  4648|-1027|
# |      1355|     Sales Executive|  5507| -993|
# |       577|     Sales Executive|  4342| -984|
# |      1446|     Sales Executive|  6712| -932|
# |       720|     Sales Executive|  4163| -916|
# |       278|     Sales Executive|  5605| -897|
# |       519|     Sales Executive|  4028| -823|
# |        98|     Sales Executive|  4221| -778|
# |       965|     Sales Executive|  6125| -768|
# |       321|     Sales Executive|  4478| -750|
# |       620|     Sales Executive|  4037| -742|
# |       169|     Sales Executive|  8686| -733|
# |       518|     Sales Executive|  4851| -710|
# |       282|     Sales Executive|  4907| -698|
# |      1032|     Sales Executive| 10096| -697|
# |       948|     Sales Executive|  8446| -648|
# |      1254|     Sales Executive|  4507| -640|
# |       564|     Sales Executive|  6180| -624|
# |        90|     Sales Executive|  9619| -620|
# |       991|     Sales Executive|  9998| -598|
# |      1274|     Sales Executive|  5468| -561|
# |       329|     Sales Executive|  4682| -556|
# |      1052|     Sales Executive|  4768| -533|
# |      1109|     Sales Executive|  9250| -464|
# |       997|     Sales Executive|  5769| -463|
# |       803|     Sales Executive|  4302| -426|
# |       213|     Sales Executive|  9981| -419|
# |      1257|     Sales Executive|  8161| -403|
# |      1188|     Sales Executive|  4187| -394|
# |       613|     Sales Executive|  4779| -381|
# |       283|     Sales Executive|  4554| -353|
# |       367|     Sales Executive|  9355| -344|
# |        53|     Sales Executive|  5454| -318|
# |       377|     Sales Executive|  4936| -317|
# |      1378|     Sales Executive|  5087| -293|
# |       320|     Sales Executive|  5228| -256|
# |      1143|     Sales Executive|  4385| -254|
# |        93|     Sales Executive|  5209| -232|
# |        95|     Sales Executive|  5010| -199|
# |       626|     Sales Executive| 10761| -173|
# |       274|     Sales Executive|  6502| -142|
# |       568|     Sales Executive|  6274| -123|
# |      1453|     Sales Executive|  6652|  -76|
# |       526|     Sales Executive|  4577|  -70|
# |      1105|     Sales Executive|  6392|  -47|
# |      1191|     Sales Executive|  5476|  -29|
# |        97|     Sales Executive|  4999|  -11|
# |       424|     Sales Executive|  8412|   20|
# |       125|     Sales Executive|  6172|   26|
# |       706|     Sales Executive|  7880|   57|
# |       639|     Sales Executive|  4256|   62|
# |       355|     Sales Executive|  4736|   87|
# |       340|     Sales Executive|  6214|   96|
# |       985|     Sales Executive|  4724|  110|
# |       776|     Sales Executive| 10798|  112|
# |       867|     Sales Executive|  4327|  212|
# |       567|     Sales Executive|  6397|  217|
# |       696|     Sales Executive| 10609|  284|
# |      1070|     Sales Executive|  4898|  307|
# |       379|     Sales Executive|  5304|  368|
# |      1049|     Sales Executive|  4759|  386|
# |      1172|     Sales Executive|  5869|  429|
# |       975|     Sales Executive|  5071|  432|
# |      1314|     Sales Executive|  5154|  470|
# |      1380|     Sales Executive|  5561|  474|
# |       463|     Sales Executive|  5337|  478|
# |      1316|     Sales Executive|  5675|  521|
# |      1050|     Sales Executive|  5301|  542|
# |       462|     Sales Executive|  4859|  553|
# |       356|     Sales Executive|  5296|  560|
# |      1237|     Sales Executive|  6735|  601|
# |      1119|     Sales Executive|  9924|  674|
# |       880|     Sales Executive|  5220|  681|
# |       680|     Sales Executive|  6932|  688|
# |       528|     Sales Executive|  5396|  819|
# |       394|     Sales Executive|  6538|  823|
# |        28|     Sales Executive|  6825|  832|
# |      1020|     Sales Executive|  5647|  868|
# |       229|     Sales Executive|  8789|  871|
# |       769|     Sales Executive|  8396|  871|
# |       443|     Sales Executive|  9980|  909|
# |      1144|     Sales Executive|  5332|  947|
# |      1103|     Sales Executive|  6439|  966|
# |      1058|     Sales Executive|  5765|  997|
# |       336|     Sales Executive|  7457| 1108|
# |      1462|     Sales Executive| 12031| 1177|
# |        49|     Sales Executive|  5772| 1204|
# |       485|     Sales Executive|  5460| 1227|
# |       294|     Sales Executive|  5828| 1274|
# |       508|     Sales Executive|  5561| 1275|
# |       503|     Sales Executive|  8381| 1277|
# |       806|     Sales Executive|  5593| 1291|
# |       570|     Sales Executive|  7587| 1313|
# |      1189|     Sales Executive|  5505| 1318|
# |       673|     Sales Executive|  6244| 1336|
# |      1364|     Sales Executive|  6834| 1347|
# |       359|     Sales Executive|  6653| 1357|
# |      1452|     Sales Executive|  6728| 1385|
# |      1218|     Sales Executive|  9241| 1394|
# |       266|     Sales Executive|  6644| 1395|
# |       987|     Sales Executive|  6120| 1396|
# |       529|     Sales Executive|  6796| 1400|
# |       951|     Sales Executive|  9852| 1406|
# |      1124|     Sales Executive|  8237| 1422|
# |       845|     Sales Executive|  6578| 1423|
# |       549|     Sales Executive|  6804| 1500|
# |      1395|     Sales Executive|  5617| 1512|
# |      1359|     Sales Executive|  8103| 1520|
# |       476|     Sales Executive|  6272| 1565|
# |      1031|     Sales Executive| 10793| 1589|
# |      1196|     Sales Executive|  7082| 1606|
# |       837|     Sales Executive|  7336| 1622|
# |      1281|     Sales Executive|  5813| 1624|
# |       885|     Sales Executive|  6852| 1632|
# |       332|     Sales Executive|  6349| 1667|
# |       116|     Sales Executive|  7428| 1684|
# |       155|     Sales Executive|  8998| 1703|
# |       404|     Sales Executive|  8392| 1815|
# |       428|     Sales Executive| 10266| 1854|
# |       159|     Sales Executive| 10855| 1857|
# |       451|     Sales Executive|  6582| 1865|
# |      1270|     Sales Executive|  6029| 2028|
# |       344|     Sales Executive|  8268| 2054|
# |       994|     Sales Executive|  6232| 2154|
# |       705|     Sales Executive|  7823| 2157|
# |       584|     Sales Executive|  6500| 2158|
# |       622|     Sales Executive|  6201| 2164|
# |       219|     Sales Executive|  8865| 2169|
# |      1285|     Sales Executive|  7991| 2178|
# |       447|     Sales Executive|  6230| 2179|
# |      1084|     Sales Executive|  7083| 2185|
# |      1358|     Sales Executive|  6583| 2190|
# |       642|     Sales Executive|  6524| 2268|
# |       772|     Sales Executive| 10686| 2290|
# |       118|     Sales Executive|  9738| 2310|
# |       608|     Sales Executive|  7654| 2330|
# |       255|     Sales Executive|  6931| 2466|
# |      1121|     Sales Executive|  6815| 2617|
# |       152|     Sales Executive|  7295| 2627|
# |       703|     Sales Executive|  7264| 2663|
# |       748|     Sales Executive|  6861| 2698|
# |      1439|     Sales Executive|  7644| 2737|
# |       139|     Sales Executive|  8639| 2737|
# |       211|     Sales Executive| 10400| 2761|
# |       685|     Sales Executive|  9705| 2773|
# |       964|     Sales Executive|  6893| 2790|
# |      1306|     Sales Executive|  9637| 2838|
# |      1241|     Sales Executive|  9610| 2875|
# |       947|     Sales Executive|  9094| 2885|
# |      1403|     Sales Executive| 13341| 2893|
# |      1042|     Sales Executive|  8463| 2977|
# |       132|     Sales Executive|  9208| 3036|
# |       360|     Sales Executive|  9699| 3046|
# |       322|     Sales Executive|  7547| 3069|
# |       653|     Sales Executive|  7642| 3105|
# |       808|     Sales Executive|  8740| 3147|
# |       909|     Sales Executive|  8380| 3209|
# |      1327|     Sales Executive| 13225| 3318|
# |      1106|     Sales Executive|  9714| 3322|
# |       385|     Sales Executive|  7596| 3336|
# |        44|     Sales Executive|  8726| 3350|
# |       758|     Sales Executive|  9725| 3378|
# |       468|     Sales Executive|  8834| 3497|
# |      1012|     Sales Executive|  9278| 3509|
# |      1448|     Sales Executive|  8938| 3532|
# |       134|     Sales Executive|  8189| 3630|
# |      1223|     Sales Executive| 12936| 3695|
# |      1063|     Sales Executive|  8620| 4021|
# |      1342|     Sales Executive|  9713| 4040|
# |      1255|     Sales Executive|  8564| 4057|
# |       521|     Sales Executive|  8120| 4092|
# |      1369|     Sales Executive|  9854| 4118|
# |       487|     Sales Executive|  9602| 4142|
# |      1211|     Sales Executive|  9525| 4157|
# |      1384|     Sales Executive|  9888| 4327|
# |       988|     Sales Executive| 10596| 4476|
# |       871|     Sales Executive|  8966| 4639|
# |       224|     Sales Executive| 10609| 4669|
# |      1396|     Sales Executive| 10448| 4831|
# |        57|     Sales Executive|  9069| 4912|
# |      1162|     Sales Executive| 10306| 4974|
# |      1027|     Sales Executive|  9204| 5042|
# |      1326|     Sales Executive|  9907| 5259|
# |       647|     Sales Executive| 11836| 5312|
# |       707|     Sales Executive| 13194| 5314|
# |      1235|     Sales Executive| 10368| 5390|
# |       889|     Sales Executive| 10377| 5427|
# |       179|     Sales Executive| 10453| 5447|
# |       534|     Sales Executive| 10475| 5515|
# |       927|     Sales Executive| 10231| 5693|
# |        83|     Sales Executive| 10239| 5927|
# |      1431|     Sales Executive| 10422| 5982|
# |      1461|     Sales Executive| 10854| 6004|
# |       694|     Sales Executive| 10325| 6031|
# |       459|     Sales Executive| 10932| 6127|
# |      1295|     Sales Executive| 10447| 6320|
# |       839|     Sales Executive| 13758| 6422|
# |       625|     Sales Executive| 10934| 6531|
# |       296|     Sales Executive| 13525| 7697|
# |       822|     Sales Executive| 13120| 8152|
# |       751|     Sales Executive| 13320| 8351|
# |       545|     Sales Executive| 13770| 8365|
# |       976|     Sales Executive| 13695| 8624|
# |       402|     Sales Executive| 13212| 8725|
# |        99|     Sales Executive| 13872| 9651|
# |        22|Sales Representative|  3407| null|
# |       581|Sales Representative|  2572|-4060|
# |      1328|Sales Representative|  3540|-1865|
# |      1338|Sales Representative|  1081|-1775|
# |      1249|Sales Representative|  2760|-1742|
# |       302|Sales Representative|  1200|-1589|
# |       912|Sales Representative|  1118|-1560|
# |      1057|Sales Representative|  2909|-1491|
# |      1013|Sales Representative|  1359|-1426|
# |        34|Sales Representative|  2086|-1321|
# |       547|Sales Representative|  2642|-1233|
# |       765|Sales Representative|  1052|-1168|
# |       293|Sales Representative|  2789|-1142|
# |       458|Sales Representative|  1878|-1105|
# |      1436|Sales Representative|  2380|-1102|
# |      1153|Sales Representative|  1569|-1075|
# |       676|Sales Representative|  2329| -965|
# |       663|Sales Representative|  2044| -929|
# |      1061|Sales Representative|  2033| -876|
# |       416|Sales Representative|  2351| -851|
# |       358|Sales Representative|  2174| -802|
# |      1428|Sales Representative|  2269| -798|
# |      1337|Sales Representative|  2856| -684|
# |        38|Sales Representative|  2014| -669|
# |       128|Sales Representative|  1675| -647|
# |      1438|Sales Representative|  1790| -590|
# |      1213|Sales Representative|  2275| -380|
# |       227|Sales Representative|  2793| -347|
# |       556|Sales Representative|  2297| -345|
# |       479|Sales Representative|  2096| -304|
# |       689|Sales Representative|  2121| -292|
# |       382|Sales Representative|  2476| -240|
# |       877|Sales Representative|  2678| -149|
# |       371|Sales Representative|  2716| -135|
# |       764|Sales Representative|  2220| -122|
# |       646|Sales Representative|  2800|  -99|
# |      1271|Sales Representative|  2679|  -81|
# |       160|Sales Representative|  2231|  -75|
# |      1204|Sales Representative|  2655|  -73|
# |       481|Sales Representative|  2033|  -63|
# |      1197|Sales Representative|  2728|  -55|
# |      1365|Sales Representative|  1091|   10|
# |       698|Sales Representative|  2157|   36|
# |       851|Sales Representative|  2827|   36|
# |       684|Sales Representative|  2413|   84|
# |       172|Sales Representative|  2325|   94|
# |      1100|Sales Representative|  2430|  122|
# |       649|Sales Representative|  2973|  173|
# |       755|Sales Representative|  2342|  185|
# |      1417|Sales Representative|  3067|  209|
# |      1102|Sales Representative|  2644|  214|
# |       971|Sales Representative|  2534|  232|
# |       364|Sales Representative|  2851|  241|
# |       981|Sales Representative|  2785|  251|
# |      1087|Sales Representative|  2308|  275|
# |        87|Sales Representative|  2322|  308|
# |       643|Sales Representative|  2899|  327|
# |       497|Sales Representative|  3447|  406|
# |       540|Sales Representative|  3875|  428|
# |       363|Sales Representative|  2610|  436|
# |       496|Sales Representative|  3041|  462|
# |       819|Sales Representative|  2791|  468|
# |       471|Sales Representative|  2400|  522|
# |       495|Sales Representative|  2579|  546|
# |        37|Sales Representative|  2683|  597|
# |       153|Sales Representative|  2306|  631|
# |       438|Sales Representative|  2983|  632|
# |       415|Sales Representative|  3202|  726|
# |       183|Sales Representative|  3140|  815|
# |       239|Sales Representative|  3931| 1138|
# |      1464|Sales Representative|  2966| 1176|
# |       953|Sales Representative|  2302| 1184|
# |      1434|Sales Representative|  3482| 1213|
# |      1178|Sales Representative|  2783| 1214|
# |       666|Sales Representative|  3294| 1250|
# |       777|Sales Representative|  2323| 1271|
# |      1391|Sales Representative|  2858| 1767|
# |       348|Sales Representative|  2976| 1776|
# |      1220|Sales Representative|  4502| 2227|
# |      1308|Sales Representative|  5405| 2726|
# |      1022|Sales Representative|  4400| 3041|
# |       565|Sales Representative|  6632| 4335|
# +----------+--------------------+------+-----+

# %%
# a variation of above query, not same but for comparison
spark.sql("""
    SELECT *, (Income-prev_income) AS diff
    FROM (
        SELECT EmployeeID, JobRole, Income,
        LAG(Income, 1) OVER(PARTITION BY JobRole ORDER BY JobRole) as prev_income
        FROM hremployee
        WHERE Income IS NOT NULL
    ) AS _
""").show()
# Out:
# +----------+---------------+------+-----------+-----+
# |EmployeeID|        JobRole|Income|prev_income| diff|
# +----------+---------------+------+-----------+-----+
# |         1|Sales Executive|  5993|       null| null|
# |        28|Sales Executive|  6825|       5993|  832|
# |        40|Sales Executive|  5376|       6825|-1449|
# |        44|Sales Executive|  8726|       5376| 3350|
# |        47|Sales Executive|  4568|       8726|-4158|
# |        49|Sales Executive|  5772|       4568| 1204|
# |        53|Sales Executive|  5454|       5772| -318|
# |        55|Sales Executive|  4157|       5454|-1297|
# |        57|Sales Executive|  9069|       4157| 4912|
# |        64|Sales Executive|  7637|       9069|-1432|
# |        71|Sales Executive|  5473|       7637|-2164|
# |        77|Sales Executive|  4312|       5473|-1161|
# |        83|Sales Executive| 10239|       4312| 5927|
# |        90|Sales Executive|  9619|      10239| -620|
# |        92|Sales Executive|  5441|       9619|-4178|
# |        93|Sales Executive|  5209|       5441| -232|
# |        95|Sales Executive|  5010|       5209| -199|
# |        97|Sales Executive|  4999|       5010|  -11|
# |        98|Sales Executive|  4221|       4999| -778|
# |        99|Sales Executive| 13872|       4221| 9651|
# +----------+---------------+------+-----------+-----+
# only showing top 20 rows

# %% [markdown]
# ### Q6:

# %%
spark.sql("""
    SELECT employeeID, department, JobRole, age, gender, income,
    LEAD(Income, 2, 0) OVER (ORDER BY EmployeeID) as next_income
    FROM hremployee
""").show()
# Out:
# +----------+--------------------+--------------------+---+------+------+-----------+
# |employeeID|          department|             JobRole|age|gender|income|next_income|
# +----------+--------------------+--------------------+---+------+------+-----------+
# |         1|               Sales|     Sales Executive| 41|Female|  5993|       2090|
# |         2|Research & Develo...|  Research Scientist| 49|  Male|  5130|       2909|
# |         3|Research & Develo...|Laboratory Techni...| 37|  Male|  2090|       3468|
# |         4|Research & Develo...|  Research Scientist| 33|Female|  2909|       3068|
# |         5|Research & Develo...|Laboratory Techni...| 27|  Male|  3468|       2670|
# |         6|Research & Develo...|Laboratory Techni...| 32|  Male|  3068|       2693|
# |         7|Research & Develo...|Laboratory Techni...| 59|Female|  2670|       9526|
# |         8|Research & Develo...|Laboratory Techni...| 30|  Male|  2693|       5237|
# |         9|Research & Develo...|Manufacturing Dir...| 38|  Male|  9526|       2426|
# |        10|Research & Develo...|Healthcare Repres...| 36|  Male|  5237|       4193|
# |        11|Research & Develo...|Laboratory Techni...| 35|  Male|  2426|       2911|
# |        12|Research & Develo...|Laboratory Techni...| 29|Female|  4193|       2661|
# |        13|Research & Develo...|  Research Scientist| 31|  Male|  2911|       2028|
# |        14|Research & Develo...|Laboratory Techni...| 34|  Male|  2661|       9980|
# |        15|Research & Develo...|Laboratory Techni...| 28|  Male|  2028|       3298|
# |        16|Research & Develo...|Manufacturing Dir...| 29|Female|  9980|       2935|
# |        17|Research & Develo...|  Research Scientist| 32|  Male|  3298|      15427|
# |        18|Research & Develo...|Laboratory Techni...| 22|  Male|  2935|       3944|
# |        19|               Sales|             Manager| 53|Female| 15427|       4011|
# |        20|Research & Develo...|  Research Scientist| 38|  Male|  3944|       3407|
# +----------+--------------------+--------------------+---+------+------+-----------+
# only showing top 20 rows

# %% [markdown]
# ### Q7: NTILE() - dividing records into percentiles

# %%
spark.sql("""
    SELECT employeeID, department, JobRole, age, gender, income,
    NTILE(4) OVER (ORDER BY INCOME) as salary_quartiles
    FROM hremployee
""").show()
# Out:
# +----------+--------------------+--------------------+---+------+------+----------------+
# |employeeID|          department|             JobRole|age|gender|income|salary_quartiles|
# +----------+--------------------+--------------------+---+------+------+----------------+
# |       514|Research & Develo...|  Research Scientist| 20|  Male|  1009|               1|
# |       728|Research & Develo...|  Research Scientist| 18|  Male|  1051|               1|
# |       765|               Sales|Sales Representative| 28|  Male|  1052|               1|
# |      1338|               Sales|Sales Representative| 30|  Male|  1081|               1|
# |      1365|               Sales|Sales Representative| 29|  Male|  1091|               1|
# |       178|Research & Develo...|Laboratory Techni...| 19|  Male|  1102|               1|
# |       912|               Sales|Sales Representative| 25|  Male|  1118|               1|
# |      1402|Research & Develo...|Laboratory Techni...| 31|Female|  1129|               1|
# |       302|               Sales|Sales Representative| 18|Female|  1200|               1|
# |       911|Research & Develo...|  Research Scientist| 23|  Male|  1223|               1|
# |        24|Research & Develo...|  Research Scientist| 21|  Male|  1232|               1|
# |      1017|Research & Develo...|  Research Scientist| 31|Female|  1261|               1|
# |      1053|Research & Develo...|  Research Scientist| 30|  Male|  1274|               1|
# |       516|Research & Develo...|Laboratory Techni...| 35|  Male|  1281|               1|
# |      1013|               Sales|Sales Representative| 31|Female|  1359|               1|
# |      1205|Research & Develo...|Laboratory Techni...| 32|  Male|  1393|               1|
# |       778|Research & Develo...|Laboratory Techni...| 21|Female|  1416|               1|
# |       297|Research & Develo...|Laboratory Techni...| 18|  Male|  1420|               1|
# |       150|Research & Develo...|Laboratory Techni...| 19|Female|  1483|               1|
# |      1311|Research & Develo...|  Research Scientist| 18|Female|  1514|               1|
# +----------+--------------------+--------------------+---+------+------+----------------+
# only showing top 20 rows

# %% [markdown]
# ### Q8: Find number of employees in each percentile group 0-25th, 25th-50th, 50-75, and 75to100th [order by income and partition by department] using PERCENT_RANK and create a new category using CASE-WHEN

# %%
spark.sql("""
    SELECT 
    CASE 
        WHEN percentile<=0.25 THEN "0.00-0.25"
        WHEN percentile<=0.50 THEN "0.25-0.50"
        WHEN percentile<=0.75 THEN "0.50-0.75"
        ELSE "0.75-1.00"
    END AS category,
    COUNT(*) AS FREQUENCY
    
    FROM (
        SELECT Income,
        PERCENT_RANK() OVER(ORDER BY Income) AS percentile
        FROM hremployee
    ) AS _
    GROUP BY category
    ORDER BY category
""").show()
# Out:
# +---------+---------+
# | category|FREQUENCY|
# +---------+---------+
# |0.00-0.25|      368|
# |0.25-0.50|      367|
# |0.50-0.75|      367|
# |0.75-1.00|      367|
# +---------+---------+

# %% [markdown]
# ## HIVE Integration with PySpark

# %%
spark.stop()

# %%
# !jps
# Out:
# 18032 Jps
# 27057 NodeManager
# 26306 NameNode
# 26500 DataNode
# 13591 SparkSubmit
# 26732 SecondaryNameNode
# 26893 ResourceManager

# %%
# spark integration with Hive [hadoop services must be running]
# config for hive integration: property-name "spark.sql.warehouse.dir", value "/user/hive/warehouse"

spark = (SparkSession.builder.appName('pyspark-hive-Integration')
        .config('spark.sql.warehouse.dir', '/user/hive/warehouse')
        .enableHiveSupport().getOrCreate())

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.0.2.15:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.8</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-hive-Integration</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.sql('show databases').show()
# Out:
# +------------+
# |databaseName|
# +------------+
# |     default|
# +------------+

# %%
spark.sql("""
    CREATE database IF NOT EXISTS airlines
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
    use airlines
""")
# Out:
# DataFrame[]

# %%
spark.sql('show tables').show()
# Out:
# +--------+---------+-----------+
# |database|tableName|isTemporary|
# +--------+---------+-----------+
# +--------+---------+-----------+

# %%
spark.sql("""
    CREATE TABLE IF NOT EXISTS flights (
        DayofMonth int,
        DayofWeek int,
        Carrier VARCHAR(10),
        OriginAirportID int,
        DestAirportID int,
        DepDelay int,
        ArrDelay int
    )
    ROW FORMAT DELIMITED
    FIELDS TERMINATED BY ','
    LINES TERMINATED BY '\n'
    STORED AS TEXTFILE
    TBLPROPERTIES('skip.header.line.count'='1')
""")
# Out:
# DataFrame[]

# %%
spark.sql('show tables').show()
# Out:
# +--------+---------+-----------+
# |database|tableName|isTemporary|
# +--------+---------+-----------+
# |airlines|  flights|      false|
# +--------+---------+-----------+

# %%
spark.sql("""load data local inpath '/home/hadoop/Downloads/raw_flight_data_1.csv'
overwrite into table flights""")
# Out:
# DataFrame[]

# %%
spark.sql("""
    CREATE TABLE IF NOT EXISTS airports (
        airport_id int, 
        city VARCHAR(50), 
        state VARCHAR(50), 
        name VARCHAR(50)
    )
    ROW FORMAT DELIMITED
    FIELDS TERMINATED BY ','
    LINES TERMINATED BY '\n'
    STORED AS TEXTFILE
    TBLPROPERTIES('skip.header.line.count'='1')
""")
# Out:
# DataFrame[]

# %%
spark.sql("""load data local inpath '/home/hadoop/Downloads/airports_1.csv'
overwrite into table airports""")
# Out:
# DataFrame[]

# %%
spark.sql('show tables').show()
# Out:
# +--------+---------+-----------+
# |database|tableName|isTemporary|
# +--------+---------+-----------+
# |airlines| airports|      false|
# |airlines|  flights|      false|
# +--------+---------+-----------+

# %%
spark.sql("""
    SELECT * FROM airports
""").show()
# Out:
# +----------+-----------+-----+--------------------+
# |airport_id|       city|state|                name|
# +----------+-----------+-----+--------------------+
# |     10165|Adak Island|   AK|                Adak|
# |     10299|  Anchorage|   AK|Ted Stevens Ancho...|
# |     10304|      Aniak|   AK|       Aniak Airport|
# |     10754|     Barrow|   AK|Wiley Post/Will R...|
# |     10551|     Bethel|   AK|      Bethel Airport|
# |     10926|    Cordova|   AK|Merle K Mudhole S...|
# |     14709|  Deadhorse|   AK|   Deadhorse Airport|
# |     11336| Dillingham|   AK|  Dillingham Airport|
# |     11630|  Fairbanks|   AK|Fairbanks Interna...|
# |     11997|   Gustavus|   AK|    Gustavus Airport|
# |     12523|     Juneau|   AK|Juneau International|
# |     12819|  Ketchikan|   AK|Ketchikan Interna...|
# |     10245|King Salmon|   AK| King Salmon Airport|
# |     10170|     Kodiak|   AK|      Kodiak Airport|
# |     13970|   Kotzebue|   AK| Ralph Wien Memorial|
# |     13873|       Nome|   AK|        Nome Airport|
# |     14256| Petersburg|   AK|Petersburg James ...|
# |     14828|      Sitka|   AK|Sitka Rocky Gutie...|
# |     12807| St. Mary's|   AK|  St. Mary's Airport|
# |     11445|   Unalaska|   AK|    Unalaska Airport|
# +----------+-----------+-----+--------------------+
# only showing top 20 rows

# %%
spark.sql("""
    SELECT * FROM flights
""").show()
# Out:
# +----------+---------+-------+---------------+-------------+--------+--------+
# |DayofMonth|DayofWeek|Carrier|OriginAirportID|DestAirportID|DepDelay|ArrDelay|
# +----------+---------+-------+---------------+-------------+--------+--------+
# |        19|        5|     DL|          11433|        13303|      -3|       1|
# |        19|        5|     DL|          14869|        12478|       0|      -8|
# |        19|        5|     DL|          14057|        14869|      -4|     -15|
# |        19|        5|     DL|          15016|        11433|      28|      24|
# |        19|        5|     DL|          11193|        12892|      -6|     -11|
# |        19|        5|     DL|          10397|        15016|      -1|     -19|
# |        19|        5|     DL|          15016|        10397|       0|      -1|
# |        19|        5|     DL|          10397|        14869|      15|      24|
# |        19|        5|     DL|          10397|        10423|      33|      34|
# |        19|        5|     DL|          11278|        10397|     323|     322|
# |        19|        5|     DL|          14107|        13487|      -7|     -13|
# |        19|        5|     DL|          11433|        11298|      22|      41|
# |        19|        5|     DL|          11298|        11433|      40|      20|
# |        19|        5|     DL|          11433|        12892|      -2|      -7|
# |        19|        5|     DL|          10397|        12451|      71|      75|
# |        19|        5|     DL|          12451|        10397|      75|      57|
# |        19|        5|     DL|          12953|        10397|      -1|      10|
# |        19|        5|     DL|          11433|        12953|      -3|     -10|
# |        19|        5|     DL|          10397|        14771|      31|      38|
# |        19|        5|     DL|          13204|        10397|       8|      25|
# +----------+---------+-------+---------------+-------------+--------+--------+
# only showing top 20 rows

# %% [markdown]
# ### STEP 1 - Extract

# %%
flights_df = spark.table('airlines.flights')
airports_df = spark.table('airlines.airports')

# %%
airports_df.show(2)
# Out:
# +----------+-----------+-----+--------------------+
# |airport_id|       city|state|                name|
# +----------+-----------+-----+--------------------+
# |     10165|Adak Island|   AK|                Adak|
# |     10299|  Anchorage|   AK|Ted Stevens Ancho...|
# +----------+-----------+-----+--------------------+
# only showing top 2 rows

# %%
flights_df.show(2)
# Out:
# +----------+---------+-------+---------------+-------------+--------+--------+
# |DayofMonth|DayofWeek|Carrier|OriginAirportID|DestAirportID|DepDelay|ArrDelay|
# +----------+---------+-------+---------------+-------------+--------+--------+
# |        19|        5|     DL|          11433|        13303|      -3|       1|
# |        19|        5|     DL|          14869|        12478|       0|      -8|
# +----------+---------+-------+---------------+-------------+--------+--------+
# only showing top 2 rows

# %%
### STEP 2 - Transform

# %%
flights_join = flights_df.join(airports_df, 
                               on=(airports_df.airport_id==flights_df.OriginAirportID), 
                               how='inner')

# %%
flights_join.show()
# Out:
# +----------+---------+-------+---------------+-------------+--------+--------+----------+-----------------+-----+--------------------+
# |DayofMonth|DayofWeek|Carrier|OriginAirportID|DestAirportID|DepDelay|ArrDelay|airport_id|             city|state|                name|
# +----------+---------+-------+---------------+-------------+--------+--------+----------+-----------------+-----+--------------------+
# |        19|        5|     DL|          11433|        13303|      -3|       1|     11433|          Detroit|   MI|Detroit Metro Way...|
# |        19|        5|     DL|          14869|        12478|       0|      -8|     14869|   Salt Lake City|   UT|Salt Lake City In...|
# |        19|        5|     DL|          14057|        14869|      -4|     -15|     14057|         Portland|   OR|Portland Internat...|
# |        19|        5|     DL|          15016|        11433|      28|      24|     15016|        St. Louis|   MO|Lambert-St. Louis...|
# |        19|        5|     DL|          11193|        12892|      -6|     -11|     11193|       Cincinnati|   OH|Cincinnati/Northe...|
# |        19|        5|     DL|          10397|        15016|      -1|     -19|     10397|          Atlanta|   GA|Hartsfield-Jackso...|
# |        19|        5|     DL|          15016|        10397|       0|      -1|     15016|        St. Louis|   MO|Lambert-St. Louis...|
# |        19|        5|     DL|          10397|        14869|      15|      24|     10397|          Atlanta|   GA|Hartsfield-Jackso...|
# |        19|        5|     DL|          10397|        10423|      33|      34|     10397|          Atlanta|   GA|Hartsfield-Jackso...|
# |        19|        5|     DL|          11278|        10397|     323|     322|     11278|       Washington|   DC|Ronald Reagan Was...|
# |        19|        5|     DL|          14107|        13487|      -7|     -13|     14107|          Phoenix|   AZ|Phoenix Sky Harbo...|
# |        19|        5|     DL|          11433|        11298|      22|      41|     11433|          Detroit|   MI|Detroit Metro Way...|
# |        19|        5|     DL|          11298|        11433|      40|      20|     11298|Dallas/Fort Worth|   TX|Dallas/Fort Worth...|
# |        19|        5|     DL|          11433|        12892|      -2|      -7|     11433|          Detroit|   MI|Detroit Metro Way...|
# |        19|        5|     DL|          10397|        12451|      71|      75|     10397|          Atlanta|   GA|Hartsfield-Jackso...|
# |        19|        5|     DL|          12451|        10397|      75|      57|     12451|     Jacksonville|   FL|Jacksonville Inte...|
# |        19|        5|     DL|          12953|        10397|      -1|      10|     12953|         New York|   NY|           LaGuardia|
# |        19|        5|     DL|          11433|        12953|      -3|     -10|     11433|          Detroit|   MI|Detroit Metro Way...|
# |        19|        5|     DL|          10397|        14771|      31|      38|     10397|          Atlanta|   GA|Hartsfield-Jackso...|
# |        19|        5|     DL|          13204|        10397|       8|      25|     13204|          Orlando|   FL|Orlando Internati...|
# +----------+---------+-------+---------------+-------------+--------+--------+----------+-----------------+-----+--------------------+
# only showing top 20 rows

# %%
### STEP 3 - Load

# %%
flights_join = flights_join.repartition(4)

# %%
flights_join.write.parquet('file:///home/hadoop/Downloads/flights')

# %%
# read from parquet
flights_parquet_df = spark.read.parquet('file:///home/hadoop/Downloads/flights/')

# %%
# write to HDFS

flights_join.write.parquet('/flights1')

# %%
# partitioning data 
flights_join.write.partitionBy('Carrier').parquet('/airlines')

# %% [markdown]
# #### 04-09-2024

# %%
flights_join
# Out:
# DataFrame[DayofMonth: int, DayofWeek: int, Carrier: string, OriginAirportID: int, DestAirportID: int, DepDelay: int, ArrDelay: int, airport_id: int, city: string, state: string, name: string]

# %%
flights_join.write.bucketBy(col='state', numBuckets=50).format('csv').saveAsTable('bucketed_table')

# %%
flights_join.write.partitionBy('Carrier').bucketBy(col='state', numBuckets=30).format('parquet').saveAsTable('partition_bucket_table')

# %%
spark.sql("""
    SELECT carrier, COUNT(*)
    FROM partition_bucket_table
    GROUP BY carrier
""").show()
# Out:
# +-------+--------+
# |carrier|count(1)|
# +-------+--------+
# |     UA|  122443|
# |     AA|  124037|
# |     EV|   46563|
# |     B6|   51381|
# |     DL|  134724|
# |     OO|   69785|
# |     F9|    9811|
# |     YV|   14612|
# |     US|  100668|
# |     MQ|   45926|
# |     HA|    4962|
# |     AS|   28796|
# |     FL|   28053|
# |     VX|   14683|
# |     WN|  216101|
# |     9E|   36030|
# +-------+--------+

# %% [markdown]
# #### Load on MySQL

# %%
connection_properties = {
    'user': 'root',
    'password': 'hadoop@123',
    'driver': 'com.mysql.cj.jdbc.Driver'
}

flights_join.write.jdbc(url="jdbc:mysql://localhost:3306/flights", table='airlines', mode='overwrite', properties=connection_properties)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-77-98657ff74f62> in <module>
#       5 }
#       6
# ----> 7 flights_join.write.jdbc(url="jdbc:mysql://localhost:3306/flights", table='airlines', mode='overwrite', properties=connection_properties)
#
# /usr/local/spark/python/pyspark/sql/readwriter.py in jdbc(self, url, table, mode, properties)
#     988         for k in properties:
#     989             jprop.setProperty(k, properties[k])
# --> 990         self.mode(mode)._jwrite.jdbc(url, table, jprop)
#     991
#     992
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /usr/local/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     326                 raise Py4JJavaError(
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#     330                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o1356.jdbc.
# : org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:226)
# 	at org.apache.spark.sql.execution.exchange.BroadcastExchangeExec.doExecuteBroadcast(BroadcastExchangeExec.scala:146)
# 	at org.apache.spark.sql.execution.InputAdapter.doExecuteBroadcast(WholeStageCodegenExec.scala:387)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeBroadcast$1.apply(SparkPlan.scala:149)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeBroadcast$1.apply(SparkPlan.scala:145)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:160)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:157)
# 	at org.apache.spark.sql.execution.SparkPlan.executeBroadcast(SparkPlan.scala:145)
# 	at org.apache.spark.sql.execution.joins.BroadcastHashJoinExec.prepareBroadcast(BroadcastHashJoinExec.scala:117)
# 	at org.apache.spark.sql.execution.joins.BroadcastHashJoinExec.codegenInner(BroadcastHashJoinExec.scala:211)
# 	at org.apache.spark.sql.execution.joins.BroadcastHashJoinExec.doConsume(BroadcastHashJoinExec.scala:101)
# 	at org.apache.spark.sql.execution.CodegenSupport$class.consume(WholeStageCodegenExec.scala:189)
# 	at org.apache.spark.sql.execution.FilterExec.consume(basicPhysicalOperators.scala:87)
# 	at org.apache.spark.sql.execution.FilterExec.doConsume(basicPhysicalOperators.scala:212)
# 	at org.apache.spark.sql.execution.CodegenSupport$class.consume(WholeStageCodegenExec.scala:189)
# 	at org.apache.spark.sql.execution.InputAdapter.consume(WholeStageCodegenExec.scala:374)
# 	at org.apache.spark.sql.execution.InputAdapter.doProduce(WholeStageCodegenExec.scala:403)
# 	at org.apache.spark.sql.execution.CodegenSupport$$anonfun$produce$1.apply(WholeStageCodegenExec.scala:90)
# 	at org.apache.spark.sql.execution.CodegenSupport$$anonfun$produce$1.apply(WholeStageCodegenExec.scala:85)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:160)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:157)
# 	at org.apache.spark.sql.execution.CodegenSupport$class.produce(WholeStageCodegenExec.scala:85)
# 	at org.apache.spark.sql.execution.InputAdapter.produce(WholeStageCodegenExec.scala:374)
# 	at org.apache.spark.sql.execution.FilterExec.doProduce(basicPhysicalOperators.scala:127)
# 	at org.apache.spark.sql.execution.CodegenSupport$$anonfun$produce$1.apply(WholeStageCodegenExec.scala:90)
# 	at org.apache.spark.sql.execution.CodegenSupport$$anonfun$produce$1.apply(WholeStageCodegenExec.scala:85)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:160)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:157)
# 	at org.apache.spark.sql.execution.CodegenSupport$class.produce(WholeStageCodegenExec.scala:85)
# 	at org.apache.spark.sql.execution.FilterExec.produce(basicPhysicalOperators.scala:87)
# 	at org.apache.spark.sql.execution.joins.BroadcastHashJoinExec.doProduce(BroadcastHashJoinExec.scala:96)
# 	at org.apache.spark.sql.execution.CodegenSupport$$anonfun$produce$1.apply(WholeStageCodegenExec.scala:90)
# 	at org.apache.spark.sql.execution.CodegenSupport$$anonfun$produce$1.apply(WholeStageCodegenExec.scala:85)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:160)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:157)
# 	at org.apache.spark.sql.execution.CodegenSupport$class.produce(WholeStageCodegenExec.scala:85)
# 	at org.apache.spark.sql.execution.joins.BroadcastHashJoinExec.produce(BroadcastHashJoinExec.scala:40)
# 	at org.apache.spark.sql.execution.WholeStageCodegenExec.doCodeGen(WholeStageCodegenExec.scala:544)
# 	at org.apache.spark.sql.execution.WholeStageCodegenExec.doExecute(WholeStageCodegenExec.scala:598)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:136)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:132)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:160)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:157)
# 	at org.apache.spark.sql.execution.SparkPlan.execute(SparkPlan.scala:132)
# 	at org.apache.spark.sql.execution.exchange.ShuffleExchangeExec.prepareShuffleDependency(ShuffleExchangeExec.scala:92)
# 	at org.apache.spark.sql.execution.exchange.ShuffleExchangeExec$$anonfun$doExecute$1.apply(ShuffleExchangeExec.scala:128)
# 	at org.apache.spark.sql.execution.exchange.ShuffleExchangeExec$$anonfun$doExecute$1.apply(ShuffleExchangeExec.scala:119)
# 	at org.apache.spark.sql.catalyst.errors.package$.attachTree(package.scala:52)
# 	at org.apache.spark.sql.execution.exchange.ShuffleExchangeExec.doExecute(ShuffleExchangeExec.scala:119)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:136)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:132)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:160)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:157)
# 	at org.apache.spark.sql.execution.SparkPlan.execute(SparkPlan.scala:132)
# 	at org.apache.spark.sql.execution.DeserializeToObjectExec.doExecute(objects.scala:89)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:136)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:132)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:160)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:157)
# 	at org.apache.spark.sql.execution.SparkPlan.execute(SparkPlan.scala:132)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd$lzycompute(QueryExecution.scala:83)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd(QueryExecution.scala:81)
# 	at org.apache.spark.sql.Dataset.rdd$lzycompute(Dataset.scala:3043)
# 	at org.apache.spark.sql.Dataset.rdd(Dataset.scala:3041)
# 	at org.apache.spark.sql.execution.datasources.jdbc.JdbcUtils$.saveTable(JdbcUtils.scala:838)
# 	at org.apache.spark.sql.execution.datasources.jdbc.JdbcRelationProvider.createRelation(JdbcRelationProvider.scala:63)
# 	at org.apache.spark.sql.execution.datasources.SaveIntoDataSourceCommand.run(SaveIntoDataSourceCommand.scala:45)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult$lzycompute(commands.scala:70)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult(commands.scala:68)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.doExecute(commands.scala:86)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:136)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:132)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:160)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:157)
# 	at org.apache.spark.sql.execution.SparkPlan.execute(SparkPlan.scala:132)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd$lzycompute(QueryExecution.scala:83)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd(QueryExecution.scala:81)
# 	at org.apache.spark.sql.DataFrameWriter$$anonfun$runCommand$1.apply(DataFrameWriter.scala:696)
# 	at org.apache.spark.sql.DataFrameWriter$$anonfun$runCommand$1.apply(DataFrameWriter.scala:696)
# 	at org.apache.spark.sql.execution.SQLExecution$$anonfun$withNewExecutionId$1.apply(SQLExecution.scala:80)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:127)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:75)
# 	at org.apache.spark.sql.DataFrameWriter.runCommand(DataFrameWriter.scala:696)
# 	at org.apache.spark.sql.DataFrameWriter.saveToV1Source(DataFrameWriter.scala:305)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:291)
# 	at org.apache.spark.sql.DataFrameWriter.jdbc(DataFrameWriter.scala:535)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:745)
# Caused by: java.lang.IllegalStateException: Cannot call methods on a stopped SparkContext.
# This stopped SparkContext was created at:
#
# org.apache.spark.api.java.JavaSparkContext.<init>(JavaSparkContext.scala:58)
# sun.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# sun.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:62)
# sun.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# java.lang.reflect.Constructor.newInstance(Constructor.java:423)
# py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:247)
# py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# py4j.Gateway.invoke(Gateway.java:238)
# py4j.commands.ConstructorCommand.invokeConstructor(ConstructorCommand.java:80)
# py4j.commands.ConstructorCommand.execute(ConstructorCommand.java:69)
# py4j.GatewayConnection.run(GatewayConnection.java:238)
# java.lang.Thread.run(Thread.java:745)
#
# The currently active SparkContext was created at:
#
# org.apache.spark.api.java.JavaSparkContext.<init>(JavaSparkContext.scala:58)
# sun.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# sun.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:62)
# sun.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# java.lang.reflect.Constructor.newInstance(Constructor.java:423)
# py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:247)
# py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# py4j.Gateway.invoke(Gateway.java:238)
# py4j.commands.ConstructorCommand.invokeConstructor(ConstructorCommand.java:80)
# py4j.commands.ConstructorCommand.execute(ConstructorCommand.java:69)
# py4j.GatewayConnection.run(GatewayConnection.java:238)
# java.lang.Thread.run(Thread.java:745)
#
# 	at org.apache.spark.SparkContext.assertNotStopped(SparkContext.scala:100)
# 	at org.apache.spark.SparkContext.broadcast(SparkContext.scala:1486)
# 	at org.apache.spark.sql.hive.HadoopTableReader.<init>(TableReader.scala:89)
# 	at org.apache.spark.sql.hive.execution.HiveTableScanExec.org$apache$spark$sql$hive$execution$HiveTableScanExec$$hadoopReader$lzycompute(HiveTableScanExec.scala:105)
# 	at org.apache.spark.sql.hive.execution.HiveTableScanExec.org$apache$spark$sql$hive$execution$HiveTableScanExec$$hadoopReader(HiveTableScanExec.scala:105)
# 	at org.apache.spark.sql.hive.execution.HiveTableScanExec$$anonfun$10.apply(HiveTableScanExec.scala:188)
# 	at org.apache.spark.sql.hive.execution.HiveTableScanExec$$anonfun$10.apply(HiveTableScanExec.scala:188)
# 	at org.apache.spark.util.Utils$.withDummyCallSite(Utils.scala:2470)
# 	at org.apache.spark.sql.hive.execution.HiveTableScanExec.doExecute(HiveTableScanExec.scala:187)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:136)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:132)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:160)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:157)
# 	at org.apache.spark.sql.execution.SparkPlan.execute(SparkPlan.scala:132)
# 	at org.apache.spark.sql.execution.InputAdapter.inputRDDs(WholeStageCodegenExec.scala:391)
# 	at org.apache.spark.sql.execution.FilterExec.inputRDDs(basicPhysicalOperators.scala:123)
# 	at org.apache.spark.sql.execution.WholeStageCodegenExec.doExecute(WholeStageCodegenExec.scala:627)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:136)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:132)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:160)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:157)
# 	at org.apache.spark.sql.execution.SparkPlan.execute(SparkPlan.scala:132)
# 	at org.apache.spark.sql.execution.SparkPlan.getByteArrayRdd(SparkPlan.scala:252)
# 	at org.apache.spark.sql.execution.SparkPlan.executeCollectIterator(SparkPlan.scala:311)
# 	at org.apache.spark.sql.execution.exchange.BroadcastExchangeExec$$anonfun$relationFuture$1$$anonfun$apply$1.apply(BroadcastExchangeExec.scala:79)
# 	at org.apache.spark.sql.execution.exchange.BroadcastExchangeExec$$anonfun$relationFuture$1$$anonfun$apply$1.apply(BroadcastExchangeExec.scala:76)
# 	at org.apache.spark.sql.execution.SQLExecution$$anonfun$withExecutionId$1.apply(SQLExecution.scala:103)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:127)
# 	at org.apache.spark.sql.execution.SQLExecution$.withExecutionId(SQLExecution.scala:100)
# 	at org.apache.spark.sql.execution.exchange.BroadcastExchangeExec$$anonfun$relationFuture$1.apply(BroadcastExchangeExec.scala:75)
# 	at org.apache.spark.sql.execution.exchange.BroadcastExchangeExec$$anonfun$relationFuture$1.apply(BroadcastExchangeExec.scala:75)
# 	at scala.concurrent.impl.Future$PromiseCompletingRunnable.liftedTree1$1(Future.scala:24)
# 	at scala.concurrent.impl.Future$PromiseCompletingRunnable.run(Future.scala:24)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1142)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:617)
# 	... 1 more

# %%
spark.stop()

# %%
sc.stop()

# %%
# !jps
# Out:
# 27057 NodeManager
# 26306 NameNode
# 26500 DataNode
# 18278 SparkSubmit
# 26732 SecondaryNameNode
# 26893 ResourceManager
# 28878 Jps
